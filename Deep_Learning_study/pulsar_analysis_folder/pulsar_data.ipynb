# %%
import pandas as pd
import numpy as np
import csv

# %%
# 파일 불러오기
with open('Pulsar.csv') as csvfile:
    csvreader = csv.reader(csvfile)
    next(csvreader, None)
    rows = []
    for row in csvreader:
        rows.append(row)

input_cnt, output_cnt = 8,1
data = np.asarray(rows, dtype='float32')

# %%
# weight와 bias를 포함한 파라미터 및 하이퍼파라미터 설정
RND_MEAN = 0
RND_STD = 0.0030
LEARNING_RATE = 0.001

weight = np.random.normal(RND_MEAN,RND_STD,[input_cnt,output_cnt])
bias = np.zeros([output_cnt])

epoch_count = 100
mb_size = 10
report = 1

# %%
# 데이터를 섞고 랜덤으로 추출하기
shuffle_map = np.arange(data.shape[0])
np.random.shuffle(shuffle_map)
step_count = int(data.shape[0] * 0.8) // mb_size
test_begin_idx = step_count * mb_size

#학습에 사용하게될 함수 정의
def relu(x):
    return np.maximum(x,0)
def sigmoid(x):
    return np.exp(-relu(-x)) / (1.0 + np.exp(-np.abs(x)))
def sigmid_derv(x,y):
    return y * (1-y)
def sigmoid_cross_entropy_with_logits(z,x):
    return relu(x) - x * z + np.log(1 + np.exp(-np.abs(x)))
def sigmoid_cross_entropy_with_logits_derv(z,x):
    return -z + sigmoid(x)

# 데이터 학습 및 결과 도출
for epoch in range(epoch_count):
    losses, accs = [], []

    for n in range(step_count):
        if n == 0:
            np.random.shuffle(shuffle_map[:test_begin_idx])
        train_x = data[shuffle_map[mb_size*n:mb_size*(n+1)]][:, :-output_cnt]
        train_y = data[shuffle_map[mb_size*n:mb_size*(n+1)]][:, -output_cnt:]

        # forward path 연산
        output_train_x = np.matmul(train_x,weight) + bias
        entropy = sigmoid_cross_entropy_with_logits(train_y,output_train_x)
        loss = np.mean(entropy)

        # 정확도 계산
        estimate = np.greater(output_train_x,0)
        answer = np.greater(train_y,0.5)
        correct = np.equal(estimate,answer)
        accuracy = np.mean(correct)

        losses.append(loss)
        accs.append(accuracy)

        # backporpagation 연산
        G_loss = 1.0

        g_loss_entropy = 1.0 / np.prod(entropy.shape)
        g_entorpy_output = sigmoid_cross_entropy_with_logits_derv(train_y,output_train_x)

        G_entropy = g_loss_entropy * G_loss
        G_output = g_entorpy_output * G_entropy

        g_outout_w = train_x.transpose()

        G_w = np.matmul(g_outout_w,G_output)
        G_b = np.sum(G_output, axis=0)

        weight -= LEARNING_RATE * G_w
        bias -= LEARNING_RATE * G_b

    if report > 0 and (epoch+1) % report == 0:
        test_data = data[shuffle_map[test_begin_idx:]]
        test_x = test_data[:, :-output_cnt]
        test_y = test_data[:, -output_cnt:]
        output_test_x = np.matmul(test_x,weight) + bias
        acc = np.mean(np.equal(np.greater(output_test_x,0),np.greater(test_y,0.5)))
        print('Epoch {}: loss={:5.3f}, accuracy={:5.3f}/{:5.3f}'. \
              format(epoch+1,np.mean(losses),np.mean(accs),acc))

output_test_x = np.matmul(test_x,weight) + bias
final_acc = np.mean(np.equal(np.greater(output_test_x,0),np.greater(test_y,0.5)))
print('\nFinal Test : final accuracy = {:5.3f}'.format(final_acc))
# Out:
# Epoch 1: loss=0.139, accuracy=0.961/0.941
# Epoch 2: loss=0.134, accuracy=0.965/0.969
# Epoch 3: loss=0.119, accuracy=0.969/0.973
# Epoch 4: loss=0.122, accuracy=0.968/0.973
# Epoch 5: loss=0.121, accuracy=0.969/0.969
# Epoch 6: loss=0.123, accuracy=0.971/0.973
# Epoch 7: loss=0.121, accuracy=0.971/0.878
# Epoch 8: loss=0.119, accuracy=0.969/0.974
# Epoch 9: loss=0.129, accuracy=0.970/0.971
# Epoch 10: loss=0.128, accuracy=0.971/0.974
# Epoch 11: loss=0.135, accuracy=0.970/0.970
# Epoch 12: loss=0.128, accuracy=0.970/0.973
# Epoch 13: loss=0.122, accuracy=0.971/0.965
# Epoch 14: loss=0.118, accuracy=0.972/0.963
# Epoch 15: loss=0.127, accuracy=0.970/0.972
# Epoch 16: loss=0.132, accuracy=0.970/0.974
# Epoch 17: loss=0.125, accuracy=0.970/0.961
# Epoch 18: loss=0.119, accuracy=0.969/0.970
# Epoch 19: loss=0.122, accuracy=0.969/0.969
# Epoch 20: loss=0.122, accuracy=0.971/0.974
# Epoch 21: loss=0.121, accuracy=0.969/0.973
# Epoch 22: loss=0.128, accuracy=0.970/0.972
# Epoch 23: loss=0.130, accuracy=0.971/0.965
# Epoch 24: loss=0.120, accuracy=0.972/0.973
# Epoch 25: loss=0.122, accuracy=0.971/0.974
# Epoch 26: loss=0.119, accuracy=0.970/0.974
# Epoch 27: loss=0.124, accuracy=0.971/0.973
# Epoch 28: loss=0.126, accuracy=0.971/0.970
# Epoch 29: loss=0.131, accuracy=0.971/0.973
# Epoch 30: loss=0.125, accuracy=0.970/0.973
# Epoch 31: loss=0.125, accuracy=0.972/0.972
# Epoch 32: loss=0.115, accuracy=0.972/0.973
# Epoch 33: loss=0.115, accuracy=0.972/0.973
# Epoch 34: loss=0.121, accuracy=0.972/0.972
# Epoch 35: loss=0.123, accuracy=0.970/0.973
# Epoch 36: loss=0.117, accuracy=0.972/0.971
# Epoch 37: loss=0.121, accuracy=0.971/0.970
# Epoch 38: loss=0.121, accuracy=0.970/0.970
# Epoch 39: loss=0.127, accuracy=0.969/0.973
# Epoch 40: loss=0.124, accuracy=0.970/0.971
# Epoch 41: loss=0.122, accuracy=0.970/0.970
# Epoch 42: loss=0.132, accuracy=0.970/0.970
# Epoch 43: loss=0.127, accuracy=0.970/0.973
# Epoch 44: loss=0.123, accuracy=0.970/0.970
# Epoch 45: loss=0.119, accuracy=0.971/0.968
# Epoch 46: loss=0.126, accuracy=0.970/0.974
# Epoch 47: loss=0.123, accuracy=0.970/0.970
# Epoch 48: loss=0.125, accuracy=0.970/0.972
# Epoch 49: loss=0.120, accuracy=0.970/0.970
# Epoch 50: loss=0.117, accuracy=0.972/0.972
# Epoch 51: loss=0.128, accuracy=0.971/0.972
# Epoch 52: loss=0.116, accuracy=0.972/0.969
# Epoch 53: loss=0.117, accuracy=0.971/0.974
# Epoch 54: loss=0.123, accuracy=0.971/0.968
# Epoch 55: loss=0.121, accuracy=0.970/0.972
# Epoch 56: loss=0.118, accuracy=0.972/0.970
# Epoch 57: loss=0.124, accuracy=0.969/0.974
# Epoch 58: loss=0.119, accuracy=0.971/0.974
# Epoch 59: loss=0.120, accuracy=0.971/0.973
# Epoch 60: loss=0.120, accuracy=0.971/0.969
# Epoch 61: loss=0.136, accuracy=0.972/0.971
# Epoch 62: loss=0.116, accuracy=0.972/0.974
# Epoch 63: loss=0.122, accuracy=0.970/0.949
# Epoch 64: loss=0.132, accuracy=0.970/0.970
# Epoch 65: loss=0.126, accuracy=0.971/0.973
# Epoch 66: loss=0.124, accuracy=0.970/0.970
# Epoch 67: loss=0.123, accuracy=0.970/0.967
# Epoch 68: loss=0.136, accuracy=0.970/0.974
# Epoch 69: loss=0.122, accuracy=0.971/0.973
# Epoch 70: loss=0.114, accuracy=0.972/0.973
# Epoch 71: loss=0.122, accuracy=0.972/0.973
# Epoch 72: loss=0.121, accuracy=0.970/0.973
# Epoch 73: loss=0.123, accuracy=0.971/0.973
# Epoch 74: loss=0.120, accuracy=0.973/0.974
# Epoch 75: loss=0.134, accuracy=0.969/0.973
# Epoch 76: loss=0.120, accuracy=0.971/0.969
# Epoch 77: loss=0.124, accuracy=0.971/0.974
# Epoch 78: loss=0.128, accuracy=0.971/0.970
# Epoch 79: loss=0.131, accuracy=0.969/0.974
# Epoch 80: loss=0.118, accuracy=0.971/0.972
# Epoch 81: loss=0.132, accuracy=0.970/0.969
# Epoch 82: loss=0.118, accuracy=0.973/0.973
# Epoch 83: loss=0.122, accuracy=0.971/0.975
# Epoch 84: loss=0.122, accuracy=0.970/0.972
# Epoch 85: loss=0.122, accuracy=0.971/0.970
# Epoch 86: loss=0.137, accuracy=0.971/0.974
# Epoch 87: loss=0.124, accuracy=0.971/0.973
# Epoch 88: loss=0.112, accuracy=0.972/0.970
# Epoch 89: loss=0.117, accuracy=0.970/0.974
# Epoch 90: loss=0.128, accuracy=0.969/0.969
# Epoch 91: loss=0.125, accuracy=0.971/0.972
# Epoch 92: loss=0.116, accuracy=0.970/0.947
# Epoch 93: loss=0.120, accuracy=0.971/0.971
# Epoch 94: loss=0.115, accuracy=0.972/0.971
# Epoch 95: loss=0.120, accuracy=0.971/0.971
# Epoch 96: loss=0.123, accuracy=0.971/0.965
# Epoch 97: loss=0.118, accuracy=0.972/0.972
# Epoch 98: loss=0.119, accuracy=0.971/0.974
# Epoch 99: loss=0.124, accuracy=0.971/0.972
# Epoch 100: loss=0.120, accuracy=0.970/0.972
#
# Final Test : final accuracy = 0.972

# %%
# Out:
# 14310

# %%
x = -10
np.maximum(x,0)
# Out:
# 0
