# %%
import requests
import pandas as pd
import numpy as np

# %%
# 첼린저,그랜드마스터,마스터의 솔로랭크 정보를 가져오기 위한 함수 생성

import requests
 
api_key = "RGAPI-f9ad895b-5f33-4894-8069-db22118e56a0"
header = {"X-Riot-Token" : api_key}
 
def league_v4_tier(tier):
    # 솔랭 기준
    queue = 'RANKED_SOLO_5x5'
 
    if tier == 'challenger' :
        url = f"https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/{queue}"
    elif tier == 'grandmaster':
        url = f"https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/{queue}"
    else:
        url = f"https://kr.api.riotgames.com/lol/league/v4/masterleagues/by-queue/{queue}"
        
    return requests.get(url, headers=header)

# %%
# 티어별 솔로랭크 정보를 테이블로 만들기

challenger_data = pd.DataFrame(league_v4_tier('challenger').json())
grandmaster_data = pd.DataFrame(league_v4_tier('grandmaster').json())
master_data = pd.DataFrame(league_v4_tier('master').json())

# %%
# 첼린저 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

challenger_df = pd.DataFrame([challenger_data['entries'][0]])
data_size = len(challenger_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([challenger_data['entries'][i]])
    challenger_df = pd.concat([challenger_df,append_df],ignore_index = True)

challenger_df['tier'] = 'CHALLENGER'
challenger_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0      Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s          1815    I
# 1    OacbcxRqaq3fsLvUCN2huofbe9zWUJGf6OPiSkFzhNugMU...          1194    I
# 2      bpTHUA287LW-JTv18xbAo9h6MTz2pUO2hTEKYrtDqDzPZFI          1437    I
# 3      LCO5dHGZnSmoruxg7F4KxB8OiTKXYPWLbSS3q_EyVRyLygI          1207    I
# 4      jwyUnVUhiSLk_dw_s-T_jSZKpHxACz-uhBZWa4Zpv64KGos          1421    I
# ..                                                 ...           ...  ...
# 295  RuIzEFZcyLYPj48M0Ac3dYMNAlCCSwiexmnqOb9VWwW3bA...          1176    I
# 296    FiSZjHpMJ8iWRPq0KI5VOC4hz_eKki20PQrs50GEseuBdeI          1303    I
# 297  P9fOrwt9AAGyaR12uUh7D68LpHNAODj97BW1HdSND0FARN...          1277    I
# 298  XK4KQMaUWZrFATz3z4O8SR2bu_HvMlCgCPgtAlbln9NQuJ...          1249    I
# 299  m_PRA704HCO-hLlpMmPUEDWPOpythJNrCrUU5dfWOjaLC2...          1115    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak        tier
# 0     181     109     True     False       False       True  CHALLENGER
# 1     245     205     True     False       False      False  CHALLENGER
# 2     211     166     True     False       False      False  CHALLENGER
# 3     214     172     True     False       False      False  CHALLENGER
# 4     215     158     True     False       False      False  CHALLENGER
# ..    ...     ...      ...       ...         ...        ...         ...
# 295   317     272     True     False       False      False  CHALLENGER
# 296   211     162     True     False       False      False  CHALLENGER
# 297   180     134    False     False       False      False  CHALLENGER
# 298   171     123    False     False       False      False  CHALLENGER
# 299   281     248    False     False        True       True  CHALLENGER
#
# [300 rows x 10 columns]

# %%
# 그랜드마스터 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

grandmaster_df = pd.DataFrame([grandmaster_data['entries'][0]])
data_size = len(grandmaster_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([grandmaster_data['entries'][i]])
    grandmaster_df = pd.concat([grandmaster_df,append_df],ignore_index = True)

grandmaster_df['tier'] = 'GRANDMASTER'
grandmaster_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0    l0wpmE9YQdbnjWHTgdKKia1_Gd80nWhNNfkw026viyuITw...          1007    I
# 1    H5xs0BlEBEhMzzzthz3T60lKSIq6ojneA4VrL1ruR44DYQ...          1046    I
# 2     80znzW0xh9p3RaJyBUbzL131mordVTRn7QzB_TeoVUqAT_G4           749    I
# 3      DJKzVYoi3OF6Y3kO0zA5OK03R534JiMPsKOXRDZ36nLa6aY           886    I
# 4    O57gK5nJHCVdPeTMlVzZfSIrYhds8AqAFkKBdWILTwQf2h...           827    I
# ..                                                 ...           ...  ...
# 695  IX-tlOYSOFBT5gjqAkzuhrRf12VlY8yFBqRToVH7pFLwa_...           697    I
# 696  vJ3pjMTqXEMg_LZn_910Tv7QZ8mfuxWt4LjBx1t3Pen6xB...           954    I
# 697  XvYK-fC2-z6bS9Ww2-4lonu4MppUMCSFjaZImtkXOsbOyG...          1060    I
# 698  B4iNK55LUjxsRUUWVOjcGWz0FH7rb7ZRVz5wlOOR3sQIbc...           887    I
# 699     tN6wOCGPNC5cgyh6p7_HqMc-XbCFndZ3rruWxbcanSrl4g           813    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak         tier
# 0     180     140    False     False       False      False  GRANDMASTER
# 1     110      73    False     False       False      False  GRANDMASTER
# 2     274     246    False     False        True      False  GRANDMASTER
# 3     166     127    False     False        True      False  GRANDMASTER
# 4     371     337    False     False        True      False  GRANDMASTER
# ..    ...     ...      ...       ...         ...        ...          ...
# 695   336     305    False     False        True      False  GRANDMASTER
# 696   178     125    False     False       False      False  GRANDMASTER
# 697   245     213    False     False        True      False  GRANDMASTER
# 698   276     232    False     False       False      False  GRANDMASTER
# 699   212     189    False     False       False       True  GRANDMASTER
#
# [700 rows x 10 columns]

# %%
# 마스터 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

master_df = pd.DataFrame([master_data['entries'][0]])
data_size = len(master_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([master_data['entries'][i]])
    master_df = pd.concat([master_df,append_df],ignore_index = True)

master_df['tier'] = 'MASTER'
master_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0        35OvEejociY9vfyy55Y7YvXzxPieeviJ50UrZsvagQ4mk6A            66    I
# 1        Oh7Yk5MgVrKrO-a_Qdijahqy_dTieuWUMZdmH__O_2L1WtM           102    I
# 2      sYj2_zjDXBqFzhxtgCDxTbvqv3r9C6lLbDvFd3LAynjYqD...           272    I
# 3      Q2kjj730eUmJaPf2A8weQXfeU_rP3fCilfyUxYzpndaj1O...           384    I
# 4      RZ5muZyTdx1foy2xm6wyKq7WPznkSDdU3NXSWhPc9YJxDV...           484    I
# ...                                                  ...           ...  ...
# 13692     Kix31WXKGH3JChqba8aj7O1v8cUbOeW8b2sIJQyxnLZobg           127    I
# 13693   GuHEPHRZ26R8Yxm9PCvYlA7AKJH7UH84qV8dvUUWCd-GXpAe           261    I
# 13694  vBpuZLe0c00bAUHtFzq1K7OPN1HqIZgaeUZvKNcR8xygxT...           183    I
# 13695  G-OtVDM0OszqiEfah3Np6XfX9LeEX-sRh9G7Jr5rCYp-aw...            22    I
# 13696  qjVmXNeHl9Ufn9kgCfAlasbg-XRvLYDSROt61FNB4BELYD...           254    I
#
#        wins  losses  veteran  inactive  freshBlood  hotStreak    tier
# 0        55      47    False     False        True      False  MASTER
# 1        22       7    False     False       False      False  MASTER
# 2       323     319     True     False       False      False  MASTER
# 3        97      61    False     False       False      False  MASTER
# 4       324     313     True     False       False      False  MASTER
# ...     ...     ...      ...       ...         ...        ...     ...
# 13692   137     115    False     False       False      False  MASTER
# 13693    55      40    False     False       False      False  MASTER
# 13694   130      91     True     False       False       True  MASTER
# 13695    57      51    False     False        True      False  MASTER
# 13696   113      97     True     False       False       True  MASTER
#
# [13697 rows x 10 columns]

# %%
# 첼린저,그마,마스터 티어의 entries정보를 하나의 테이블로 합치기

top_class_df = pd.concat([challenger_df,grandmaster_df,master_df],ignore_index = True)
top_class_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0        Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s          1815    I
# 1      OacbcxRqaq3fsLvUCN2huofbe9zWUJGf6OPiSkFzhNugMU...          1194    I
# 2        bpTHUA287LW-JTv18xbAo9h6MTz2pUO2hTEKYrtDqDzPZFI          1437    I
# 3        LCO5dHGZnSmoruxg7F4KxB8OiTKXYPWLbSS3q_EyVRyLygI          1207    I
# 4        jwyUnVUhiSLk_dw_s-T_jSZKpHxACz-uhBZWa4Zpv64KGos          1421    I
# ...                                                  ...           ...  ...
# 14692     Kix31WXKGH3JChqba8aj7O1v8cUbOeW8b2sIJQyxnLZobg           127    I
# 14693   GuHEPHRZ26R8Yxm9PCvYlA7AKJH7UH84qV8dvUUWCd-GXpAe           261    I
# 14694  vBpuZLe0c00bAUHtFzq1K7OPN1HqIZgaeUZvKNcR8xygxT...           183    I
# 14695  G-OtVDM0OszqiEfah3Np6XfX9LeEX-sRh9G7Jr5rCYp-aw...            22    I
# 14696  qjVmXNeHl9Ufn9kgCfAlasbg-XRvLYDSROt61FNB4BELYD...           254    I
#
#        wins  losses  veteran  inactive  freshBlood  hotStreak        tier
# 0       181     109     True     False       False       True  CHALLENGER
# 1       245     205     True     False       False      False  CHALLENGER
# 2       211     166     True     False       False      False  CHALLENGER
# 3       214     172     True     False       False      False  CHALLENGER
# 4       215     158     True     False       False      False  CHALLENGER
# ...     ...     ...      ...       ...         ...        ...         ...
# 14692   137     115    False     False       False      False      MASTER
# 14693    55      40    False     False       False      False      MASTER
# 14694   130      91     True     False       False       True      MASTER
# 14695    57      51    False     False        True      False      MASTER
# 14696   113      97     True     False       False       True      MASTER
#
# [14697 rows x 10 columns]

# %%
# summonerid로 소환사 정보인 puuid를 가져오기 위한 API코드

import requests
 
api_key = "RGAPI-f9ad895b-5f33-4894-8069-db22118e56a0"
header = {"X-Riot-Token" : api_key}

def summoners(encryptedSummonerId):
    url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/{encryptedSummonerId}"
    
    return requests.get(url, headers = header)

# %%
encryptedSummonerId = top_class_df['summonerId'].loc[0]

temp_summoners = summoners(encryptedSummonerId).json()
temp_summoners
# Out:
# {'id': 'Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s',
#  'accountId': 'vSUf4CYN91bnoZRv8RueblPvTGoOZz-hfaYdyrtRCZ17d6o',
#  'puuid': 'FNHn19CPilc-zYduEMr3nKVkpX5OAZycwOETS9mns3T8pP7cz0IFIgajrrfNciZAOP_nCB-eUzYeNA',
#  'profileIconId': 3898,
#  'revisionDate': 1722180852047,
#  'summonerLevel': 702}

# %%
temp_summoners['puuid']
# Out:
# 'FNHn19CPilc-zYduEMr3nKVkpX5OAZycwOETS9mns3T8pP7cz0IFIgajrrfNciZAOP_nCB-eUzYeNA'

# %%
def match_list(puuid):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?type=ranked&start={0}&count={100}"
    
    return requests.get(url, headers=header)

# %%
puuid = temp_summoners['puuid']

temp_match_list = match_list(puuid).json()
temp_match_list
# Out:
# ['KR_7188590273',
#  'KR_7186044060',
#  'KR_7185980060',
#  'KR_7185839874',
#  'KR_7185714566',
#  'KR_7185672699',
#  'KR_7185541354',
#  'KR_7183007383',
#  'KR_7182957606',
#  'KR_7182842090',
#  'KR_7182703122',
#  'KR_7182573440',
#  'KR_7182374609',
#  'KR_7180417714',
#  'KR_7180367213',
#  'KR_7180248658',
#  'KR_7180180488',
#  'KR_7180048916',
#  'KR_7179416006',
#  'KR_7179219856',
#  'KR_7179122623',
#  'KR_7179006247',
#  'KR_7178233335',
#  'KR_7177562602',
#  'KR_7176043052',
#  'KR_7174960968',
#  'KR_7174885317',
#  'KR_7174828196',
#  'KR_7174726143',
#  'KR_7174633002',
#  'KR_7174495872',
#  'KR_7171745852',
#  'KR_7171582692',
#  'KR_7171494087',
#  'KR_7171323471',
#  'KR_7169304856',
#  'KR_7169254256',
#  'KR_7168392210',
#  'KR_7168266220',
#  'KR_7168161499',
#  'KR_7168007244',
#  'KR_7167894856',
#  'KR_7167645378',
#  'KR_7159177112',
#  'KR_7158897558',
#  'KR_7158707891',
#  'KR_7158518921',
#  'KR_7157518856',
#  'KR_7155142594',
#  'KR_7155070679',
#  'KR_7154962307',
#  'KR_7154814732',
#  'KR_7154569760',
#  'KR_7153542523',
#  'KR_7153345692',
#  'KR_7153212384',
#  'KR_7152982707',
#  'KR_7152003080',
#  'KR_7151375054',
#  'KR_7151354339',
#  'KR_7151324389',
#  'KR_7151294240',
#  'KR_7151250754',
#  'KR_7150712673',
#  'KR_7150323362',
#  'KR_7150277719',
#  'KR_7150230140',
#  'KR_7150169368',
#  'KR_7149223334',
#  'KR_7149200764',
#  'KR_7149170767',
#  'KR_7149152291',
#  'KR_7149088355',
#  'KR_7148146355',
#  'KR_7148117011',
#  'KR_7148072606',
#  'KR_7148030421',
#  'KR_7146680341',
#  'KR_7146640476',
#  'KR_7146565370',
#  'KR_7146470699',
#  'KR_7145829718',
#  'KR_7145077427',
#  'KR_7145020407',
#  'KR_7144608269',
#  'KR_7144399704',
#  'KR_7143969701',
#  'KR_7143805998',
#  'KR_7143513845',
#  'KR_7143433616',
#  'KR_7143358753',
#  'KR_7142878021',
#  'KR_7142838447',
#  'KR_7142809100',
#  'KR_7141755856',
#  'KR_7141705273',
#  'KR_7141661242',
#  'KR_7140642632',
#  'KR_7140530514',
#  'KR_7138000163']

# %%
import requests
 
api_key = "RGAPI-f9ad895b-5f33-4894-8069-db22118e56a0"
header = {"X-Riot-Token" : api_key}
 
def match(matchId):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{matchId}"
    
    return requests.get(url, headers=header)

# %%
matchId = temp_match_list[0]
temp_match_data = match(matchId).json()
temp_match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_7188590273',
#   'participants': ['PNXS-TH8OkdRyLXONcMZtNDIfJ0hEYta8GUCaEKp_tKGpoDF4zBsfViA_YsK8GA0qevrcdyDW2HJFA',
#    'LQ2jrGzLI85VQ2kF1rtkUGLb1dek_25NcO5KNveWda8Mn7SsEGBJt3CMqztdRfFpkatAtKrCzfwAHA',
#    '9MOT2cUzidG9slSLcCmeegX0L4dce13-sz_jAUrdlrstO5xbpM-NAvbZ2QdgrUlp2vld0tdDV4l3PA',
#    'FNHn19CPilc-zYduEMr3nKVkpX5OAZycwOETS9mns3T8pP7cz0IFIgajrrfNciZAOP_nCB-eUzYeNA',
#    '_cxbUaGm1qKxwxWVUC9eHZcZ-R5aApS8RfZn6Q7P_ikmc0XdX5GsozAyG4eO90_LtyGHPxX4zi3nWw',
#    'MT3vX8ULOMBPg0MkftwUs761oLZ9RPHkm3LrGIMgFQlfQwDWeTr9G4Pmy4_a7JIkfdHJki8vzr_eBQ',
#    'X09KD3AyrD-de0CVEWpJ_NurtDXRu6d_kL0NuY-mQ3v9yfMN6yAPLNkHYhmCyTz0HttUNgybqOkGig',
#    'EeY3uFDpc4qpnLVpjpGTtedXoC9HzzXI45vLAltLxeKx-bukpwzscSdLhK4erf0cUV0qlY8LimpREg',
#    '5b7KW3VcT2OGVYG3H_fFdNw_sSosQh72VD-1-3o6mej_Id2ylhh9qAsk1Wzve59SukQxjyTdbmJ0AQ',
#    'A7e-bI-f26-pwWSf09y9AZmVvj_Vq3xe_7VqDxUvelDg4JpLYc0gbb1X70W26UheYnB6Oc0GUDRuYQ']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1722178842198,
#   'gameDuration': 1993,
#   'gameEndTimestamp': 1722180849755,
#   'gameId': 7188590273,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-7188590273',
#   'gameStartTimestamp': 1722178856795,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '14.14.603.4237',
#   'mapId': 11,
#   'participants': [{'allInPings': 1,
#     'assistMePings': 9,
#     'assists': 10,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 363,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 14,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7792911160266691,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 1080.937236691961,
#      'damageTakenOnTeamPercentage': 0.16676117432207022,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1534.5345089030002,
#      'earliestDragonTakedown': 814.2745124600001,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 822.080782276,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1993.215359773,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 482.5339506418338,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 6,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.6428571428571429,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 5,
#      'laneMinionsFirst10Minutes': 93,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3078, 3004, 3042, 6675, 3036],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 83,
#      'maxKillDeficit': 4,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 12,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 16,
#      'skillshotsHit': 44,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 6,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 18,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.2511556905876511,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.48219096660614014,
#      'visionScorePerMinute': 0.9951447628639504,
#      'voidMonsterKill': 2,
#      'wardTakedowns': 7,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 20228,
#     'champLevel': 18,
#     'championId': 42,
#     'championName': 'Corki',
#     'championTransform': 0,
#     'commandPings': 61,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 6199,
#     'damageDealtToObjectives': 22699,
#     'damageDealtToTurrets': 6199,
#     'damageSelfMitigated': 14416,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 30,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 17,
#     'goldEarned': 16029,
#     'goldSpent': 15283,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3036,
#     'item1': 3042,
#     'item2': 2055,
#     'item3': 6675,
#     'item4': 3078,
#     'item5': 3111,
#     'item6': 3363,
#     'itemsPurchased': 26,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 644,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 980,
#     'magicDamageDealt': 73154,
#     'magicDamageDealtToChampions': 5547,
#     'magicDamageTaken': 10074,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 2,
#     'neutralMinionsKilled': 28,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 63,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2990, 'var2': 2842, 'var3': 0},
#         {'perk': 9101, 'var1': 2203, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 14, 'var2': 10, 'var3': 0},
#         {'perk': 8017, 'var1': 1564, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8316, 'var1': 11, 'var2': 25, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 182085,
#     'physicalDamageDealtToChampions': 25177,
#     'physicalDamageTaken': 12115,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6335,
#     'pushPings': 0,
#     'puuid': 'PNXS-TH8OkdRyLXONcMZtNDIfJ0hEYta8GUCaEKp_tKGpoDF4zBsfViA_YsK8GA0qevrcdyDW2HJFA',
#     'quadraKills': 0,
#     'riotIdGameName': '아이유',
#     'riotIdTagline': '1128',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 107,
#     'spell2Casts': 49,
#     'spell3Casts': 86,
#     'spell4Casts': 121,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 12,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'A3VYN1IIYUgqOkQm5JHNoNMleeOnDwFJ4eX3zTerYcNI_-o',
#     'summonerLevel': 537,
#     'summonerName': 'dlwlrma22',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 2,
#     'timePlayed': 1993,
#     'totalAllyJungleMinionsKilled': 22,
#     'totalDamageDealt': 280007,
#     'totalDamageDealtToChampions': 35909,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23363,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 7946,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 298,
#     'totalTimeCCDealt': 85,
#     'totalTimeSpentDead': 85,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 24767,
#     'trueDamageDealtToChampions': 5184,
#     'trueDamageTaken': 1173,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 33,
#     'visionWardsBoughtInGame': 5,
#     'wardsKilled': 7,
#     'wardsPlaced': 15,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 2,
#     'assists': 15,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 3,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 924,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 16,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.48941444209726387,
#      'controlWardsPlaced': 6,
#      'damagePerMinute': 1000.5355430971199,
#      'damageTakenOnTeamPercentage': 0.16737692854655264,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1534.5345089030002,
#      'earliestDragonTakedown': 1140.499855488,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 10,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 822.080782276,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1993.215359773,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 482.797961485504,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5.5,
#      'killAfterHiddenWithAlly': 5,
#      'killParticipation': 0.7857142857142857,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 104,
#      'laneMinionsFirst10Minutes': 66,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3087, 3085, 3031, 3036],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 30.000000029802322,
#      'maxKillDeficit': 4,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 15,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 1,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 3,
#      'skillshotsHit': 513,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.23247436276048913,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.16276371479034424,
#      'visionScorePerMinute': 1.46274622208246,
#      'voidMonsterKill': 2,
#      'wardTakedowns': 13,
#      'wardTakedownsBefore20M': 9,
#      'wardsGuarded': 0},
#     'champExperience': 18488,
#     'champLevel': 18,
#     'championId': 221,
#     'championName': 'Zeri',
#     'championTransform': 0,
#     'commandPings': 46,
#     'consumablesPurchased': 10,
#     'damageDealtToBuildings': 5495,
#     'damageDealtToObjectives': 23356,
#     'damageDealtToTurrets': 5495,
#     'damageSelfMitigated': 10894,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 0,
#     'dragonKills': 2,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 58,
#     'enemyVisionPings': 2,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 8,
#     'goldEarned': 16038,
#     'goldSpent': 14180,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 0,
#     'item1': 3036,
#     'item2': 3085,
#     'item3': 3006,
#     'item4': 3087,
#     'item5': 3031,
#     'item6': 3363,
#     'itemsPurchased': 29,
#     'killingSprees': 2,
#     'kills': 7,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 942,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 657,
#     'magicDamageDealt': 56817,
#     'magicDamageDealtToChampions': 10263,
#     'magicDamageTaken': 10263,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 38,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 14,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 3456, 'var2': 3256, 'var3': 0},
#         {'perk': 9101, 'var1': 1576, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 16, 'var2': 30, 'var3': 0},
#         {'perk': 8017, 'var1': 1646, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8313, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 189988,
#     'physicalDamageDealtToChampions': 20416,
#     'physicalDamageTaken': 12510,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3797,
#     'pushPings': 0,
#     'puuid': 'LQ2jrGzLI85VQ2kF1rtkUGLb1dek_25NcO5KNveWda8Mn7SsEGBJt3CMqztdRfFpkatAtKrCzfwAHA',
#     'quadraKills': 0,
#     'riotIdGameName': 'sad and bad',
#     'riotIdTagline': 'KR1',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 796,
#     'spell2Casts': 73,
#     'spell3Casts': 46,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 1,
#     'summonerId': 'p0dnYl0FKB6DXtwVEZwWBhlEv8LyT-PqpHbKEFqYZEeGlv8',
#     'summonerLevel': 396,
#     'summonerName': 'sad and bad',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 12,
#     'timePlayed': 1993,
#     'totalAllyJungleMinionsKilled': 20,
#     'totalDamageDealt': 294775,
#     'totalDamageDealtToChampions': 33238,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23450,
#     'totalEnemyJungleMinionsKilled': 5,
#     'totalHeal': 6541,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 284,
#     'totalTimeCCDealt': 171,
#     'totalTimeSpentDead': 94,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 47969,
#     'trueDamageDealtToChampions': 2558,
#     'trueDamageTaken': 676,
#     'turretKills': 4,
#     'turretTakedowns': 4,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 48,
#     'visionWardsBoughtInGame': 6,
#     'wardsKilled': 13,
#     'wardsPlaced': 15,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 11,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 597,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 2,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 500,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6404367562927967,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 1272.9980261836686,
#      'damageTakenOnTeamPercentage': 0.18215801321246577,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1534.5345089030002,
#      'earliestDragonTakedown': 1456.666154367,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 41,
#      'enemyJungleMonsterKills': 2,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 822.080782276,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1993.215359773,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 524.3156582721294,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 7,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 1,
#      'kda': 3.8,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.6785714285714286,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 4,
#      'landSkillShotsEarlyGame': 5,
#      'laneMinionsFirst10Minutes': 98,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6692, 3004, 3042, 6701, 6694, 3026],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 67,
#      'maxKillDeficit': 4,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 27,
#      'skillshotsHit': 26,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 4,
#      'stealthWardsPlaced': 3,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 1,
#      'takedowns': 19,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.2957810014588183,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 5,
#      'turretTakedowns': 6,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.2681320309638977,
#      'visionScorePerMinute': 1.0205352702878006,
#      'voidMonsterKill': 2,
#      'wardTakedowns': 7,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 1},
#     'champExperience': 21305,
#     'champLevel': 18,
#     'championId': 126,
#     'championName': 'Jayce',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 11659,
#     'damageDealtToObjectives': 22395,
#     'damageDealtToTurrets': 11659,
#     'damageSelfMitigated': 26334,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 4,
#     'enemyVisionPings': 3,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 17417,
#     'goldSpent': 16450,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6694,
#     'item1': 6692,
#     'item2': 3026,
#     'item3': 3042,
#     'item4': 6701,
#     'item5': 3158,
#     'item6': 3363,
#     'itemsPurchased': 28,
#     'killingSprees': 3,
#     'kills': 8,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 650,
#     'magicDamageDealt': 25604,
#     'magicDamageDealtToChampions': 7426,
#     'magicDamageTaken': 7040,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 9,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 10,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2800, 'var2': 3506, 'var3': 0},
#         {'perk': 9101, 'var1': 1983, 'var2': 0, 'var3': 0},
#         {'perk': 9105, 'var1': 15, 'var2': 30, 'var3': 0},
#         {'perk': 8017, 'var1': 1948, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8316, 'var1': 7, 'var2': 10, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 224843,
#     'physicalDamageDealtToChampions': 34425,
#     'physicalDamageTaken': 17257,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4533,
#     'pushPings': 0,
#     'puuid': '9MOT2cUzidG9slSLcCmeegX0L4dce13-sz_jAUrdlrstO5xbpM-NAvbZ2QdgrUlp2vld0tdDV4l3PA',
#     'quadraKills': 0,
#     'riotIdGameName': '젠지 한별',
#     'riotIdTagline': 'GEN',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 169,
#     'spell2Casts': 113,
#     'spell3Casts': 111,
#     'spell4Casts': 204,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 12,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'CZGqTYMzumUi6Bwm0NTCsA5cu-VerV4S3_hzJ6dqVV4LV7M',
#     'summonerLevel': 856,
#     'summonerName': '강하다 별',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 16,
#     'timePlayed': 1993,
#     'totalAllyJungleMinionsKilled': 2,
#     'totalDamageDealt': 259770,
#     'totalDamageDealtToChampions': 42289,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25521,
#     'totalEnemyJungleMinionsKilled': 5,
#     'totalHeal': 6435,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 290,
#     'totalTimeCCDealt': 180,
#     'totalTimeSpentDead': 234,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 9322,
#     'trueDamageDealtToChampions': 437,
#     'trueDamageTaken': 1223,
#     'turretKills': 5,
#     'turretTakedowns': 6,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 33,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 7,
#     'wardsPlaced': 13,
#     'win': True},
#    {'allInPings': 1,
#     'assistMePings': 15,
#     'assists': 20,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 206,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.8339002052960777,
#      'controlWardsPlaced': 22,
#      'damagePerMinute': 236.0028089898412,
#      'damageTakenOnTeamPercentage': 0.18306180714231962,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1534.5345089030002,
#      'earliestDragonTakedown': 814.2745124600001,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 74,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 822.080782276,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1993.215359773,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 265.07920421926855,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 11,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.75,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 6,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 15,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3869, 3083],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 4,
#      'maxKillDeficit': 4,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 14,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 9,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 45,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 21,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.054835235997481385,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 1,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.018286287784576416,
#      'visionScorePerMinute': 3.631934484451346,
#      'voidMonsterKill': 3,
#      'wardTakedowns': 9,
#      'wardTakedownsBefore20M': 4,
#      'wardsGuarded': 2},
#     'champExperience': 11847,
#     'champLevel': 14,
#     'championId': 526,
#     'championName': 'Rell',
#     'championTransform': 0,
#     'commandPings': 22,
#     'consumablesPurchased': 24,
#     'damageDealtToBuildings': 451,
#     'damageDealtToObjectives': 877,
#     'damageDealtToTurrets': 451,
#     'damageSelfMitigated': 27612,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 22,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 17,
#     'enemyVisionPings': 16,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 15,
#     'goldEarned': 8805,
#     'goldSpent': 7600,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 1029,
#     'item1': 0,
#     'item2': 3869,
#     'item3': 3083,
#     'item4': 3067,
#     'item5': 3111,
#     'item6': 3364,
#     'itemsPurchased': 40,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 464,
#     'magicDamageDealt': 7122,
#     'magicDamageDealtToChampions': 5639,
#     'magicDamageTaken': 11157,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 38,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5010, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8439, 'var1': 951, 'var2': 745, 'var3': 0},
#         {'perk': 8401, 'var1': 461, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 809, 'var2': 0, 'var3': 0},
#         {'perk': 8451, 'var1': 200, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8306, 'var1': 10, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 3447,
#     'physicalDamageDealtToChampions': 1144,
#     'physicalDamageTaken': 13459,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3898,
#     'pushPings': 0,
#     'puuid': 'FNHn19CPilc-zYduEMr3nKVkpX5OAZycwOETS9mns3T8pP7cz0IFIgajrrfNciZAOP_nCB-eUzYeNA',
#     'quadraKills': 0,
#     'riotIdGameName': 'Anami',
#     'riotIdTagline': 'KR0',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 59,
#     'spell2Casts': 46,
#     'spell3Casts': 92,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 8,
#     'summoner1Id': 14,
#     'summoner2Casts': 15,
#     'summoner2Id': 4,
#     'summonerId': 'Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s',
#     'summonerLevel': 702,
#     'summonerName': 'wway',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 52,
#     'timePlayed': 1993,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 14439,
#     'totalDamageDealtToChampions': 7840,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25647,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 593,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 27,
#     'totalTimeCCDealt': 91,
#     'totalTimeSpentDead': 139,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 3870,
#     'trueDamageDealtToChampions': 1056,
#     'trueDamageTaken': 1030,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 120,
#     'visionWardsBoughtInGame': 22,
#     'wardsKilled': 9,
#     'wardsPlaced': 67,
#     'win': True},
#    {'allInPings': 2,
#     'assistMePings': 7,
#     'assists': 13,
#     'baronKills': 2,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 1314,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 66,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 2,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 2,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5322938305160516,
#      'controlWardsPlaced': 7,
#      'damagePerMinute': 713.379641011013,
#      'damageTakenOnTeamPercentage': 0.3006420767765917,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 2,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestBaron': 1534.5345089030002,
#      'earliestDragonTakedown': 814.2745124600001,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 6674.14404296875,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 35,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 822.080782276,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 9,
#      'gameLength': 1993.215359773,
#      'goldPerMinute': 404.03894976843685,
#      'hadOpenNexus': 0,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 85.75000014901161,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 8.5,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.6071428571428571,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 2,
#      'killsOnLanersEarlyJungleAsJungler': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 0,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6653, 4628, 3165],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 53.200000047683716,
#      'maxKillDeficit': 4,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -10.999999940395355,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 12,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 1,
#      'scuttleCrabKills': 3,
#      'skillshotsDodged': 9,
#      'skillshotsHit': 20,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 2,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 6,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 17,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 2,
#      'teamDamagePercentage': 0.16575370919556004,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 4,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 1,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.744604229927063,
#      'visionScorePerMinute': 1.4529713940354985,
#      'voidMonsterKill': 9,
#      'wardTakedowns': 15,
#      'wardTakedownsBefore20M': 6,
#      'wardsGuarded': 1},
#     'champExperience': 16723,
#     'champLevel': 17,
#     'championId': 76,
#     'championName': 'Nidalee',
#     'championTransform': 0,
#     'commandPings': 3,
#     'consumablesPurchased': 10,
#     'damageDealtToBuildings': 921,
#     'damageDealtToObjectives': 41678,
#     'damageDealtToTurrets': 921,
#     'damageSelfMitigated': 27318,
#     'dangerPings': 0,
#     'deaths': 2,
#     'detectorWardsPlaced': 7,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 11,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 9,
#     'goldEarned': 13422,
#     'goldSpent': 12190,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 2055,
#     'item1': 3165,
#     'item2': 1082,
#     'item3': 6653,
#     'item4': 4628,
#     'item5': 3111,
#     'item6': 3364,
#     'itemsPurchased': 26,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 1295,
#     'magicDamageDealt': 170094,
#     'magicDamageDealtToChampions': 18285,
#     'magicDamageTaken': 13365,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 200,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 34,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 55, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 1635, 'var2': 340, 'var3': 0},
#         {'perk': 9105, 'var1': 11, 'var2': 0, 'var3': 0},
#         {'perk': 8017, 'var1': 1084, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8210, 'var1': 12, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 6, 'var2': 50, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 24102,
#     'physicalDamageDealtToChampions': 1224,
#     'physicalDamageTaken': 27650,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4568,
#     'pushPings': 0,
#     'puuid': '_cxbUaGm1qKxwxWVUC9eHZcZ-R5aApS8RfZn6Q7P_ikmc0XdX5GsozAyG4eO90_LtyGHPxX4zi3nWw',
#     'quadraKills': 0,
#     'riotIdGameName': 'HamBak',
#     'riotIdTagline': 'KR0',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 336,
#     'spell2Casts': 362,
#     'spell3Casts': 223,
#     'spell4Casts': 393,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 16,
#     'summoner2Id': 11,
#     'summonerId': 'mgbmIw1zBafdMlezogAxuUtw-_noT4AQFkF3Yq_yTFGD1-c',
#     'summonerLevel': 428,
#     'summonerName': 'hhhhbbbb',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 13,
#     'timePlayed': 1993,
#     'totalAllyJungleMinionsKilled': 107,
#     'totalDamageDealt': 280705,
#     'totalDamageDealtToChampions': 23698,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 42121,
#     'totalEnemyJungleMinionsKilled': 41,
#     'totalHeal': 36585,
#     'totalHealsOnTeammates': 6674,
#     'totalMinionsKilled': 25,
#     'totalTimeCCDealt': 292,
#     'totalTimeSpentDead': 93,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 86508,
#     'trueDamageDealtToChampions': 4188,
#     'trueDamageTaken': 1104,
#     'turretKills': 0,
#     'turretTakedowns': 4,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 48,
#     'visionWardsBoughtInGame': 8,
#     'wardsKilled': 15,
#     'wardsPlaced': 9,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 7,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 197,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 11,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6705777221545298,
#      'controlWardsPlaced': 5,
#      'damagePerMinute': 1140.7054583825502,
#      'damageTakenOnTeamPercentage': 0.13576252296725302,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 30,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 1771.0560944130002,
#      'earlyLaningPhaseGoldExpAdvantage': 1,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 1,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1993.215359773,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
# ...
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 40,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 1,
#      'survivedSingleDigitHpCount': 1,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 10,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.24303652835342918,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.32532310485839844,
#      'visionScorePerMinute': 0.6714011810338714,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 10,
#      'wardTakedownsBefore20M': 7,
#      'wardsGuarded': 1},
#     'champExperience': 16609,
#     'champLevel': 17,
#     'championId': 55,
#     'championName': 'Katarina',
#     'championTransform': 0,
#     'commandPings': 26,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 8066,
#     'damageDealtToObjectives': 14081,
#     'damageDealtToTurrets': 8066,
#     'damageSelfMitigated': 17982,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 11,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 8,
#     'goldEarned': 15779,
#     'goldSpent': 15775,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3026,
#     'item1': 2019,
#     'item2': 6672,
#     'item3': 3047,
#     'item4': 3087,
#     'item5': 3153,
#     'item6': 3364,
#     'itemsPurchased': 26,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 1039,
#     'magicDamageDealt': 112189,
#     'magicDamageDealtToChampions': 10916,
#     'magicDamageTaken': 6225,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 20,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 893, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 941, 'var2': 200, 'var3': 0},
#         {'perk': 9104, 'var1': 19, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 692, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8143, 'var1': 960, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 76418,
#     'physicalDamageDealtToChampions': 11009,
#     'physicalDamageTaken': 17965,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4933,
#     'pushPings': 0,
#     'puuid': '5b7KW3VcT2OGVYG3H_fFdNw_sSosQh72VD-1-3o6mej_Id2ylhh9qAsk1Wzve59SukQxjyTdbmJ0AQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'DK ShowMaker',
#     'riotIdTagline': 'KR1',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 82,
#     'spell2Casts': 75,
#     'spell3Casts': 0,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 14,
#     'summoner2Casts': 4,
#     'summoner2Id': 12,
#     'summonerId': 'NvWvJxh4_K3dNNr75V1eiAqFQxB9uYN7XZq0tO9F5RaNdgQ',
#     'summonerLevel': 496,
#     'summonerName': 'DK ShowMaker',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 4,
#     'timePlayed': 1993,
#     'totalAllyJungleMinionsKilled': 4,
#     'totalDamageDealt': 195045,
#     'totalDamageDealtToChampions': 24746,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 26194,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 7850,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 239,
#     'totalTimeCCDealt': 90,
#     'totalTimeSpentDead': 91,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 6438,
#     'trueDamageDealtToChampions': 2821,
#     'trueDamageTaken': 2003,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 9,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 22,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 8,
#     'wardsPlaced': 4,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 6,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 215,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 1,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.24943508614273463,
#      'controlWardsPlaced': 5,
#      'damagePerMinute': 466.74062854387194,
#      'damageTakenOnTeamPercentage': 0.22064380777892648,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 18,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1993.215359773,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 336.6289355306617,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.6666666666666666,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.2857142857142857,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 11,
#      'laneMinionsFirst10Minutes': 63,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3078, 3143, 3053],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 6,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 47,
#      'skillshotsHit': 46,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 8,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 7,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 6,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 0,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.15227550343929205,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.36636674404144287,
#      'visionScorePerMinute': 1.394425428676032,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 9,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 1},
#     'champExperience': 15889,
#     'champLevel': 16,
#     'championId': 150,
#     'championName': 'Gnar',
#     'championTransform': 0,
#     'commandPings': 6,
#     'consumablesPurchased': 7,
#     'damageDealtToBuildings': 748,
#     'damageDealtToObjectives': 748,
#     'damageDealtToTurrets': 748,
#     'damageSelfMitigated': 41978,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 5,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 7,
#     'enemyVisionPings': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11182,
#     'goldSpent': 11258,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 3053,
#     'item1': 3143,
#     'item2': 0,
#     'item3': 3078,
#     'item4': 3047,
#     'item5': 0,
#     'item6': 3363,
#     'itemsPurchased': 27,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'TOP',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 368,
#     'magicDamageDealt': 14535,
#     'magicDamageDealtToChampions': 1274,
#     'magicDamageTaken': 11057,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 1,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 1839, 'var2': 1754, 'var3': 0},
#         {'perk': 9101, 'var1': 1908, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 21, 'var2': 30, 'var3': 0},
#         {'perk': 8017, 'var1': 942, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8451, 'var1': 228, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 1435, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 148562,
#     'physicalDamageDealtToChampions': 13832,
#     'physicalDamageTaken': 25141,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6651,
#     'pushPings': 0,
#     'puuid': 'A7e-bI-f26-pwWSf09y9AZmVvj_Vq3xe_7VqDxUvelDg4JpLYc0gbb1X70W26UheYnB6Oc0GUDRuYQ',
#     'quadraKills': 0,
#     'riotIdGameName': '天下 第一',
#     'riotIdTagline': 'CN1',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 142,
#     'spell2Casts': 29,
#     'spell3Casts': 38,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 12,
#     'summonerId': 'bYUnZu8QojtutWt1Pk5eERcw_CMOsdS1JC5yGpGc5UfuuWXCFmj0LKqiZA',
#     'summonerLevel': 120,
#     'summonerName': '4238963482364387',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 27,
#     'timePlayed': 1993,
#     'totalAllyJungleMinionsKilled': 4,
#     'totalDamageDealt': 165666,
#     'totalDamageDealtToChampions': 15505,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 38147,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 4310,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 246,
#     'totalTimeCCDealt': 573,
#     'totalTimeSpentDead': 271,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2568,
#     'trueDamageDealtToChampions': 398,
#     'trueDamageTaken': 1947,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 9,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 46,
#     'visionWardsBoughtInGame': 5,
#     'wardsKilled': 9,
#     'wardsPlaced': 16,
#     'win': False}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 81, 'pickTurn': 1},
#      {'championId': -1, 'pickTurn': 2},
#      {'championId': -1, 'pickTurn': 3},
#      {'championId': 133, 'pickTurn': 4},
#      {'championId': -1, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 2},
#      'champion': {'first': False, 'kills': 28},
#      'dragon': {'first': False, 'kills': 3},
#      'horde': {'first': True, 'kills': 6},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': True, 'kills': 1},
#      'tower': {'first': True, 'kills': 9}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 30, 'pickTurn': 6},
#      {'championId': -1, 'pickTurn': 7},
#      {'championId': 81, 'pickTurn': 8},
#      {'championId': 166, 'pickTurn': 9},
#      {'championId': -1, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 21},
#      'dragon': {'first': True, 'kills': 2},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 5}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
temp_match_data['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_7188590273',
#  'participants': ['PNXS-TH8OkdRyLXONcMZtNDIfJ0hEYta8GUCaEKp_tKGpoDF4zBsfViA_YsK8GA0qevrcdyDW2HJFA',
#   'LQ2jrGzLI85VQ2kF1rtkUGLb1dek_25NcO5KNveWda8Mn7SsEGBJt3CMqztdRfFpkatAtKrCzfwAHA',
#   '9MOT2cUzidG9slSLcCmeegX0L4dce13-sz_jAUrdlrstO5xbpM-NAvbZ2QdgrUlp2vld0tdDV4l3PA',
#   'FNHn19CPilc-zYduEMr3nKVkpX5OAZycwOETS9mns3T8pP7cz0IFIgajrrfNciZAOP_nCB-eUzYeNA',
#   '_cxbUaGm1qKxwxWVUC9eHZcZ-R5aApS8RfZn6Q7P_ikmc0XdX5GsozAyG4eO90_LtyGHPxX4zi3nWw',
#   'MT3vX8ULOMBPg0MkftwUs761oLZ9RPHkm3LrGIMgFQlfQwDWeTr9G4Pmy4_a7JIkfdHJki8vzr_eBQ',
#   'X09KD3AyrD-de0CVEWpJ_NurtDXRu6d_kL0NuY-mQ3v9yfMN6yAPLNkHYhmCyTz0HttUNgybqOkGig',
#   'EeY3uFDpc4qpnLVpjpGTtedXoC9HzzXI45vLAltLxeKx-bukpwzscSdLhK4erf0cUV0qlY8LimpREg',
#   '5b7KW3VcT2OGVYG3H_fFdNw_sSosQh72VD-1-3o6mej_Id2ylhh9qAsk1Wzve59SukQxjyTdbmJ0AQ',
#   'A7e-bI-f26-pwWSf09y9AZmVvj_Vq3xe_7VqDxUvelDg4JpLYc0gbb1X70W26UheYnB6Oc0GUDRuYQ']}

# %%
temp_match_data['info']
# Out:
# {'endOfGameResult': 'GameComplete',
#  'gameCreation': 1722178842198,
#  'gameDuration': 1993,
#  'gameEndTimestamp': 1722180849755,
#  'gameId': 7188590273,
#  'gameMode': 'CLASSIC',
#  'gameName': 'teambuilder-match-7188590273',
#  'gameStartTimestamp': 1722178856795,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '14.14.603.4237',
#  'mapId': 11,
#  'participants': [{'allInPings': 1,
#    'assistMePings': 9,
#    'assists': 10,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 4,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 363,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 14,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 2,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7792911160266691,
#     'controlWardsPlaced': 4,
#     'damagePerMinute': 1080.937236691961,
#     'damageTakenOnTeamPercentage': 0.16676117432207022,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 3,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestBaron': 1534.5345089030002,
#     'earliestDragonTakedown': 814.2745124600001,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 0,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 822.080782276,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 9,
#     'gameLength': 1993.215359773,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 482.5339506418338,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 0,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 6,
#     'killAfterHiddenWithAlly': 1,
#     'killParticipation': 0.6428571428571429,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 2,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 1,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 5,
#     'laneMinionsFirst10Minutes': 93,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3078, 3004, 3042, 6675, 3036],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 83,
#     'maxKillDeficit': 4,
#     'maxLevelLeadLaneOpponent': 2,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 12,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 1,
#     'skillshotsDodged': 16,
#     'skillshotsHit': 44,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 6,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 18,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 4,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 2,
#     'teamDamagePercentage': 0.2511556905876511,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 1,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.48219096660614014,
#     'visionScorePerMinute': 0.9951447628639504,
#     'voidMonsterKill': 2,
#     'wardTakedowns': 7,
#     'wardTakedownsBefore20M': 1,
#     'wardsGuarded': 0},
#    'champExperience': 20228,
#    'champLevel': 18,
#    'championId': 42,
#    'championName': 'Corki',
#    'championTransform': 0,
#    'commandPings': 61,
#    'consumablesPurchased': 6,
#    'damageDealtToBuildings': 6199,
#    'damageDealtToObjectives': 22699,
#    'damageDealtToTurrets': 6199,
#    'damageSelfMitigated': 14416,
#    'dangerPings': 0,
#    'deaths': 3,
#    'detectorWardsPlaced': 4,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 30,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 17,
#    'goldEarned': 16029,
#    'goldSpent': 15283,
#    'holdPings': 0,
#    'individualPosition': 'MIDDLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 3036,
#    'item1': 3042,
#    'item2': 2055,
#    'item3': 6675,
#    'item4': 3078,
#    'item5': 3111,
#    'item6': 3363,
#    'itemsPurchased': 26,
#    'killingSprees': 2,
#    'kills': 8,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 644,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 980,
#    'magicDamageDealt': 73154,
#    'magicDamageDealtToChampions': 5547,
#    'magicDamageTaken': 10074,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 2,
#    'neutralMinionsKilled': 28,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 63,
#    'participantId': 1,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 2990, 'var2': 2842, 'var3': 0},
#        {'perk': 9101, 'var1': 2203, 'var2': 0, 'var3': 0},
#        {'perk': 9104, 'var1': 14, 'var2': 10, 'var3': 0},
#        {'perk': 8017, 'var1': 1564, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8316, 'var1': 11, 'var2': 25, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 182085,
#    'physicalDamageDealtToChampions': 25177,
#    'physicalDamageTaken': 12115,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6335,
#    'pushPings': 0,
#    'puuid': 'PNXS-TH8OkdRyLXONcMZtNDIfJ0hEYta8GUCaEKp_tKGpoDF4zBsfViA_YsK8GA0qevrcdyDW2HJFA',
#    'quadraKills': 0,
#    'riotIdGameName': '아이유',
#    'riotIdTagline': '1128',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 107,
#    'spell2Casts': 49,
#    'spell3Casts': 86,
#    'spell4Casts': 121,
#    'subteamPlacement': 0,
#    'summoner1Casts': 4,
#    'summoner1Id': 12,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'A3VYN1IIYUgqOkQm5JHNoNMleeOnDwFJ4eX3zTerYcNI_-o',
#    'summonerLevel': 537,
#    'summonerName': 'dlwlrma22',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 2,
#    'timePlayed': 1993,
#    'totalAllyJungleMinionsKilled': 22,
#    'totalDamageDealt': 280007,
#    'totalDamageDealtToChampions': 35909,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 23363,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 7946,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 298,
#    'totalTimeCCDealt': 85,
#    'totalTimeSpentDead': 85,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 24767,
#    'trueDamageDealtToChampions': 5184,
#    'trueDamageTaken': 1173,
#    'turretKills': 0,
#    'turretTakedowns': 2,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 33,
#    'visionWardsBoughtInGame': 5,
#    'wardsKilled': 7,
#    'wardsPlaced': 15,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 2,
#    'assists': 15,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 3,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 924,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 16,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 2,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.48941444209726387,
#     'controlWardsPlaced': 6,
#     'damagePerMinute': 1000.5355430971199,
#     'damageTakenOnTeamPercentage': 0.16737692854655264,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 4,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 2,
#     'earliestBaron': 1534.5345089030002,
#     'earliestDragonTakedown': 1140.499855488,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 0,
#     'enemyJungleMonsterKills': 10,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 822.080782276,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 9,
#     'gameLength': 1993.215359773,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 482.797961485504,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 0,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 5.5,
#     'killAfterHiddenWithAlly': 5,
#     'killParticipation': 0.7857142857142857,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 2,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 1,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 104,
#     'laneMinionsFirst10Minutes': 66,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3087, 3085, 3031, 3036],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 30.000000029802322,
#     'maxKillDeficit': 4,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 15,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 1,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 1,
#     'skillshotsDodged': 3,
#     'skillshotsHit': 513,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'soloTurretsLategame': 1,
#     'stealthWardsPlaced': 4,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 4,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 22,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 4,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 2,
#     'teamDamagePercentage': 0.23247436276048913,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 1,
#     'turretTakedowns': 4,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.16276371479034424,
#     'visionScorePerMinute': 1.46274622208246,
#     'voidMonsterKill': 2,
#     'wardTakedowns': 13,
#     'wardTakedownsBefore20M': 9,
#     'wardsGuarded': 0},
#    'champExperience': 18488,
#    'champLevel': 18,
#    'championId': 221,
#    'championName': 'Zeri',
#    'championTransform': 0,
#    'commandPings': 46,
#    'consumablesPurchased': 10,
#    'damageDealtToBuildings': 5495,
#    'damageDealtToObjectives': 23356,
#    'damageDealtToTurrets': 5495,
#    'damageSelfMitigated': 10894,
#    'dangerPings': 0,
#    'deaths': 4,
#    'detectorWardsPlaced': 6,
#    'doubleKills': 0,
#    'dragonKills': 2,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 58,
#    'enemyVisionPings': 2,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 8,
#    'goldEarned': 16038,
#    'goldSpent': 14180,
#    'holdPings': 0,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 0,
#    'item1': 3036,
#    'item2': 3085,
#    'item3': 3006,
#    'item4': 3087,
#    'item5': 3031,
#    'item6': 3363,
#    'itemsPurchased': 29,
#    'killingSprees': 2,
#    'kills': 7,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 942,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 657,
#    'magicDamageDealt': 56817,
#    'magicDamageDealtToChampions': 10263,
#    'magicDamageTaken': 10263,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 38,
#    'nexusKills': 1,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 14,
#    'participantId': 2,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 3456, 'var2': 3256, 'var3': 0},
#        {'perk': 9101, 'var1': 1576, 'var2': 0, 'var3': 0},
#        {'perk': 9104, 'var1': 16, 'var2': 30, 'var3': 0},
#        {'perk': 8017, 'var1': 1646, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8313, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 189988,
#    'physicalDamageDealtToChampions': 20416,
#    'physicalDamageTaken': 12510,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 3797,
#    'pushPings': 0,
#    'puuid': 'LQ2jrGzLI85VQ2kF1rtkUGLb1dek_25NcO5KNveWda8Mn7SsEGBJt3CMqztdRfFpkatAtKrCzfwAHA',
#    'quadraKills': 0,
#    'riotIdGameName': 'sad and bad',
#    'riotIdTagline': 'KR1',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 796,
#    'spell2Casts': 73,
#    'spell3Casts': 46,
#    'spell4Casts': 9,
#    'subteamPlacement': 0,
#    'summoner1Casts': 4,
#    'summoner1Id': 4,
#    'summoner2Casts': 5,
#    'summoner2Id': 1,
#    'summonerId': 'p0dnYl0FKB6DXtwVEZwWBhlEv8LyT-PqpHbKEFqYZEeGlv8',
#    'summonerLevel': 396,
#    'summonerName': 'sad and bad',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 12,
#    'timePlayed': 1993,
#    'totalAllyJungleMinionsKilled': 20,
#    'totalDamageDealt': 294775,
#    'totalDamageDealtToChampions': 33238,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 23450,
#    'totalEnemyJungleMinionsKilled': 5,
#    'totalHeal': 6541,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 284,
#    'totalTimeCCDealt': 171,
#    'totalTimeSpentDead': 94,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 47969,
#    'trueDamageDealtToChampions': 2558,
#    'trueDamageTaken': 676,
#    'turretKills': 4,
#    'turretTakedowns': 4,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 48,
#    'visionWardsBoughtInGame': 6,
#    'wardsKilled': 13,
#    'wardsPlaced': 15,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 11,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 1,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 597,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 2,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 500,
#     'buffsStolen': 1,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6404367562927967,
#     'controlWardsPlaced': 2,
#     'damagePerMinute': 1272.9980261836686,
#     'damageTakenOnTeamPercentage': 0.18215801321246577,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 5,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestBaron': 1534.5345089030002,
#     'earliestDragonTakedown': 1456.666154367,
#     'earlyLaningPhaseGoldExpAdvantage': 1,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 41,
#     'enemyJungleMonsterKills': 2,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 822.080782276,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 9,
#     'gameLength': 1993.215359773,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 524.3156582721294,
#     'hadOpenNexus': 0,
#     'highestChampionDamage': 1,
#     'immobilizeAndKillWithAlly': 7,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 1,
#     'kda': 3.8,
#     'killAfterHiddenWithAlly': 1,
#     'killParticipation': 0.6785714285714286,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 3,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 4,
#     'landSkillShotsEarlyGame': 5,
#     'laneMinionsFirst10Minutes': 98,
#     'laningPhaseGoldExpAdvantage': 1,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [6692, 3004, 3042, 6701, 6694, 3026],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 67,
#     'maxKillDeficit': 4,
#     'maxLevelLeadLaneOpponent': 3,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 8,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 1,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 27,
#     'skillshotsHit': 26,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 4,
#     'stealthWardsPlaced': 3,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 1,
#     'takedownOnFirstTurret': 1,
#     'takedowns': 19,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 3,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 2,
#     'teamDamagePercentage': 0.2957810014588183,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 5,
#     'turretTakedowns': 6,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.2681320309638977,
#     'visionScorePerMinute': 1.0205352702878006,
#     'voidMonsterKill': 2,
#     'wardTakedowns': 7,
#     'wardTakedownsBefore20M': 2,
#     'wardsGuarded': 1},
#    'champExperience': 21305,
#    'champLevel': 18,
#    'championId': 126,
#    'championName': 'Jayce',
#    'championTransform': 0,
#    'commandPings': 1,
#    'consumablesPurchased': 5,
#    'damageDealtToBuildings': 11659,
#    'damageDealtToObjectives': 22395,
#    'damageDealtToTurrets': 11659,
#    'damageSelfMitigated': 26334,
#    'dangerPings': 0,
#    'deaths': 5,
#    'detectorWardsPlaced': 2,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 4,
#    'enemyVisionPings': 3,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 17417,
#    'goldSpent': 16450,
#    'holdPings': 0,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 1,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 6694,
#    'item1': 6692,
#    'item2': 3026,
#    'item3': 3042,
#    'item4': 6701,
#    'item5': 3158,
#    'item6': 3363,
#    'itemsPurchased': 28,
#    'killingSprees': 3,
#    'kills': 8,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 650,
#    'magicDamageDealt': 25604,
#    'magicDamageDealtToChampions': 7426,
#    'magicDamageTaken': 7040,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 9,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 10,
#    'participantId': 3,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 2800, 'var2': 3506, 'var3': 0},
#        {'perk': 9101, 'var1': 1983, 'var2': 0, 'var3': 0},
#        {'perk': 9105, 'var1': 15, 'var2': 30, 'var3': 0},
#        {'perk': 8017, 'var1': 1948, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8316, 'var1': 7, 'var2': 10, 'var3': 0},
#        {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 224843,
#    'physicalDamageDealtToChampions': 34425,
#    'physicalDamageTaken': 17257,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4533,
#    'pushPings': 0,
#    'puuid': '9MOT2cUzidG9slSLcCmeegX0L4dce13-sz_jAUrdlrstO5xbpM-NAvbZ2QdgrUlp2vld0tdDV4l3PA',
#    'quadraKills': 0,
#    'riotIdGameName': '젠지 한별',
#    'riotIdTagline': 'GEN',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 169,
#    'spell2Casts': 113,
#    'spell3Casts': 111,
#    'spell4Casts': 204,
#    'subteamPlacement': 0,
#    'summoner1Casts': 4,
#    'summoner1Id': 12,
#    'summoner2Casts': 5,
#    'summoner2Id': 4,
#    'summonerId': 'CZGqTYMzumUi6Bwm0NTCsA5cu-VerV4S3_hzJ6dqVV4LV7M',
#    'summonerLevel': 856,
#    'summonerName': '강하다 별',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 16,
#    'timePlayed': 1993,
#    'totalAllyJungleMinionsKilled': 2,
#    'totalDamageDealt': 259770,
#    'totalDamageDealtToChampions': 42289,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 25521,
#    'totalEnemyJungleMinionsKilled': 5,
#    'totalHeal': 6435,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 290,
#    'totalTimeCCDealt': 180,
#    'totalTimeSpentDead': 234,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 9322,
#    'trueDamageDealtToChampions': 437,
#    'trueDamageTaken': 1223,
#    'turretKills': 5,
#    'turretTakedowns': 6,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 33,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 7,
#    'wardsPlaced': 13,
#    'win': True},
#   {'allInPings': 1,
#    'assistMePings': 15,
#    'assists': 20,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 1,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 206,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 2,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.8339002052960777,
#     'controlWardsPlaced': 22,
#     'damagePerMinute': 236.0028089898412,
#     'damageTakenOnTeamPercentage': 0.18306180714231962,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 7,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestBaron': 1534.5345089030002,
#     'earliestDragonTakedown': 814.2745124600001,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 74,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 822.080782276,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 9,
#     'gameLength': 1993.215359773,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 265.07920421926855,
#     'hadOpenNexus': 0,
#     'highestCrowdControlScore': 1,
#     'immobilizeAndKillWithAlly': 11,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3,
#     'killAfterHiddenWithAlly': 3,
#     'killParticipation': 0.75,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 6,
#     'landSkillShotsEarlyGame': 0,
#     'laneMinionsFirst10Minutes': 15,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3869, 3083],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 4,
#     'maxKillDeficit': 4,
#     'maxLevelLeadLaneOpponent': 3,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 14,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 1,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 9,
#     'skillshotsHit': 0,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 45,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 21,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 3,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 2,
#     'teamDamagePercentage': 0.054835235997481385,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 1,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.018286287784576416,
#     'visionScorePerMinute': 3.631934484451346,
#     'voidMonsterKill': 3,
#     'wardTakedowns': 9,
#     'wardTakedownsBefore20M': 4,
#     'wardsGuarded': 2},
#    'champExperience': 11847,
#    'champLevel': 14,
#    'championId': 526,
#    'championName': 'Rell',
#    'championTransform': 0,
#    'commandPings': 22,
#    'consumablesPurchased': 24,
#    'damageDealtToBuildings': 451,
#    'damageDealtToObjectives': 877,
#    'damageDealtToTurrets': 451,
#    'damageSelfMitigated': 27612,
#    'dangerPings': 0,
#    'deaths': 7,
#    'detectorWardsPlaced': 22,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 17,
#    'enemyVisionPings': 16,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 15,
#    'goldEarned': 8805,
#    'goldSpent': 7600,
#    'holdPings': 0,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 1029,
#    'item1': 0,
#    'item2': 3869,
#    'item3': 3083,
#    'item4': 3067,
#    'item5': 3111,
#    'item6': 3364,
#    'itemsPurchased': 40,
#    'killingSprees': 0,
#    'kills': 1,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 464,
#    'magicDamageDealt': 7122,
#    'magicDamageDealtToChampions': 5639,
#    'magicDamageTaken': 11157,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 38,
#    'participantId': 4,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5010, 'offense': 5007},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8439, 'var1': 951, 'var2': 745, 'var3': 0},
#        {'perk': 8401, 'var1': 461, 'var2': 0, 'var3': 0},
#        {'perk': 8473, 'var1': 809, 'var2': 0, 'var3': 0},
#        {'perk': 8451, 'var1': 200, 'var2': 0, 'var3': 0}],
#       'style': 8400},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8306, 'var1': 10, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 3447,
#    'physicalDamageDealtToChampions': 1144,
#    'physicalDamageTaken': 13459,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 3898,
#    'pushPings': 0,
#    'puuid': 'FNHn19CPilc-zYduEMr3nKVkpX5OAZycwOETS9mns3T8pP7cz0IFIgajrrfNciZAOP_nCB-eUzYeNA',
#    'quadraKills': 0,
#    'riotIdGameName': 'Anami',
#    'riotIdTagline': 'KR0',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 59,
#    'spell2Casts': 46,
#    'spell3Casts': 92,
#    'spell4Casts': 9,
#    'subteamPlacement': 0,
#    'summoner1Casts': 8,
#    'summoner1Id': 14,
#    'summoner2Casts': 15,
#    'summoner2Id': 4,
#    'summonerId': 'Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s',
#    'summonerLevel': 702,
#    'summonerName': 'wway',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'UTILITY',
#    'timeCCingOthers': 52,
#    'timePlayed': 1993,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 14439,
#    'totalDamageDealtToChampions': 7840,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 25647,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 593,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 27,
#    'totalTimeCCDealt': 91,
#    'totalTimeSpentDead': 139,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 3870,
#    'trueDamageDealtToChampions': 1056,
#    'trueDamageTaken': 1030,
#    'turretKills': 0,
#    'turretTakedowns': 1,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 120,
#    'visionWardsBoughtInGame': 22,
#    'wardsKilled': 9,
#    'wardsPlaced': 67,
#    'win': True},
#   {'allInPings': 2,
#    'assistMePings': 7,
#    'assists': 13,
#    'baronKills': 2,
#    'basicPings': 0,
#    'bountyLevel': 1,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 1314,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 66,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 2,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 2,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5322938305160516,
#     'controlWardsPlaced': 7,
#     'damagePerMinute': 713.379641011013,
#     'damageTakenOnTeamPercentage': 0.3006420767765917,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 2,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 2,
#     'earliestBaron': 1534.5345089030002,
#     'earliestDragonTakedown': 814.2745124600001,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 6674.14404296875,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 0,
#     'enemyJungleMonsterKills': 35,
#     'epicMonsterKillsNearEnemyJungler': 1,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 822.080782276,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 9,
#     'gameLength': 1993.215359773,
#     'goldPerMinute': 404.03894976843685,
#     'hadOpenNexus': 0,
#     'highestWardKills': 1,
#     'immobilizeAndKillWithAlly': 0,
#     'initialBuffCount': 2,
#     'initialCrabCount': 1,
#     'jungleCsBefore10Minutes': 85.75000014901161,
#     'junglerKillsEarlyJungle': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 8.5,
#     'killAfterHiddenWithAlly': 4,
#     'killParticipation': 0.6071428571428571,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 2,
#     'killsOnLanersEarlyJungleAsJungler': 1,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 0,
#     'laneMinionsFirst10Minutes': 0,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [6653, 4628, 3165],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 53.200000047683716,
#     'maxKillDeficit': 4,
#     'maxLevelLeadLaneOpponent': 2,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': -10.999999940395355,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 12,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 1,
#     'saveAllyFromDeath': 1,
#     'scuttleCrabKills': 3,
#     'skillshotsDodged': 9,
#     'skillshotsHit': 20,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 2,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 6,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 17,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 2,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 2,
#     'teamDamagePercentage': 0.16575370919556004,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 4,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 1,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.744604229927063,
#     'visionScorePerMinute': 1.4529713940354985,
#     'voidMonsterKill': 9,
#     'wardTakedowns': 15,
#     'wardTakedownsBefore20M': 6,
#     'wardsGuarded': 1},
#    'champExperience': 16723,
#    'champLevel': 17,
#    'championId': 76,
#    'championName': 'Nidalee',
#    'championTransform': 0,
#    'commandPings': 3,
#    'consumablesPurchased': 10,
#    'damageDealtToBuildings': 921,
#    'damageDealtToObjectives': 41678,
#    'damageDealtToTurrets': 921,
#    'damageSelfMitigated': 27318,
#    'dangerPings': 0,
#    'deaths': 2,
#    'detectorWardsPlaced': 7,
#    'doubleKills': 0,
#    'dragonKills': 1,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 11,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 9,
#    'goldEarned': 13422,
#    'goldSpent': 12190,
#    'holdPings': 0,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 2055,
#    'item1': 3165,
#    'item2': 1082,
#    'item3': 6653,
#    'item4': 4628,
#    'item5': 3111,
#    'item6': 3364,
#    'itemsPurchased': 26,
#    'killingSprees': 1,
#    'kills': 4,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 1295,
#    'magicDamageDealt': 170094,
#    'magicDamageDealtToChampions': 18285,
#    'magicDamageTaken': 13365,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 200,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 34,
#    'participantId': 5,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 55, 'var2': 0, 'var3': 0},
#        {'perk': 9111, 'var1': 1635, 'var2': 340, 'var3': 0},
#        {'perk': 9105, 'var1': 11, 'var2': 0, 'var3': 0},
#        {'perk': 8017, 'var1': 1084, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8210, 'var1': 12, 'var2': 0, 'var3': 0},
#        {'perk': 8232, 'var1': 6, 'var2': 50, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 24102,
#    'physicalDamageDealtToChampions': 1224,
#    'physicalDamageTaken': 27650,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4568,
#    'pushPings': 0,
#    'puuid': '_cxbUaGm1qKxwxWVUC9eHZcZ-R5aApS8RfZn6Q7P_ikmc0XdX5GsozAyG4eO90_LtyGHPxX4zi3nWw',
#    'quadraKills': 0,
#    'riotIdGameName': 'HamBak',
#    'riotIdTagline': 'KR0',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 336,
#    'spell2Casts': 362,
#    'spell3Casts': 223,
#    'spell4Casts': 393,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 16,
#    'summoner2Id': 11,
#    'summonerId': 'mgbmIw1zBafdMlezogAxuUtw-_noT4AQFkF3Yq_yTFGD1-c',
#    'summonerLevel': 428,
#    'summonerName': 'hhhhbbbb',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'JUNGLE',
#    'timeCCingOthers': 13,
#    'timePlayed': 1993,
#    'totalAllyJungleMinionsKilled': 107,
#    'totalDamageDealt': 280705,
#    'totalDamageDealtToChampions': 23698,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 42121,
#    'totalEnemyJungleMinionsKilled': 41,
#    'totalHeal': 36585,
#    'totalHealsOnTeammates': 6674,
#    'totalMinionsKilled': 25,
#    'totalTimeCCDealt': 292,
#    'totalTimeSpentDead': 93,
#    'totalUnitsHealed': 5,
#    'tripleKills': 0,
#    'trueDamageDealt': 86508,
#    'trueDamageDealtToChampions': 4188,
#    'trueDamageTaken': 1104,
#    'turretKills': 0,
#    'turretTakedowns': 4,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 48,
#    'visionWardsBoughtInGame': 8,
#    'wardsKilled': 15,
#    'wardsPlaced': 9,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 1,
#    'assists': 7,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 197,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 11,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6705777221545298,
#     'controlWardsPlaced': 5,
#     'damagePerMinute': 1140.7054583825502,
#     'damageTakenOnTeamPercentage': 0.13576252296725302,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 6,
#     'dodgeSkillShotsSmallWindow': 30,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestDragonTakedown': 1771.0560944130002,
#     'earlyLaningPhaseGoldExpAdvantage': 1,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 1,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1993.215359773,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 489.0865992453633,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 1,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 2.5,
#     'killAfterHiddenWithAlly': 2,
#     'killParticipation': 0.7142857142857143,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 1,
#     'landSkillShotsEarlyGame': 5,
#     'laneMinionsFirst10Minutes': 69,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3087, 3124, 3115, 3157],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 12,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 2,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 11,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 2,
#     'skillshotsDodged': 210,
#     'skillshotsHit': 33,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 3,
#     'stealthWardsPlaced': 4,
#     'survivedSingleDigitHpCount': 1,
#     'survivedThreeImmobilizesInFight': 4,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 15,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 7,
#     'takedownsInAlcove': 1,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.37215851230492125,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 2,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
# ...
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 0,
#     'laneMinionsFirst10Minutes': 70,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3087, 6672, 3153, 3026],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 0,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 2,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 9,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 40,
#     'skillshotsHit': 0,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'soloTurretsLategame': 1,
#     'stealthWardsPlaced': 1,
#     'survivedSingleDigitHpCount': 1,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 10,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 3,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.24303652835342918,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 3,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.32532310485839844,
#     'visionScorePerMinute': 0.6714011810338714,
#     'voidMonsterKill': 0,
#     'wardTakedowns': 10,
#     'wardTakedownsBefore20M': 7,
#     'wardsGuarded': 1},
#    'champExperience': 16609,
#    'champLevel': 17,
#    'championId': 55,
#    'championName': 'Katarina',
#    'championTransform': 0,
#    'commandPings': 26,
#    'consumablesPurchased': 5,
#    'damageDealtToBuildings': 8066,
#    'damageDealtToObjectives': 14081,
#    'damageDealtToTurrets': 8066,
#    'damageSelfMitigated': 17982,
#    'dangerPings': 0,
#    'deaths': 3,
#    'detectorWardsPlaced': 3,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 1,
#    'enemyVisionPings': 11,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 8,
#    'goldEarned': 15779,
#    'goldSpent': 15775,
#    'holdPings': 0,
#    'individualPosition': 'MIDDLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 3026,
#    'item1': 2019,
#    'item2': 6672,
#    'item3': 3047,
#    'item4': 3087,
#    'item5': 3153,
#    'item6': 3364,
#    'itemsPurchased': 26,
#    'killingSprees': 2,
#    'kills': 8,
#    'lane': 'TOP',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 6,
#    'largestMultiKill': 3,
#    'longestTimeSpentLiving': 1039,
#    'magicDamageDealt': 112189,
#    'magicDamageDealtToChampions': 10916,
#    'magicDamageTaken': 6225,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 4,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 20,
#    'participantId': 9,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 893, 'var2': 0, 'var3': 0},
#        {'perk': 9111, 'var1': 941, 'var2': 200, 'var3': 0},
#        {'perk': 9104, 'var1': 19, 'var2': 0, 'var3': 0},
#        {'perk': 8299, 'var1': 692, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8143, 'var1': 960, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 76418,
#    'physicalDamageDealtToChampions': 11009,
#    'physicalDamageTaken': 17965,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4933,
#    'pushPings': 0,
#    'puuid': '5b7KW3VcT2OGVYG3H_fFdNw_sSosQh72VD-1-3o6mej_Id2ylhh9qAsk1Wzve59SukQxjyTdbmJ0AQ',
#    'quadraKills': 0,
#    'riotIdGameName': 'DK ShowMaker',
#    'riotIdTagline': 'KR1',
#    'role': 'DUO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 82,
#    'spell2Casts': 75,
#    'spell3Casts': 0,
#    'spell4Casts': 9,
#    'subteamPlacement': 0,
#    'summoner1Casts': 5,
#    'summoner1Id': 14,
#    'summoner2Casts': 4,
#    'summoner2Id': 12,
#    'summonerId': 'NvWvJxh4_K3dNNr75V1eiAqFQxB9uYN7XZq0tO9F5RaNdgQ',
#    'summonerLevel': 496,
#    'summonerName': 'DK ShowMaker',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 4,
#    'timePlayed': 1993,
#    'totalAllyJungleMinionsKilled': 4,
#    'totalDamageDealt': 195045,
#    'totalDamageDealtToChampions': 24746,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 26194,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 7850,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 239,
#    'totalTimeCCDealt': 90,
#    'totalTimeSpentDead': 91,
#    'totalUnitsHealed': 1,
#    'tripleKills': 1,
#    'trueDamageDealt': 6438,
#    'trueDamageDealtToChampions': 2821,
#    'trueDamageTaken': 2003,
#    'turretKills': 2,
#    'turretTakedowns': 3,
#    'turretsLost': 9,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 22,
#    'visionWardsBoughtInGame': 3,
#    'wardsKilled': 8,
#    'wardsPlaced': 4,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 6,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 215,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 1,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.24943508614273463,
#     'controlWardsPlaced': 5,
#     'damagePerMinute': 466.74062854387194,
#     'damageTakenOnTeamPercentage': 0.22064380777892648,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 9,
#     'dodgeSkillShotsSmallWindow': 4,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 18,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1993.215359773,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 336.6289355306617,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 2,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 0.6666666666666666,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.2857142857142857,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 11,
#     'laneMinionsFirst10Minutes': 63,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3078, 3143, 3053],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 0,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 6,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 47,
#     'skillshotsHit': 46,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 8,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 7,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 6,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 0,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.15227550343929205,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.36636674404144287,
#     'visionScorePerMinute': 1.394425428676032,
#     'voidMonsterKill': 0,
#     'wardTakedowns': 9,
#     'wardTakedownsBefore20M': 1,
#     'wardsGuarded': 1},
#    'champExperience': 15889,
#    'champLevel': 16,
#    'championId': 150,
#    'championName': 'Gnar',
#    'championTransform': 0,
#    'commandPings': 6,
#    'consumablesPurchased': 7,
#    'damageDealtToBuildings': 748,
#    'damageDealtToObjectives': 748,
#    'damageDealtToTurrets': 748,
#    'damageSelfMitigated': 41978,
#    'dangerPings': 0,
#    'deaths': 9,
#    'detectorWardsPlaced': 5,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 7,
#    'enemyVisionPings': 1,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 11182,
#    'goldSpent': 11258,
#    'holdPings': 0,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 3053,
#    'item1': 3143,
#    'item2': 0,
#    'item3': 3078,
#    'item4': 3047,
#    'item5': 0,
#    'item6': 3363,
#    'itemsPurchased': 27,
#    'killingSprees': 0,
#    'kills': 0,
#    'lane': 'TOP',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 0,
#    'longestTimeSpentLiving': 368,
#    'magicDamageDealt': 14535,
#    'magicDamageDealtToChampions': 1274,
#    'magicDamageTaken': 11057,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 4,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 1,
#    'participantId': 10,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 1839, 'var2': 1754, 'var3': 0},
#        {'perk': 9101, 'var1': 1908, 'var2': 0, 'var3': 0},
#        {'perk': 9104, 'var1': 21, 'var2': 30, 'var3': 0},
#        {'perk': 8017, 'var1': 942, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8451, 'var1': 228, 'var2': 0, 'var3': 0},
#        {'perk': 8473, 'var1': 1435, 'var2': 0, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 148562,
#    'physicalDamageDealtToChampions': 13832,
#    'physicalDamageTaken': 25141,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6651,
#    'pushPings': 0,
#    'puuid': 'A7e-bI-f26-pwWSf09y9AZmVvj_Vq3xe_7VqDxUvelDg4JpLYc0gbb1X70W26UheYnB6Oc0GUDRuYQ',
#    'quadraKills': 0,
#    'riotIdGameName': '天下 第一',
#    'riotIdTagline': 'CN1',
#    'role': 'DUO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 142,
#    'spell2Casts': 29,
#    'spell3Casts': 38,
#    'spell4Casts': 6,
#    'subteamPlacement': 0,
#    'summoner1Casts': 4,
#    'summoner1Id': 4,
#    'summoner2Casts': 4,
#    'summoner2Id': 12,
#    'summonerId': 'bYUnZu8QojtutWt1Pk5eERcw_CMOsdS1JC5yGpGc5UfuuWXCFmj0LKqiZA',
#    'summonerLevel': 120,
#    'summonerName': '4238963482364387',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 27,
#    'timePlayed': 1993,
#    'totalAllyJungleMinionsKilled': 4,
#    'totalDamageDealt': 165666,
#    'totalDamageDealtToChampions': 15505,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 38147,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 4310,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 246,
#    'totalTimeCCDealt': 573,
#    'totalTimeSpentDead': 271,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 2568,
#    'trueDamageDealtToChampions': 398,
#    'trueDamageTaken': 1947,
#    'turretKills': 1,
#    'turretTakedowns': 1,
#    'turretsLost': 9,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 46,
#    'visionWardsBoughtInGame': 5,
#    'wardsKilled': 9,
#    'wardsPlaced': 16,
#    'win': False}],
#  'platformId': 'KR',
#  'queueId': 420,
#  'teams': [{'bans': [{'championId': 81, 'pickTurn': 1},
#     {'championId': -1, 'pickTurn': 2},
#     {'championId': -1, 'pickTurn': 3},
#     {'championId': 133, 'pickTurn': 4},
#     {'championId': -1, 'pickTurn': 5}],
#    'objectives': {'baron': {'first': True, 'kills': 2},
#     'champion': {'first': False, 'kills': 28},
#     'dragon': {'first': False, 'kills': 3},
#     'horde': {'first': True, 'kills': 6},
#     'inhibitor': {'first': True, 'kills': 1},
#     'riftHerald': {'first': True, 'kills': 1},
#     'tower': {'first': True, 'kills': 9}},
#    'teamId': 100,
#    'win': True},
#   {'bans': [{'championId': 30, 'pickTurn': 6},
#     {'championId': -1, 'pickTurn': 7},
#     {'championId': 81, 'pickTurn': 8},
#     {'championId': 166, 'pickTurn': 9},
#     {'championId': -1, 'pickTurn': 10}],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': True, 'kills': 21},
#     'dragon': {'first': True, 'kills': 2},
#     'horde': {'first': False, 'kills': 0},
#     'inhibitor': {'first': False, 'kills': 0},
#     'riftHerald': {'first': False, 'kills': 0},
#     'tower': {'first': False, 'kills': 5}},
#    'teamId': 200,
#    'win': False}],
#  'tournamentCode': ''}

# %%
temp_match_data['info']['participants']
# Out:
# [{'allInPings': 1,
#   'assistMePings': 9,
#   'assists': 10,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 4,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 0,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 363,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 14,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 2,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7792911160266691,
#    'controlWardsPlaced': 4,
#    'damagePerMinute': 1080.937236691961,
#    'damageTakenOnTeamPercentage': 0.16676117432207022,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 3,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestBaron': 1534.5345089030002,
#    'earliestDragonTakedown': 814.2745124600001,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 0,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 822.080782276,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 9,
#    'gameLength': 1993.215359773,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 482.5339506418338,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 0,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 6,
#    'killAfterHiddenWithAlly': 1,
#    'killParticipation': 0.6428571428571429,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 2,
#    'killsNearEnemyTurret': 1,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 1,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 5,
#    'laneMinionsFirst10Minutes': 93,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3078, 3004, 3042, 6675, 3036],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 83,
#    'maxKillDeficit': 4,
#    'maxLevelLeadLaneOpponent': 2,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 1,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 12,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 1,
#    'skillshotsDodged': 16,
#    'skillshotsHit': 44,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 6,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 2,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 18,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 4,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 2,
#    'teamDamagePercentage': 0.2511556905876511,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 1,
#    'turretTakedowns': 2,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 0.48219096660614014,
#    'visionScorePerMinute': 0.9951447628639504,
#    'voidMonsterKill': 2,
#    'wardTakedowns': 7,
#    'wardTakedownsBefore20M': 1,
#    'wardsGuarded': 0},
#   'champExperience': 20228,
#   'champLevel': 18,
#   'championId': 42,
#   'championName': 'Corki',
#   'championTransform': 0,
#   'commandPings': 61,
#   'consumablesPurchased': 6,
#   'damageDealtToBuildings': 6199,
#   'damageDealtToObjectives': 22699,
#   'damageDealtToTurrets': 6199,
#   'damageSelfMitigated': 14416,
#   'dangerPings': 0,
#   'deaths': 3,
#   'detectorWardsPlaced': 4,
#   'doubleKills': 1,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 30,
#   'enemyVisionPings': 0,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 17,
#   'goldEarned': 16029,
#   'goldSpent': 15283,
#   'holdPings': 0,
#   'individualPosition': 'MIDDLE',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 3036,
#   'item1': 3042,
#   'item2': 2055,
#   'item3': 6675,
#   'item4': 3078,
#   'item5': 3111,
#   'item6': 3363,
#   'itemsPurchased': 26,
#   'killingSprees': 2,
#   'kills': 8,
#   'lane': 'MIDDLE',
#   'largestCriticalStrike': 644,
#   'largestKillingSpree': 4,
#   'largestMultiKill': 2,
#   'longestTimeSpentLiving': 980,
#   'magicDamageDealt': 73154,
#   'magicDamageDealtToChampions': 5547,
#   'magicDamageTaken': 10074,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 2,
#   'neutralMinionsKilled': 28,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 0,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 63,
#   'participantId': 1,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8021, 'var1': 2990, 'var2': 2842, 'var3': 0},
#       {'perk': 9101, 'var1': 2203, 'var2': 0, 'var3': 0},
#       {'perk': 9104, 'var1': 14, 'var2': 10, 'var3': 0},
#       {'perk': 8017, 'var1': 1564, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#       {'perk': 8316, 'var1': 11, 'var2': 25, 'var3': 0}],
#      'style': 8300}]},
#   'physicalDamageDealt': 182085,
#   'physicalDamageDealtToChampions': 25177,
#   'physicalDamageTaken': 12115,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 6335,
#   'pushPings': 0,
#   'puuid': 'PNXS-TH8OkdRyLXONcMZtNDIfJ0hEYta8GUCaEKp_tKGpoDF4zBsfViA_YsK8GA0qevrcdyDW2HJFA',
#   'quadraKills': 0,
#   'riotIdGameName': '아이유',
#   'riotIdTagline': '1128',
#   'role': 'SOLO',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 107,
#   'spell2Casts': 49,
#   'spell3Casts': 86,
#   'spell4Casts': 121,
#   'subteamPlacement': 0,
#   'summoner1Casts': 4,
#   'summoner1Id': 12,
#   'summoner2Casts': 4,
#   'summoner2Id': 4,
#   'summonerId': 'A3VYN1IIYUgqOkQm5JHNoNMleeOnDwFJ4eX3zTerYcNI_-o',
#   'summonerLevel': 537,
#   'summonerName': 'dlwlrma22',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'MIDDLE',
#   'timeCCingOthers': 2,
#   'timePlayed': 1993,
#   'totalAllyJungleMinionsKilled': 22,
#   'totalDamageDealt': 280007,
#   'totalDamageDealtToChampions': 35909,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 23363,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 7946,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 298,
#   'totalTimeCCDealt': 85,
#   'totalTimeSpentDead': 85,
#   'totalUnitsHealed': 1,
#   'tripleKills': 0,
#   'trueDamageDealt': 24767,
#   'trueDamageDealtToChampions': 5184,
#   'trueDamageTaken': 1173,
#   'turretKills': 0,
#   'turretTakedowns': 2,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 33,
#   'visionWardsBoughtInGame': 5,
#   'wardsKilled': 7,
#   'wardsPlaced': 15,
#   'win': True},
#  {'allInPings': 0,
#   'assistMePings': 2,
#   'assists': 15,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 3,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 0,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 924,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 16,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 2,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.48941444209726387,
#    'controlWardsPlaced': 6,
#    'damagePerMinute': 1000.5355430971199,
#    'damageTakenOnTeamPercentage': 0.16737692854655264,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 4,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 2,
#    'earliestBaron': 1534.5345089030002,
#    'earliestDragonTakedown': 1140.499855488,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 0,
#    'enemyJungleMonsterKills': 10,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 822.080782276,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 9,
#    'gameLength': 1993.215359773,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 482.797961485504,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 0,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 5.5,
#    'killAfterHiddenWithAlly': 5,
#    'killParticipation': 0.7857142857142857,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 2,
#    'killsNearEnemyTurret': 1,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 1,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 104,
#    'laneMinionsFirst10Minutes': 66,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3087, 3085, 3031, 3036],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 30.000000029802322,
#    'maxKillDeficit': 4,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 15,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 1,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 1,
#    'skillshotsDodged': 3,
#    'skillshotsHit': 513,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'soloTurretsLategame': 1,
#    'stealthWardsPlaced': 4,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 4,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 22,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 4,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 2,
#    'teamDamagePercentage': 0.23247436276048913,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 1,
#    'turretTakedowns': 4,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 0.16276371479034424,
#    'visionScorePerMinute': 1.46274622208246,
#    'voidMonsterKill': 2,
#    'wardTakedowns': 13,
#    'wardTakedownsBefore20M': 9,
#    'wardsGuarded': 0},
#   'champExperience': 18488,
#   'champLevel': 18,
#   'championId': 221,
#   'championName': 'Zeri',
#   'championTransform': 0,
#   'commandPings': 46,
#   'consumablesPurchased': 10,
#   'damageDealtToBuildings': 5495,
#   'damageDealtToObjectives': 23356,
#   'damageDealtToTurrets': 5495,
#   'damageSelfMitigated': 10894,
#   'dangerPings': 0,
#   'deaths': 4,
#   'detectorWardsPlaced': 6,
#   'doubleKills': 0,
#   'dragonKills': 2,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 58,
#   'enemyVisionPings': 2,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 8,
#   'goldEarned': 16038,
#   'goldSpent': 14180,
#   'holdPings': 0,
#   'individualPosition': 'BOTTOM',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 0,
#   'item0': 0,
#   'item1': 3036,
#   'item2': 3085,
#   'item3': 3006,
#   'item4': 3087,
#   'item5': 3031,
#   'item6': 3363,
#   'itemsPurchased': 29,
#   'killingSprees': 2,
#   'kills': 7,
#   'lane': 'BOTTOM',
#   'largestCriticalStrike': 942,
#   'largestKillingSpree': 3,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 657,
#   'magicDamageDealt': 56817,
#   'magicDamageDealtToChampions': 10263,
#   'magicDamageTaken': 10263,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 38,
#   'nexusKills': 1,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 14,
#   'participantId': 2,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8021, 'var1': 3456, 'var2': 3256, 'var3': 0},
#       {'perk': 9101, 'var1': 1576, 'var2': 0, 'var3': 0},
#       {'perk': 9104, 'var1': 16, 'var2': 30, 'var3': 0},
#       {'perk': 8017, 'var1': 1646, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8313, 'var1': 3, 'var2': 0, 'var3': 0},
#       {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#      'style': 8300}]},
#   'physicalDamageDealt': 189988,
#   'physicalDamageDealtToChampions': 20416,
#   'physicalDamageTaken': 12510,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 3797,
#   'pushPings': 0,
#   'puuid': 'LQ2jrGzLI85VQ2kF1rtkUGLb1dek_25NcO5KNveWda8Mn7SsEGBJt3CMqztdRfFpkatAtKrCzfwAHA',
#   'quadraKills': 0,
#   'riotIdGameName': 'sad and bad',
#   'riotIdTagline': 'KR1',
#   'role': 'CARRY',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 796,
#   'spell2Casts': 73,
#   'spell3Casts': 46,
#   'spell4Casts': 9,
#   'subteamPlacement': 0,
#   'summoner1Casts': 4,
#   'summoner1Id': 4,
#   'summoner2Casts': 5,
#   'summoner2Id': 1,
#   'summonerId': 'p0dnYl0FKB6DXtwVEZwWBhlEv8LyT-PqpHbKEFqYZEeGlv8',
#   'summonerLevel': 396,
#   'summonerName': 'sad and bad',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'BOTTOM',
#   'timeCCingOthers': 12,
#   'timePlayed': 1993,
#   'totalAllyJungleMinionsKilled': 20,
#   'totalDamageDealt': 294775,
#   'totalDamageDealtToChampions': 33238,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 23450,
#   'totalEnemyJungleMinionsKilled': 5,
#   'totalHeal': 6541,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 284,
#   'totalTimeCCDealt': 171,
#   'totalTimeSpentDead': 94,
#   'totalUnitsHealed': 1,
#   'tripleKills': 0,
#   'trueDamageDealt': 47969,
#   'trueDamageDealtToChampions': 2558,
#   'trueDamageTaken': 676,
#   'turretKills': 4,
#   'turretTakedowns': 4,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 48,
#   'visionWardsBoughtInGame': 6,
#   'wardsKilled': 13,
#   'wardsPlaced': 15,
#   'win': True},
#  {'allInPings': 0,
#   'assistMePings': 0,
#   'assists': 11,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 1,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 0,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 597,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 2,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 1,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 500,
#    'buffsStolen': 1,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6404367562927967,
#    'controlWardsPlaced': 2,
#    'damagePerMinute': 1272.9980261836686,
#    'damageTakenOnTeamPercentage': 0.18215801321246577,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 5,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestBaron': 1534.5345089030002,
#    'earliestDragonTakedown': 1456.666154367,
#    'earlyLaningPhaseGoldExpAdvantage': 1,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 41,
#    'enemyJungleMonsterKills': 2,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 822.080782276,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 9,
#    'gameLength': 1993.215359773,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 524.3156582721294,
#    'hadOpenNexus': 0,
#    'highestChampionDamage': 1,
#    'immobilizeAndKillWithAlly': 7,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 1,
#    'kda': 3.8,
#    'killAfterHiddenWithAlly': 1,
#    'killParticipation': 0.6785714285714286,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 0,
#    'killsNearEnemyTurret': 3,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 4,
#    'landSkillShotsEarlyGame': 5,
#    'laneMinionsFirst10Minutes': 98,
#    'laningPhaseGoldExpAdvantage': 1,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [6692, 3004, 3042, 6701, 6694, 3026],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 67,
#    'maxKillDeficit': 4,
#    'maxLevelLeadLaneOpponent': 3,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 1,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 8,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 1,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'skillshotsDodged': 27,
#    'skillshotsHit': 26,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 4,
#    'stealthWardsPlaced': 3,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 1,
#    'takedownOnFirstTurret': 1,
#    'takedowns': 19,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 3,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 2,
#    'teamDamagePercentage': 0.2957810014588183,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 5,
#    'turretTakedowns': 6,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.2681320309638977,
#    'visionScorePerMinute': 1.0205352702878006,
#    'voidMonsterKill': 2,
#    'wardTakedowns': 7,
#    'wardTakedownsBefore20M': 2,
#    'wardsGuarded': 1},
#   'champExperience': 21305,
#   'champLevel': 18,
#   'championId': 126,
#   'championName': 'Jayce',
#   'championTransform': 0,
#   'commandPings': 1,
#   'consumablesPurchased': 5,
#   'damageDealtToBuildings': 11659,
#   'damageDealtToObjectives': 22395,
#   'damageDealtToTurrets': 11659,
#   'damageSelfMitigated': 26334,
#   'dangerPings': 0,
#   'deaths': 5,
#   'detectorWardsPlaced': 2,
#   'doubleKills': 0,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 4,
#   'enemyVisionPings': 3,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 0,
#   'goldEarned': 17417,
#   'goldSpent': 16450,
#   'holdPings': 0,
#   'individualPosition': 'TOP',
#   'inhibitorKills': 1,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 6694,
#   'item1': 6692,
#   'item2': 3026,
#   'item3': 3042,
#   'item4': 6701,
#   'item5': 3158,
#   'item6': 3363,
#   'itemsPurchased': 28,
#   'killingSprees': 3,
#   'kills': 8,
#   'lane': 'JUNGLE',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 2,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 650,
#   'magicDamageDealt': 25604,
#   'magicDamageDealtToChampions': 7426,
#   'magicDamageTaken': 7040,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 9,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 10,
#   'participantId': 3,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8021, 'var1': 2800, 'var2': 3506, 'var3': 0},
#       {'perk': 9101, 'var1': 1983, 'var2': 0, 'var3': 0},
#       {'perk': 9105, 'var1': 15, 'var2': 30, 'var3': 0},
#       {'perk': 8017, 'var1': 1948, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8316, 'var1': 7, 'var2': 10, 'var3': 0},
#       {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#      'style': 8300}]},
#   'physicalDamageDealt': 224843,
#   'physicalDamageDealtToChampions': 34425,
#   'physicalDamageTaken': 17257,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 4533,
#   'pushPings': 0,
#   'puuid': '9MOT2cUzidG9slSLcCmeegX0L4dce13-sz_jAUrdlrstO5xbpM-NAvbZ2QdgrUlp2vld0tdDV4l3PA',
#   'quadraKills': 0,
#   'riotIdGameName': '젠지 한별',
#   'riotIdTagline': 'GEN',
#   'role': 'NONE',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 169,
#   'spell2Casts': 113,
#   'spell3Casts': 111,
#   'spell4Casts': 204,
#   'subteamPlacement': 0,
#   'summoner1Casts': 4,
#   'summoner1Id': 12,
#   'summoner2Casts': 5,
#   'summoner2Id': 4,
#   'summonerId': 'CZGqTYMzumUi6Bwm0NTCsA5cu-VerV4S3_hzJ6dqVV4LV7M',
#   'summonerLevel': 856,
#   'summonerName': '강하다 별',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'TOP',
#   'timeCCingOthers': 16,
#   'timePlayed': 1993,
#   'totalAllyJungleMinionsKilled': 2,
#   'totalDamageDealt': 259770,
#   'totalDamageDealtToChampions': 42289,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 25521,
#   'totalEnemyJungleMinionsKilled': 5,
#   'totalHeal': 6435,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 290,
#   'totalTimeCCDealt': 180,
#   'totalTimeSpentDead': 234,
#   'totalUnitsHealed': 1,
#   'tripleKills': 0,
#   'trueDamageDealt': 9322,
#   'trueDamageDealtToChampions': 437,
#   'trueDamageTaken': 1223,
#   'turretKills': 5,
#   'turretTakedowns': 6,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 33,
#   'visionWardsBoughtInGame': 2,
#   'wardsKilled': 7,
#   'wardsPlaced': 13,
#   'win': True},
#  {'allInPings': 1,
#   'assistMePings': 15,
#   'assists': 20,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 0,
#   'challenges': {'12AssistStreakCount': 1,
#    'InfernalScalePickup': 0,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 206,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 0,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 2,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.8339002052960777,
#    'controlWardsPlaced': 22,
#    'damagePerMinute': 236.0028089898412,
#    'damageTakenOnTeamPercentage': 0.18306180714231962,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 7,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestBaron': 1534.5345089030002,
#    'earliestDragonTakedown': 814.2745124600001,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 74,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 822.080782276,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 9,
#    'gameLength': 1993.215359773,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 265.07920421926855,
#    'hadOpenNexus': 0,
#    'highestCrowdControlScore': 1,
#    'immobilizeAndKillWithAlly': 11,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 3,
#    'killAfterHiddenWithAlly': 3,
#    'killParticipation': 0.75,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 0,
#    'killsNearEnemyTurret': 0,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 6,
#    'landSkillShotsEarlyGame': 0,
#    'laneMinionsFirst10Minutes': 15,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3869, 3083],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 4,
#    'maxKillDeficit': 4,
#    'maxLevelLeadLaneOpponent': 3,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 14,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 1,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'skillshotsDodged': 9,
#    'skillshotsHit': 0,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 45,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 2,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 21,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 3,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 2,
#    'teamDamagePercentage': 0.054835235997481385,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 0,
#    'turretTakedowns': 1,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 1,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.018286287784576416,
#    'visionScorePerMinute': 3.631934484451346,
#    'voidMonsterKill': 3,
#    'wardTakedowns': 9,
#    'wardTakedownsBefore20M': 4,
#    'wardsGuarded': 2},
#   'champExperience': 11847,
#   'champLevel': 14,
#   'championId': 526,
#   'championName': 'Rell',
#   'championTransform': 0,
#   'commandPings': 22,
#   'consumablesPurchased': 24,
#   'damageDealtToBuildings': 451,
#   'damageDealtToObjectives': 877,
#   'damageDealtToTurrets': 451,
#   'damageSelfMitigated': 27612,
#   'dangerPings': 0,
#   'deaths': 7,
#   'detectorWardsPlaced': 22,
#   'doubleKills': 0,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 17,
#   'enemyVisionPings': 16,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 15,
#   'goldEarned': 8805,
#   'goldSpent': 7600,
#   'holdPings': 0,
#   'individualPosition': 'UTILITY',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 0,
#   'item0': 1029,
#   'item1': 0,
#   'item2': 3869,
#   'item3': 3083,
#   'item4': 3067,
#   'item5': 3111,
#   'item6': 3364,
#   'itemsPurchased': 40,
#   'killingSprees': 0,
#   'kills': 1,
#   'lane': 'BOTTOM',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 464,
#   'magicDamageDealt': 7122,
#   'magicDamageDealtToChampions': 5639,
#   'magicDamageTaken': 11157,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 0,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 38,
#   'participantId': 4,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5010, 'offense': 5007},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8439, 'var1': 951, 'var2': 745, 'var3': 0},
#       {'perk': 8401, 'var1': 461, 'var2': 0, 'var3': 0},
#       {'perk': 8473, 'var1': 809, 'var2': 0, 'var3': 0},
#       {'perk': 8451, 'var1': 200, 'var2': 0, 'var3': 0}],
#      'style': 8400},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8306, 'var1': 10, 'var2': 0, 'var3': 0},
#       {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#      'style': 8300}]},
#   'physicalDamageDealt': 3447,
#   'physicalDamageDealtToChampions': 1144,
#   'physicalDamageTaken': 13459,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 3898,
#   'pushPings': 0,
#   'puuid': 'FNHn19CPilc-zYduEMr3nKVkpX5OAZycwOETS9mns3T8pP7cz0IFIgajrrfNciZAOP_nCB-eUzYeNA',
#   'quadraKills': 0,
#   'riotIdGameName': 'Anami',
#   'riotIdTagline': 'KR0',
#   'role': 'SUPPORT',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 59,
#   'spell2Casts': 46,
#   'spell3Casts': 92,
#   'spell4Casts': 9,
#   'subteamPlacement': 0,
#   'summoner1Casts': 8,
#   'summoner1Id': 14,
#   'summoner2Casts': 15,
#   'summoner2Id': 4,
#   'summonerId': 'Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s',
#   'summonerLevel': 702,
#   'summonerName': 'wway',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'UTILITY',
#   'timeCCingOthers': 52,
#   'timePlayed': 1993,
#   'totalAllyJungleMinionsKilled': 0,
#   'totalDamageDealt': 14439,
#   'totalDamageDealtToChampions': 7840,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 25647,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 593,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 27,
#   'totalTimeCCDealt': 91,
#   'totalTimeSpentDead': 139,
#   'totalUnitsHealed': 1,
#   'tripleKills': 0,
#   'trueDamageDealt': 3870,
#   'trueDamageDealtToChampions': 1056,
#   'trueDamageTaken': 1030,
#   'turretKills': 0,
#   'turretTakedowns': 1,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 120,
#   'visionWardsBoughtInGame': 22,
#   'wardsKilled': 9,
#   'wardsPlaced': 67,
#   'win': True},
#  {'allInPings': 2,
#   'assistMePings': 7,
#   'assists': 13,
#   'baronKills': 2,
#   'basicPings': 0,
#   'bountyLevel': 1,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 0,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 1314,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 66,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 2,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 2,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5322938305160516,
#    'controlWardsPlaced': 7,
#    'damagePerMinute': 713.379641011013,
#    'damageTakenOnTeamPercentage': 0.3006420767765917,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 2,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 2,
#    'earliestBaron': 1534.5345089030002,
#    'earliestDragonTakedown': 814.2745124600001,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 6674.14404296875,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 0,
#    'enemyJungleMonsterKills': 35,
#    'epicMonsterKillsNearEnemyJungler': 1,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 822.080782276,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 9,
#    'gameLength': 1993.215359773,
#    'goldPerMinute': 404.03894976843685,
#    'hadOpenNexus': 0,
#    'highestWardKills': 1,
#    'immobilizeAndKillWithAlly': 0,
#    'initialBuffCount': 2,
#    'initialCrabCount': 1,
#    'jungleCsBefore10Minutes': 85.75000014901161,
#    'junglerKillsEarlyJungle': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 8.5,
#    'killAfterHiddenWithAlly': 4,
#    'killParticipation': 0.6071428571428571,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 0,
#    'killsNearEnemyTurret': 2,
#    'killsOnLanersEarlyJungleAsJungler': 1,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 0,
#    'laneMinionsFirst10Minutes': 0,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [6653, 4628, 3165],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 53.200000047683716,
#    'maxKillDeficit': 4,
#    'maxLevelLeadLaneOpponent': 2,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': -10.999999940395355,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 12,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 1,
#    'saveAllyFromDeath': 1,
#    'scuttleCrabKills': 3,
#    'skillshotsDodged': 9,
#    'skillshotsHit': 20,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 2,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 6,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 17,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 2,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 2,
#    'teamDamagePercentage': 0.16575370919556004,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 0,
#    'turretTakedowns': 4,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 1,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 0.744604229927063,
#    'visionScorePerMinute': 1.4529713940354985,
#    'voidMonsterKill': 9,
#    'wardTakedowns': 15,
#    'wardTakedownsBefore20M': 6,
#    'wardsGuarded': 1},
#   'champExperience': 16723,
#   'champLevel': 17,
#   'championId': 76,
#   'championName': 'Nidalee',
#   'championTransform': 0,
#   'commandPings': 3,
#   'consumablesPurchased': 10,
#   'damageDealtToBuildings': 921,
#   'damageDealtToObjectives': 41678,
#   'damageDealtToTurrets': 921,
#   'damageSelfMitigated': 27318,
#   'dangerPings': 0,
#   'deaths': 2,
#   'detectorWardsPlaced': 7,
#   'doubleKills': 0,
#   'dragonKills': 1,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 11,
#   'enemyVisionPings': 0,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 9,
#   'goldEarned': 13422,
#   'goldSpent': 12190,
#   'holdPings': 0,
#   'individualPosition': 'JUNGLE',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 2055,
#   'item1': 3165,
#   'item2': 1082,
#   'item3': 6653,
#   'item4': 4628,
#   'item5': 3111,
#   'item6': 3364,
#   'itemsPurchased': 26,
#   'killingSprees': 1,
#   'kills': 4,
#   'lane': 'JUNGLE',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 2,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 1295,
#   'magicDamageDealt': 170094,
#   'magicDamageDealtToChampions': 18285,
#   'magicDamageTaken': 13365,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 200,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 34,
#   'participantId': 5,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8010, 'var1': 55, 'var2': 0, 'var3': 0},
#       {'perk': 9111, 'var1': 1635, 'var2': 340, 'var3': 0},
#       {'perk': 9105, 'var1': 11, 'var2': 0, 'var3': 0},
#       {'perk': 8017, 'var1': 1084, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8210, 'var1': 12, 'var2': 0, 'var3': 0},
#       {'perk': 8232, 'var1': 6, 'var2': 50, 'var3': 0}],
#      'style': 8200}]},
#   'physicalDamageDealt': 24102,
#   'physicalDamageDealtToChampions': 1224,
#   'physicalDamageTaken': 27650,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 4568,
#   'pushPings': 0,
#   'puuid': '_cxbUaGm1qKxwxWVUC9eHZcZ-R5aApS8RfZn6Q7P_ikmc0XdX5GsozAyG4eO90_LtyGHPxX4zi3nWw',
#   'quadraKills': 0,
#   'riotIdGameName': 'HamBak',
#   'riotIdTagline': 'KR0',
#   'role': 'NONE',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 336,
#   'spell2Casts': 362,
#   'spell3Casts': 223,
#   'spell4Casts': 393,
#   'subteamPlacement': 0,
#   'summoner1Casts': 3,
#   'summoner1Id': 4,
#   'summoner2Casts': 16,
#   'summoner2Id': 11,
#   'summonerId': 'mgbmIw1zBafdMlezogAxuUtw-_noT4AQFkF3Yq_yTFGD1-c',
#   'summonerLevel': 428,
#   'summonerName': 'hhhhbbbb',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'JUNGLE',
#   'timeCCingOthers': 13,
#   'timePlayed': 1993,
#   'totalAllyJungleMinionsKilled': 107,
#   'totalDamageDealt': 280705,
#   'totalDamageDealtToChampions': 23698,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 42121,
#   'totalEnemyJungleMinionsKilled': 41,
#   'totalHeal': 36585,
#   'totalHealsOnTeammates': 6674,
#   'totalMinionsKilled': 25,
#   'totalTimeCCDealt': 292,
#   'totalTimeSpentDead': 93,
#   'totalUnitsHealed': 5,
#   'tripleKills': 0,
#   'trueDamageDealt': 86508,
#   'trueDamageDealtToChampions': 4188,
#   'trueDamageTaken': 1104,
#   'turretKills': 0,
#   'turretTakedowns': 4,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 48,
#   'visionWardsBoughtInGame': 8,
#   'wardsKilled': 15,
#   'wardsPlaced': 9,
#   'win': True},
#  {'allInPings': 0,
#   'assistMePings': 1,
#   'assists': 7,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 0,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 0,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 197,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 11,
#    'baronTakedowns': 0,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 150,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6705777221545298,
#    'controlWardsPlaced': 5,
#    'damagePerMinute': 1140.7054583825502,
#    'damageTakenOnTeamPercentage': 0.13576252296725302,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 6,
#    'dodgeSkillShotsSmallWindow': 30,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestDragonTakedown': 1771.0560944130002,
#    'earlyLaningPhaseGoldExpAdvantage': 1,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 1,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 0,
#    'gameLength': 1993.215359773,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 489.0865992453633,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 1,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 2.5,
#    'killAfterHiddenWithAlly': 2,
#    'killParticipation': 0.7142857142857143,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 1,
#    'killsNearEnemyTurret': 1,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 1,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 1,
#    'landSkillShotsEarlyGame': 5,
#    'laneMinionsFirst10Minutes': 69,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3087, 3124, 3115, 3157],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 12,
#    'maxKillDeficit': 0,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 2,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 11,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 2,
#    'skillshotsDodged': 210,
#    'skillshotsHit': 33,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 3,
#    'stealthWardsPlaced': 4,
#    'survivedSingleDigitHpCount': 1,
#    'survivedThreeImmobilizesInFight': 4,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 15,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 7,
#    'takedownsInAlcove': 1,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 0,
#    'teamDamagePercentage': 0.37215851230492125,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 2,
#    'turretTakedowns': 2,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.13998007774353027,
#    'visionScorePerMinute': 1.2579908811819187,
#    'voidMonsterKill': 0,
#    'wardTakedowns': 10,
#    'wardTakedownsBefore20M': 6,
#    'wardsGuarded': 1},
#   'champExperience': 17321,
#   'champLevel': 17,
#   'championId': 145,
#   'championName': 'Kaisa',
#   'championTransform': 0,
#   'commandPings': 4,
#   'consumablesPurchased': 8,
#   'damageDealtToBuildings': 5446,
#   'damageDealtToObjectives': 11980,
#   'damageDealtToTurrets': 5446,
#   'damageSelfMitigated': 14433,
#   'dangerPings': 0,
#   'deaths': 6,
#   'detectorWardsPlaced': 5,
#   'doubleKills': 0,
#   'dragonKills': 1,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 1,
#   'enemyVisionPings': 3,
#   'firstBloodAssist': False,
#   'firstBloodKill': True,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 0,
#   'goldEarned': 16247,
#   'goldSpent': 15675,
#   'holdPings': 0,
#   'individualPosition': 'BOTTOM',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 1,
#   'item0': 1058,
#   'item1': 3157,
#   'item2': 3115,
#   'item3': 3124,
#   'item4': 3087,
#   'item5': 3006,
#   'item6': 3363,
#   'itemsPurchased': 30,
#   'killingSprees': 3,
#   'kills': 8,
#   'lane': 'BOTTOM',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 3,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 664,
#   'magicDamageDealt': 94892,
#   'magicDamageDealtToChampions': 19847,
#   'magicDamageTaken': 5890,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 1,
#   'neutralMinionsKilled': 28,
#   'nexusKills': 0,
#   'nexusLost': 1,
#   'nexusTakedowns': 0,
# ...
#    'alliedJungleMonsterKills': 6,
#    'baronTakedowns': 0,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 825,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.19257603422076522,
#    'controlWardsPlaced': 2,
#    'damagePerMinute': 744.9328318787888,
#    'damageTakenOnTeamPercentage': 0.15150924838444801,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 3,
#    'dodgeSkillShotsSmallWindow': 4,
#    'doubleAces': 0,
#    'dragonTakedowns': 2,
#    'earliestDragonTakedown': 431.202947666,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 0,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 0,
#    'gameLength': 1993.215359773,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 474.99037212746174,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 0,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 3.3333333333333335,
#    'killAfterHiddenWithAlly': 1,
#    'killParticipation': 0.47619047619047616,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 1,
#    'killsNearEnemyTurret': 0,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 0,
#    'laneMinionsFirst10Minutes': 70,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3087, 6672, 3153, 3026],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 0,
#    'maxKillDeficit': 0,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 2,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 9,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'skillshotsDodged': 40,
#    'skillshotsHit': 0,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 1,
#    'soloTurretsLategame': 1,
#    'stealthWardsPlaced': 1,
#    'survivedSingleDigitHpCount': 1,
#    'survivedThreeImmobilizesInFight': 0,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 10,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 3,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 0,
#    'teamDamagePercentage': 0.24303652835342918,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 0,
#    'turretTakedowns': 3,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.32532310485839844,
#    'visionScorePerMinute': 0.6714011810338714,
#    'voidMonsterKill': 0,
#    'wardTakedowns': 10,
#    'wardTakedownsBefore20M': 7,
#    'wardsGuarded': 1},
#   'champExperience': 16609,
#   'champLevel': 17,
#   'championId': 55,
#   'championName': 'Katarina',
#   'championTransform': 0,
#   'commandPings': 26,
#   'consumablesPurchased': 5,
#   'damageDealtToBuildings': 8066,
#   'damageDealtToObjectives': 14081,
#   'damageDealtToTurrets': 8066,
#   'damageSelfMitigated': 17982,
#   'dangerPings': 0,
#   'deaths': 3,
#   'detectorWardsPlaced': 3,
#   'doubleKills': 1,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 1,
#   'enemyVisionPings': 11,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 8,
#   'goldEarned': 15779,
#   'goldSpent': 15775,
#   'holdPings': 0,
#   'individualPosition': 'MIDDLE',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 1,
#   'item0': 3026,
#   'item1': 2019,
#   'item2': 6672,
#   'item3': 3047,
#   'item4': 3087,
#   'item5': 3153,
#   'item6': 3364,
#   'itemsPurchased': 26,
#   'killingSprees': 2,
#   'kills': 8,
#   'lane': 'TOP',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 6,
#   'largestMultiKill': 3,
#   'longestTimeSpentLiving': 1039,
#   'magicDamageDealt': 112189,
#   'magicDamageDealtToChampions': 10916,
#   'magicDamageTaken': 6225,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 4,
#   'nexusKills': 0,
#   'nexusLost': 1,
#   'nexusTakedowns': 0,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 20,
#   'participantId': 9,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8010, 'var1': 893, 'var2': 0, 'var3': 0},
#       {'perk': 9111, 'var1': 941, 'var2': 200, 'var3': 0},
#       {'perk': 9104, 'var1': 19, 'var2': 0, 'var3': 0},
#       {'perk': 8299, 'var1': 692, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8143, 'var1': 960, 'var2': 0, 'var3': 0},
#       {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#      'style': 8100}]},
#   'physicalDamageDealt': 76418,
#   'physicalDamageDealtToChampions': 11009,
#   'physicalDamageTaken': 17965,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 4933,
#   'pushPings': 0,
#   'puuid': '5b7KW3VcT2OGVYG3H_fFdNw_sSosQh72VD-1-3o6mej_Id2ylhh9qAsk1Wzve59SukQxjyTdbmJ0AQ',
#   'quadraKills': 0,
#   'riotIdGameName': 'DK ShowMaker',
#   'riotIdTagline': 'KR1',
#   'role': 'DUO',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 82,
#   'spell2Casts': 75,
#   'spell3Casts': 0,
#   'spell4Casts': 9,
#   'subteamPlacement': 0,
#   'summoner1Casts': 5,
#   'summoner1Id': 14,
#   'summoner2Casts': 4,
#   'summoner2Id': 12,
#   'summonerId': 'NvWvJxh4_K3dNNr75V1eiAqFQxB9uYN7XZq0tO9F5RaNdgQ',
#   'summonerLevel': 496,
#   'summonerName': 'DK ShowMaker',
#   'teamEarlySurrendered': False,
#   'teamId': 200,
#   'teamPosition': 'MIDDLE',
#   'timeCCingOthers': 4,
#   'timePlayed': 1993,
#   'totalAllyJungleMinionsKilled': 4,
#   'totalDamageDealt': 195045,
#   'totalDamageDealtToChampions': 24746,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 26194,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 7850,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 239,
#   'totalTimeCCDealt': 90,
#   'totalTimeSpentDead': 91,
#   'totalUnitsHealed': 1,
#   'tripleKills': 1,
#   'trueDamageDealt': 6438,
#   'trueDamageDealtToChampions': 2821,
#   'trueDamageTaken': 2003,
#   'turretKills': 2,
#   'turretTakedowns': 3,
#   'turretsLost': 9,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 22,
#   'visionWardsBoughtInGame': 3,
#   'wardsKilled': 8,
#   'wardsPlaced': 4,
#   'win': False},
#  {'allInPings': 0,
#   'assistMePings': 0,
#   'assists': 6,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 0,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 0,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 215,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 1,
#    'baronTakedowns': 0,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.24943508614273463,
#    'controlWardsPlaced': 5,
#    'damagePerMinute': 466.74062854387194,
#    'damageTakenOnTeamPercentage': 0.22064380777892648,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 9,
#    'dodgeSkillShotsSmallWindow': 4,
#    'doubleAces': 0,
#    'dragonTakedowns': 0,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 18,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 0,
#    'gameLength': 1993.215359773,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 336.6289355306617,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 2,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 0.6666666666666666,
#    'killAfterHiddenWithAlly': 0,
#    'killParticipation': 0.2857142857142857,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 0,
#    'killsNearEnemyTurret': 0,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 11,
#    'laneMinionsFirst10Minutes': 63,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3078, 3143, 3053],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 0,
#    'maxKillDeficit': 0,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 6,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'skillshotsDodged': 47,
#    'skillshotsHit': 46,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 8,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 7,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 6,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 0,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 0,
#    'teamDamagePercentage': 0.15227550343929205,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 0,
#    'turretTakedowns': 1,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 0.36636674404144287,
#    'visionScorePerMinute': 1.394425428676032,
#    'voidMonsterKill': 0,
#    'wardTakedowns': 9,
#    'wardTakedownsBefore20M': 1,
#    'wardsGuarded': 1},
#   'champExperience': 15889,
#   'champLevel': 16,
#   'championId': 150,
#   'championName': 'Gnar',
#   'championTransform': 0,
#   'commandPings': 6,
#   'consumablesPurchased': 7,
#   'damageDealtToBuildings': 748,
#   'damageDealtToObjectives': 748,
#   'damageDealtToTurrets': 748,
#   'damageSelfMitigated': 41978,
#   'dangerPings': 0,
#   'deaths': 9,
#   'detectorWardsPlaced': 5,
#   'doubleKills': 0,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 7,
#   'enemyVisionPings': 1,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 0,
#   'goldEarned': 11182,
#   'goldSpent': 11258,
#   'holdPings': 0,
#   'individualPosition': 'TOP',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 1,
#   'item0': 3053,
#   'item1': 3143,
#   'item2': 0,
#   'item3': 3078,
#   'item4': 3047,
#   'item5': 0,
#   'item6': 3363,
#   'itemsPurchased': 27,
#   'killingSprees': 0,
#   'kills': 0,
#   'lane': 'TOP',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 0,
#   'longestTimeSpentLiving': 368,
#   'magicDamageDealt': 14535,
#   'magicDamageDealtToChampions': 1274,
#   'magicDamageTaken': 11057,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 4,
#   'nexusKills': 0,
#   'nexusLost': 1,
#   'nexusTakedowns': 0,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 1,
#   'participantId': 10,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8021, 'var1': 1839, 'var2': 1754, 'var3': 0},
#       {'perk': 9101, 'var1': 1908, 'var2': 0, 'var3': 0},
#       {'perk': 9104, 'var1': 21, 'var2': 30, 'var3': 0},
#       {'perk': 8017, 'var1': 942, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8451, 'var1': 228, 'var2': 0, 'var3': 0},
#       {'perk': 8473, 'var1': 1435, 'var2': 0, 'var3': 0}],
#      'style': 8400}]},
#   'physicalDamageDealt': 148562,
#   'physicalDamageDealtToChampions': 13832,
#   'physicalDamageTaken': 25141,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 6651,
#   'pushPings': 0,
#   'puuid': 'A7e-bI-f26-pwWSf09y9AZmVvj_Vq3xe_7VqDxUvelDg4JpLYc0gbb1X70W26UheYnB6Oc0GUDRuYQ',
#   'quadraKills': 0,
#   'riotIdGameName': '天下 第一',
#   'riotIdTagline': 'CN1',
#   'role': 'DUO',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 142,
#   'spell2Casts': 29,
#   'spell3Casts': 38,
#   'spell4Casts': 6,
#   'subteamPlacement': 0,
#   'summoner1Casts': 4,
#   'summoner1Id': 4,
#   'summoner2Casts': 4,
#   'summoner2Id': 12,
#   'summonerId': 'bYUnZu8QojtutWt1Pk5eERcw_CMOsdS1JC5yGpGc5UfuuWXCFmj0LKqiZA',
#   'summonerLevel': 120,
#   'summonerName': '4238963482364387',
#   'teamEarlySurrendered': False,
#   'teamId': 200,
#   'teamPosition': 'TOP',
#   'timeCCingOthers': 27,
#   'timePlayed': 1993,
#   'totalAllyJungleMinionsKilled': 4,
#   'totalDamageDealt': 165666,
#   'totalDamageDealtToChampions': 15505,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 38147,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 4310,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 246,
#   'totalTimeCCDealt': 573,
#   'totalTimeSpentDead': 271,
#   'totalUnitsHealed': 1,
#   'tripleKills': 0,
#   'trueDamageDealt': 2568,
#   'trueDamageDealtToChampions': 398,
#   'trueDamageTaken': 1947,
#   'turretKills': 1,
#   'turretTakedowns': 1,
#   'turretsLost': 9,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 46,
#   'visionWardsBoughtInGame': 5,
#   'wardsKilled': 9,
#   'wardsPlaced': 16,
#   'win': False}]

# %%
match_info_data_df = pd.DataFrame(temp_match_data['info']['participants'])
match_info_data_df
# Out:
#    allInPings  assistMePings  assists  baronKills  basicPings  bountyLevel  \
# 0           1              9       10           0           0            4
# 1           0              2       15           0           0            3
# 2           0              0       11           0           0            1
# 3           1             15       20           0           0            0
# 4           2              7       13           2           0            1
# 5           0              1        7           0           0            0
# 6           0              0       10           0           0            0
# 7          10              7        6           0           0            0
# 8           0              2        2           0           0            0
# 9           0              0        6           0           0            0
#
#                                           challenges  champExperience  \
# 0  {'12AssistStreakCount': 0, 'InfernalScalePicku...            20228
# 1  {'12AssistStreakCount': 0, 'InfernalScalePicku...            18488
# 2  {'12AssistStreakCount': 0, 'InfernalScalePicku...            21305
# 3  {'12AssistStreakCount': 1, 'InfernalScalePicku...            11847
# 4  {'12AssistStreakCount': 0, 'InfernalScalePicku...            16723
# 5  {'12AssistStreakCount': 0, 'InfernalScalePicku...            17321
# 6  {'12AssistStreakCount': 0, 'InfernalScalePicku...            13374
# 7  {'12AssistStreakCount': 0, 'InfernalScalePicku...             8469
# 8  {'12AssistStreakCount': 0, 'InfernalScalePicku...            16609
# 9  {'12AssistStreakCount': 0, 'InfernalScalePicku...            15889
#
#    champLevel  championId  ... turretKills  turretTakedowns  turretsLost  \
# 0          18          42  ...           0                2            5
# 1          18         221  ...           4                4            5
# 2          18         126  ...           5                6            5
# 3          14         526  ...           0                1            5
# 4          17          76  ...           0                4            5
# 5          17         145  ...           2                2            9
# 6          15         154  ...           0                0            9
# 7          11          78  ...           0                1            9
# 8          17          55  ...           2                3            9
# 9          16         150  ...           1                1            9
#
#    unrealKills  visionClearedPings  visionScore  visionWardsBoughtInGame  \
# 0            0                   0           33                        5
# 1            0                   0           48                        6
# 2            0                   0           33                        2
# 3            0                   0          120                       22
# 4            0                   0           48                        8
# 5            0                   0           41                        5
# 6            0                   0           27                        2
# 7            0                   0          122                       25
# 8            0                   0           22                        3
# 9            0                   0           46                        5
#
#    wardsKilled  wardsPlaced    win
# 0            7           15   True
# 1           13           15   True
# 2            7           13   True
# 3            9           67   True
# 4           15            9   True
# 5            9           13  False
# 6            7            3  False
# 7           12           81  False
# 8            8            4  False
# 9            9           16  False
#
# [10 rows x 132 columns]

# %%
match_info_data_dftemp = match_info_data_df[['teamId','summonerId','summonerName','summoner1Id','summoner2Id','teamPosition','championId','kills','deaths','assists','challenges','neutralMinionsKilled','totalMinionsKilled']]
match_info_data_dftemp
# Out:
#    teamId                                         summonerId  \
# 0     100    A3VYN1IIYUgqOkQm5JHNoNMleeOnDwFJ4eX3zTerYcNI_-o
# 1     100    p0dnYl0FKB6DXtwVEZwWBhlEv8LyT-PqpHbKEFqYZEeGlv8
# 2     100    CZGqTYMzumUi6Bwm0NTCsA5cu-VerV4S3_hzJ6dqVV4LV7M
# 3     100    Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s
# 4     100    mgbmIw1zBafdMlezogAxuUtw-_noT4AQFkF3Yq_yTFGD1-c
# 5     200    II88WHvhADMS4U0wHlhKSBOa3oCLsu-uNq7O6OSyp9x-k6U
# 6     200  UzcpEOI0u2opiG1vOwUCmDZxbjtV6ugGZbKfPtxY_ui3OW...
# 7     200    qGQcI3Cb44u_RxUJKMGsAXCgOuB6a9gBilxn97Y9EJhEkwQ
# 8     200    NvWvJxh4_K3dNNr75V1eiAqFQxB9uYN7XZq0tO9F5RaNdgQ
# 9     200  bYUnZu8QojtutWt1Pk5eERcw_CMOsdS1JC5yGpGc5UfuuW...
#
#        summonerName  summoner1Id  summoner2Id teamPosition  championId  kills  \
# 0         dlwlrma22           12            4       MIDDLE          42      8
# 1       sad and bad            4            1       BOTTOM         221      7
# 2             강하다 별           12            4          TOP         126      8
# 3              wway           14            4      UTILITY         526      1
# 4          hhhhbbbb            4           11       JUNGLE          76      4
# 5            viper3            1            4       BOTTOM         145      8
# 6               Zac           11            4       JUNGLE         154      3
# 7               댕청잇           14            4      UTILITY          78      2
# 8      DK ShowMaker           14           12       MIDDLE          55      8
# 9  4238963482364387            4           12          TOP         150      0
#
#    deaths  assists                                         challenges  \
# 0       3       10  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 1       4       15  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 2       5       11  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 3       7       20  {'12AssistStreakCount': 1, 'InfernalScalePicku...
# 4       2       13  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 5       6        7  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 6       5       10  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 7       5        6  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 8       3        2  {'12AssistStreakCount': 0, 'InfernalScalePicku...
# 9       9        6  {'12AssistStreakCount': 0, 'InfernalScalePicku...
#
#    neutralMinionsKilled  totalMinionsKilled
# 0                    28                 298
# 1                    38                 284
# 2                     9                 290
# 3                     0                  27
# 4                   200                  25
# 5                    28                 289
# 6                   143                  33
# 7                     0                  28
# 8                     4                 239
# 9                     4                 246

# %%
match_info_data_dftemp['challenges'].loc[0]
# Out:
# {'12AssistStreakCount': 0,
#  'InfernalScalePickup': 0,
#  'SWARM_DefeatAatrox': 0,
#  'SWARM_DefeatBriar': 0,
#  'SWARM_DefeatMiniBosses': 0,
#  'SWARM_EvolveWeapon': 0,
#  'SWARM_Have3Passives': 0,
#  'SWARM_KillEnemy': 0,
#  'SWARM_PickupGold': 0,
#  'SWARM_ReachLevel50': 0,
#  'SWARM_Survive15Min': 0,
#  'SWARM_WinWith5EvolvedWeapons': 0,
#  'abilityUses': 363,
#  'acesBefore15Minutes': 0,
#  'alliedJungleMonsterKills': 14,
#  'baronBuffGoldAdvantageOverThreshold': 1,
#  'baronTakedowns': 2,
#  'blastConeOppositeOpponentCount': 0,
#  'bountyGold': 0,
#  'buffsStolen': 0,
#  'completeSupportQuestInTime': 0,
#  'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7792911160266691,
#  'controlWardsPlaced': 4,
#  'damagePerMinute': 1080.937236691961,
#  'damageTakenOnTeamPercentage': 0.16676117432207022,
#  'dancedWithRiftHerald': 0,
#  'deathsByEnemyChamps': 3,
#  'dodgeSkillShotsSmallWindow': 0,
#  'doubleAces': 0,
#  'dragonTakedowns': 1,
#  'earliestBaron': 1534.5345089030002,
#  'earliestDragonTakedown': 814.2745124600001,
#  'earlyLaningPhaseGoldExpAdvantage': 0,
#  'effectiveHealAndShielding': 0,
#  'elderDragonKillsWithOpposingSoul': 0,
#  'elderDragonMultikills': 0,
#  'enemyChampionImmobilizations': 0,
#  'enemyJungleMonsterKills': 0,
#  'epicMonsterKillsNearEnemyJungler': 0,
#  'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#  'epicMonsterSteals': 0,
#  'epicMonsterStolenWithoutSmite': 0,
#  'firstTurretKilled': 1,
#  'firstTurretKilledTime': 822.080782276,
#  'fistBumpParticipation': 0,
#  'flawlessAces': 0,
#  'fullTeamTakedown': 9,
#  'gameLength': 1993.215359773,
#  'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#  'goldPerMinute': 482.5339506418338,
#  'hadOpenNexus': 0,
#  'immobilizeAndKillWithAlly': 0,
#  'initialBuffCount': 0,
#  'initialCrabCount': 0,
#  'jungleCsBefore10Minutes': 0,
#  'junglerTakedownsNearDamagedEpicMonster': 0,
#  'kTurretsDestroyedBeforePlatesFall': 0,
#  'kda': 6,
#  'killAfterHiddenWithAlly': 1,
#  'killParticipation': 0.6428571428571429,
#  'killedChampTookFullTeamDamageSurvived': 0,
#  'killingSprees': 2,
#  'killsNearEnemyTurret': 1,
#  'killsOnOtherLanesEarlyJungleAsLaner': 0,
#  'killsOnRecentlyHealedByAramPack': 0,
#  'killsUnderOwnTurret': 0,
#  'killsWithHelpFromEpicMonster': 1,
#  'knockEnemyIntoTeamAndKill': 0,
#  'landSkillShotsEarlyGame': 5,
#  'laneMinionsFirst10Minutes': 93,
#  'laningPhaseGoldExpAdvantage': 0,
#  'legendaryCount': 0,
#  'legendaryItemUsed': [3078, 3004, 3042, 6675, 3036],
#  'lostAnInhibitor': 0,
#  'maxCsAdvantageOnLaneOpponent': 83,
#  'maxKillDeficit': 4,
#  'maxLevelLeadLaneOpponent': 2,
#  'mejaisFullStackInTime': 0,
#  'moreEnemyJungleThanOpponent': 0,
#  'multiKillOneSpell': 0,
#  'multiTurretRiftHeraldCount': 0,
#  'multikills': 1,
#  'multikillsAfterAggressiveFlash': 0,
#  'outerTurretExecutesBefore10Minutes': 0,
#  'outnumberedKills': 0,
#  'outnumberedNexusKill': 0,
#  'perfectDragonSoulsTaken': 0,
#  'perfectGame': 0,
#  'pickKillWithAlly': 12,
#  'playedChampSelectPosition': 1,
#  'poroExplosions': 0,
#  'quickCleanse': 0,
#  'quickFirstTurret': 0,
#  'quickSoloKills': 0,
#  'riftHeraldTakedowns': 0,
#  'saveAllyFromDeath': 0,
#  'scuttleCrabKills': 1,
#  'skillshotsDodged': 16,
#  'skillshotsHit': 44,
#  'snowballsHit': 0,
#  'soloBaronKills': 0,
#  'soloKills': 0,
#  'stealthWardsPlaced': 6,
#  'survivedSingleDigitHpCount': 0,
#  'survivedThreeImmobilizesInFight': 2,
#  'takedownOnFirstTurret': 0,
#  'takedowns': 18,
#  'takedownsAfterGainingLevelAdvantage': 0,
#  'takedownsBeforeJungleMinionSpawn': 0,
#  'takedownsFirstXMinutes': 4,
#  'takedownsInAlcove': 0,
#  'takedownsInEnemyFountain': 0,
#  'teamBaronKills': 2,
#  'teamDamagePercentage': 0.2511556905876511,
#  'teamElderDragonKills': 0,
#  'teamRiftHeraldKills': 1,
#  'tookLargeDamageSurvived': 0,
#  'turretPlatesTaken': 1,
#  'turretTakedowns': 2,
#  'turretsTakenWithRiftHerald': 0,
#  'twentyMinionsIn3SecondsCount': 0,
#  'twoWardsOneSweeperCount': 0,
#  'unseenRecalls': 0,
#  'visionScoreAdvantageLaneOpponent': 0.48219096660614014,
#  'visionScorePerMinute': 0.9951447628639504,
#  'voidMonsterKill': 2,
#  'wardTakedowns': 7,
#  'wardTakedownsBefore20M': 1,
#  'wardsGuarded': 0}
