# %%
import requests
import pandas as pd
import numpy as np

# %%
import requests
 
api_key = "RGAPI-dca92473-57ec-4764-a5b1-33eb5e36bb00"
header = {"X-Riot-Token" : api_key}
 
def league_v4_tier(tier):
    # 솔랭 기준
    queue = 'RANKED_SOLO_5x5'
 
    if tier == 'challenger' :
        url = f"https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/{queue}"
    elif tier == 'grandmaster':
        url = f"https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/{queue}"
    else:
        url = f"https://kr.api.riotgames.com/lol/league/v4/masterleagues/by-queue/{queue}"
        
    return requests.get(url, headers=header)

# %%
challenger_data = pd.DataFrame(league_v4_tier('challenger').json())
grandmaster_data = pd.DataFrame(league_v4_tier('grandmaster').json())
master_data = pd.DataFrame(league_v4_tier('master').json())

# %%
challenger_data
# Out:
#            tier                              leagueId            queue  \
# 0    CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 1    CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 2    CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 3    CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 4    CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# ..          ...                                   ...              ...
# 295  CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 296  CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 297  CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 298  CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
# 299  CHALLENGER  f00d084d-0795-3285-856e-43b2fbda61e4  RANKED_SOLO_5x5
#
#                  name                                            entries
# 0    Syndra's Shadows  {'summonerId': 'HUKstLatFwr8EBgjjk4JhhtPHQmltr...
# 1    Syndra's Shadows  {'summonerId': 'kJXDwQs6qz6iiNsj8kLhKv1SvBjwiu...
# 2    Syndra's Shadows  {'summonerId': 'Rknfx8BguhOFB2MgdU5CnHyfO2w0PA...
# 3    Syndra's Shadows  {'summonerId': 'RS1gV2BSFO7XHo_0MK5HUHlFNfwkfG...
# 4    Syndra's Shadows  {'summonerId': 'hLFSF42aDJL01m75Rht2m7AEiMewLN...
# ..                ...                                                ...
# 295  Syndra's Shadows  {'summonerId': '1QHLaYRc7KjvHbh3YhtWjZ_hpbtyrZ...
# 296  Syndra's Shadows  {'summonerId': 'mV0m3b_zx_OrF95c7uo8nT24DzqfrP...
# 297  Syndra's Shadows  {'summonerId': 'r8W2e2G9Tk8AN_Q-RLq-dsyc7Z71YQ...
# 298  Syndra's Shadows  {'summonerId': '0AOjhJby8KswuGU0mpqVs_C6a3u9Wv...
# 299  Syndra's Shadows  {'summonerId': 'A3VYN1IIYUgqOkQm5JHNoNMleeOnDw...
#
# [300 rows x 5 columns]

# %%
grandmaster_data
# Out:
#             tier                              leagueId            queue  \
# 0    GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 1    GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 2    GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 3    GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 4    GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# ..           ...                                   ...              ...
# 695  GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 696  GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 697  GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 698  GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
# 699  GRANDMASTER  31071602-a09e-3e31-93da-ba9a0f2268b3  RANKED_SOLO_5x5
#
#                    name                                            entries
# 0    Nocturne's Hunters  {'summonerId': 'ovpt-sgPwmTzb3WVg92MsTjL5zjB5r...
# 1    Nocturne's Hunters  {'summonerId': 'CeUDrQzn7nT1bbSVqu4TbZbCYVkxVa...
# 2    Nocturne's Hunters  {'summonerId': 'VEohdMTElJi1AZQfwW-FH7RabxKSpP...
# 3    Nocturne's Hunters  {'summonerId': 'dNxsb_lSq0Bj__fnetLzjKMQDhDd6g...
# 4    Nocturne's Hunters  {'summonerId': 'jWzRbGmnCp5ruPvkwr9ZYlQbK9ZzGJ...
# ..                  ...                                                ...
# 695  Nocturne's Hunters  {'summonerId': 'sIUFzfQCpx4sjS1bJOCzpWlWElrsLy...
# 696  Nocturne's Hunters  {'summonerId': '7ePH3xfGlX1NTbQPWcdE9IDRLTKVsJ...
# 697  Nocturne's Hunters  {'summonerId': 'Xfc9La7Nnqg0acA3Z2419l71iECTPt...
# 698  Nocturne's Hunters  {'summonerId': 'DntR0VN7VuUrMIe9JWW_mAJxd7cY-O...
# 699  Nocturne's Hunters  {'summonerId': 'JEOuq3h66IQbf56Z1c2um6Ozc_Q97u...
#
# [700 rows x 5 columns]

# %%
master_data
# Out:
#          tier                              leagueId            queue  \
# 0      MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 1      MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 2      MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 3      MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 4      MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# ...       ...                                   ...              ...
# 13367  MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 13368  MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 13369  MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 13370  MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
# 13371  MASTER  64de9d2d-89e0-3698-a7cd-a9b7e04ef3b6  RANKED_SOLO_5x5
#
#                            name  \
# 0      Vladimir's Swashbucklers
# 1      Vladimir's Swashbucklers
# 2      Vladimir's Swashbucklers
# 3      Vladimir's Swashbucklers
# 4      Vladimir's Swashbucklers
# ...                         ...
# 13367  Vladimir's Swashbucklers
# 13368  Vladimir's Swashbucklers
# 13369  Vladimir's Swashbucklers
# 13370  Vladimir's Swashbucklers
# 13371  Vladimir's Swashbucklers
#
#                                                  entries
# 0      {'summonerId': '8n8t6w63OgSyp2fpzX9o7gREtbQXyY...
# 1      {'summonerId': 'eU4DFd8KimMCkDbF4CijaGWEWxq_Nm...
# 2      {'summonerId': 'ycVN8k2Yz76R3TBpQN-g7iFI-cpzZb...
# 3      {'summonerId': '7TuzWFGsmnVv588hANuiQHL2hopBFr...
# 4      {'summonerId': 'o655U-oOdHAQWKCQsvr84FkUfbq4pu...
# ...                                                  ...
# 13367  {'summonerId': 'r6ZRYIymufN-8Jvhk2ThmNcRwKtq2H...
# 13368  {'summonerId': 'HG5mAD4YJBbaF-f8iLll7gWQZ78nRw...
# 13369  {'summonerId': 'ggwdJcf8XmX30XhUKLZVvl13KgJ6Q0...
# 13370  {'summonerId': '_SlWF9OaghaN8rwCJvO1VGpVW4WLvP...
# 13371  {'summonerId': 'jZlYlHvTXZPgbKYAIo6irhqzI0nUgl...
#
# [13372 rows x 5 columns]

# %%
challenger_df = pd.DataFrame([challenger_data['entries'][0]])
data_size = len(challenger_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([challenger_data['entries'][i]])
    challenger_df = pd.concat([challenger_df,append_df],ignore_index = True)

challenger_df['tier'] = 'CHALLENGER'
challenger_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0      HUKstLatFwr8EBgjjk4JhhtPHQmltr4u6aZ4FFhm8rblEfk          1160    I
# 1    kJXDwQs6qz6iiNsj8kLhKv1SvBjwiuQK3DVI9AshS8rgjn...          1241    I
# 2      Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s          1758    I
# 3    RS1gV2BSFO7XHo_0MK5HUHlFNfwkfGAVqnv0rURXx-ULc5...          1091    I
# 4       hLFSF42aDJL01m75Rht2m7AEiMewLNMiaThjrVE6cagc2g          1138    I
# ..                                                 ...           ...  ...
# 295    1QHLaYRc7KjvHbh3YhtWjZ_hpbtyrZwULjMzZa0WLUV34H0          1068    I
# 296    mV0m3b_zx_OrF95c7uo8nT24DzqfrPlhJM30tRDxZMgKxqY          1144    I
# 297    r8W2e2G9Tk8AN_Q-RLq-dsyc7Z71YQKeyWh-bXkTDElQYVs          1169    I
# 298  0AOjhJby8KswuGU0mpqVs_C6a3u9Wvu4rCBPf5M-OVsONM...          1346    I
# 299    A3VYN1IIYUgqOkQm5JHNoNMleeOnDwFJ4eX3zTerYcNI_-o          1346    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak        tier
# 0     301     258    False     False       False       True  CHALLENGER
# 1     205     162     True     False       False      False  CHALLENGER
# 2     173     105     True     False       False      False  CHALLENGER
# 3     203     158    False     False        True      False  CHALLENGER
# 4     302     267     True     False       False      False  CHALLENGER
# ..    ...     ...      ...       ...         ...        ...         ...
# 295   226     186    False     False        True      False  CHALLENGER
# 296   139      98     True     False       False      False  CHALLENGER
# 297   164     119    False     False        True      False  CHALLENGER
# 298   243     190    False     False       False      False  CHALLENGER
# 299   108      55    False     False       False      False  CHALLENGER
#
# [300 rows x 10 columns]

# %%
grandmaster_df = pd.DataFrame([grandmaster_data['entries'][0]])
data_size = len(grandmaster_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([grandmaster_data['entries'][i]])
    grandmaster_df = pd.concat([grandmaster_df,append_df],ignore_index = True)

grandmaster_df['tier'] = 'GRANDMASTER'
grandmaster_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0    ovpt-sgPwmTzb3WVg92MsTjL5zjB5rRYlpzRQua9feTgQi...           693    I
# 1      CeUDrQzn7nT1bbSVqu4TbZbCYVkxVacldIX9J6SaDSC_pUE           750    I
# 2       VEohdMTElJi1AZQfwW-FH7RabxKSpPrl3oHZCh-oIB5Guw           821    I
# 3      dNxsb_lSq0Bj__fnetLzjKMQDhDd6guXeAmBF6z1u-Lb8Xo           923    I
# 4    jWzRbGmnCp5ruPvkwr9ZYlQbK9ZzGJHpWa7BjLQrk1hFn5...           843    I
# ..                                                 ...           ...  ...
# 695    sIUFzfQCpx4sjS1bJOCzpWlWElrsLy7ZjcIHMGd5jvHkMfI           771    I
# 696  7ePH3xfGlX1NTbQPWcdE9IDRLTKVsJars6FyU00Scb6qlB...           740    I
# 697  Xfc9La7Nnqg0acA3Z2419l71iECTPtSi4GWU1Qk2XyZQ8m...           893    I
# 698    DntR0VN7VuUrMIe9JWW_mAJxd7cY-OyT5AQ6shrmPx2GOXM           911    I
# 699    JEOuq3h66IQbf56Z1c2um6Ozc_Q97u7ZgI9NCb-zhsxSjMA           995    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak         tier
# 0     428     407     True     False       False      False  GRANDMASTER
# 1     109      73    False     False       False      False  GRANDMASTER
# 2     143     109    False     False        True      False  GRANDMASTER
# 3     303     272     True     False       False      False  GRANDMASTER
# 4     162     126    False     False       False      False  GRANDMASTER
# ..    ...     ...      ...       ...         ...        ...          ...
# 695   226     195    False     False       False       True  GRANDMASTER
# 696    93      55    False     False        True       True  GRANDMASTER
# 697   197     142    False     False       False      False  GRANDMASTER
# 698   169     139    False     False        True      False  GRANDMASTER
# 699   310     272     True     False       False      False  GRANDMASTER
#
# [700 rows x 10 columns]

# %%
master_df = pd.DataFrame([master_data['entries'][0]])
data_size = len(master_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([master_data['entries'][i]])
    master_df = pd.concat([master_df,append_df],ignore_index = True)

master_df['tier'] = 'MASTER'
master_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0      8n8t6w63OgSyp2fpzX9o7gREtbQXyYMwIO_QPRZxs5rshZ...            58    I
# 1      eU4DFd8KimMCkDbF4CijaGWEWxq_Nm8Sjbv7iZM6zR39BE...            79    I
# 2        ycVN8k2Yz76R3TBpQN-g7iFI-cpzZb8aEE28z-7ihg6c5fY           286    I
# 3      7TuzWFGsmnVv588hANuiQHL2hopBFrwpiFGYanOxqpS1dC...             0    I
# 4        o655U-oOdHAQWKCQsvr84FkUfbq4puu2w_dSLLhhD0yl-bQ             0    I
# ...                                                  ...           ...  ...
# 13367    r6ZRYIymufN-8Jvhk2ThmNcRwKtq2HhycLZUuYP4Z2aXCu4           274    I
# 13368    HG5mAD4YJBbaF-f8iLll7gWQZ78nRwVQF38mQ9IkZ0Of4gI             9    I
# 13369  ggwdJcf8XmX30XhUKLZVvl13KgJ6Q0f4mNorVUMtAAAQOL...            94    I
# 13370    _SlWF9OaghaN8rwCJvO1VGpVW4WLvPkejyRIIBcPmbWvcJs           474    I
# 13371  jZlYlHvTXZPgbKYAIo6irhqzI0nUglJVMC47T2fakjTT_t...           170    I
#
#        wins  losses  veteran  inactive  freshBlood  hotStreak    tier
# 0       184     177    False     False        True       True  MASTER
# 1        34      22    False     False        True      False  MASTER
# 2       238     230     True     False       False      False  MASTER
# 3       158     141    False     False        True      False  MASTER
# 4        97      95    False     False        True      False  MASTER
# ...     ...     ...      ...       ...         ...        ...     ...
# 13367    39      24    False     False       False      False  MASTER
# 13368    27      16    False     False        True      False  MASTER
# 13369   148      99    False     False        True      False  MASTER
# 13370   122     100    False     False       False      False  MASTER
# 13371   498     492     True     False       False      False  MASTER
#
# [13372 rows x 10 columns]

# %%
top_class_df = pd.concat([challenger_df,grandmaster_df,master_df],ignore_index = True)
top_class_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0        HUKstLatFwr8EBgjjk4JhhtPHQmltr4u6aZ4FFhm8rblEfk          1160    I
# 1      kJXDwQs6qz6iiNsj8kLhKv1SvBjwiuQK3DVI9AshS8rgjn...          1241    I
# 2        Rknfx8BguhOFB2MgdU5CnHyfO2w0PAQdI2ZG8U4eJ2ior3s          1758    I
# 3      RS1gV2BSFO7XHo_0MK5HUHlFNfwkfGAVqnv0rURXx-ULc5...          1091    I
# 4         hLFSF42aDJL01m75Rht2m7AEiMewLNMiaThjrVE6cagc2g          1138    I
# ...                                                  ...           ...  ...
# 14367    r6ZRYIymufN-8Jvhk2ThmNcRwKtq2HhycLZUuYP4Z2aXCu4           274    I
# 14368    HG5mAD4YJBbaF-f8iLll7gWQZ78nRwVQF38mQ9IkZ0Of4gI             9    I
# 14369  ggwdJcf8XmX30XhUKLZVvl13KgJ6Q0f4mNorVUMtAAAQOL...            94    I
# 14370    _SlWF9OaghaN8rwCJvO1VGpVW4WLvPkejyRIIBcPmbWvcJs           474    I
# 14371  jZlYlHvTXZPgbKYAIo6irhqzI0nUglJVMC47T2fakjTT_t...           170    I
#
#        wins  losses  veteran  inactive  freshBlood  hotStreak        tier
# 0       301     258    False     False       False       True  CHALLENGER
# 1       205     162     True     False       False      False  CHALLENGER
# 2       173     105     True     False       False      False  CHALLENGER
# 3       203     158    False     False        True      False  CHALLENGER
# 4       302     267     True     False       False      False  CHALLENGER
# ...     ...     ...      ...       ...         ...        ...         ...
# 14367    39      24    False     False       False      False      MASTER
# 14368    27      16    False     False        True      False      MASTER
# 14369   148      99    False     False        True      False      MASTER
# 14370   122     100    False     False       False      False      MASTER
# 14371   498     492     True     False       False      False      MASTER
#
# [14372 rows x 10 columns]

# %%
top_class_df['summonerId'].loc[0]
# Out:
# 'HUKstLatFwr8EBgjjk4JhhtPHQmltr4u6aZ4FFhm8rblEfk'

# %%
import requests
 
api_key = "RGAPI-dca92473-57ec-4764-a5b1-33eb5e36bb00"
header = {"X-Riot-Token" : api_key}

def summoners(encryptedSummonerId):
    url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/{encryptedSummonerId}"
    
    return requests.get(url, headers = header)

# %%
encryptedSummonerId = top_class_df['summonerId'].loc[0]

temp_summoners = summoners(encryptedSummonerId).json()
temp_summoners
# Out:
# {'id': 'HUKstLatFwr8EBgjjk4JhhtPHQmltr4u6aZ4FFhm8rblEfk',
#  'accountId': '4IIkEKD1aVBvQep0k5FhVNo1sZqR-jHYSiqRvJFAwAMkwcEYq9E3WAmI',
#  'puuid': 'Zdu9sOJuQSRyeVcivC8gdXfJpgPwMA14gRStmTqtsjH2S7NAw5s71lTgARV7gtuPcPkr-iSsog5WWQ',
#  'profileIconId': 4417,
#  'revisionDate': 1721935068858,
#  'summonerLevel': 927}

# %%
temp_summoners['puuid']
# Out:
# 'Zdu9sOJuQSRyeVcivC8gdXfJpgPwMA14gRStmTqtsjH2S7NAw5s71lTgARV7gtuPcPkr-iSsog5WWQ'

# %%
def match_list(puuid):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?type=ranked&start={0}&count={100}"
    
    return requests.get(url, headers=header)

# %%
puuid = temp_summoners['puuid']

temp_match_list = match_list(puuid).json()
temp_match_list
# Out:
# ['KR_7180464646',
#  'KR_7180384840',
#  'KR_7180328694',
#  'KR_7180091023',
#  'KR_7179875612',
#  'KR_7179694375',
#  'KR_7177935751',
#  'KR_7177914837',
#  'KR_7177772222',
#  'KR_7177705326',
#  'KR_7177630451',
#  'KR_7177373896',
#  'KR_7177079700',
#  'KR_7176700657',
#  'KR_7176547667',
#  'KR_7175077865',
#  'KR_7175036865',
#  'KR_7174939037',
#  'KR_7174885317',
#  'KR_7174705359',
#  'KR_7174363779',
#  'KR_7171950910',
#  'KR_7171873995',
#  'KR_7168643151',
#  'KR_7160817079',
#  'KR_7155419320',
#  'KR_7155327787',
#  'KR_7155299237',
#  'KR_7155108491',
#  'KR_7154687439',
#  'KR_7154426935',
#  'KR_7153910206',
#  'KR_7151506089',
#  'KR_7151458557',
#  'KR_7151362579',
#  'KR_7151351197',
#  'KR_7151103388',
#  'KR_7151030767',
#  'KR_7150956555',
#  'KR_7150906848',
#  'KR_7150350794',
#  'KR_7150340315',
#  'KR_7150323250',
#  'KR_7150274943',
#  'KR_7150244288',
#  'KR_7150183769',
#  'KR_7150132896',
#  'KR_7148248823',
#  'KR_7148235859',
#  'KR_7148232323',
#  'KR_7148204730',
#  'KR_7148185152',
#  'KR_7148158177',
#  'KR_7148119073',
#  'KR_7147955453',
#  'KR_7147899938',
#  'KR_7147828544',
#  'KR_7146682786',
#  'KR_7146660041',
#  'KR_7146605948',
#  'KR_7146529008',
#  'KR_7146308612',
#  'KR_7146190417',
#  'KR_7145452099',
#  'KR_7145413118',
#  'KR_7145365405',
#  'KR_7145330795',
#  'KR_7145313053',
#  'KR_7145295350',
#  'KR_7145253224',
#  'KR_7145232814',
#  'KR_7145215829',
#  'KR_7144032579',
#  'KR_7144023516',
#  'KR_7144015085',
#  'KR_7144006062',
#  'KR_7143940430',
#  'KR_7143868901',
#  'KR_7143823448',
#  'KR_7143788830',
#  'KR_7143707007',
#  'KR_7143645937',
#  'KR_7143597138',
#  'KR_7143548068',
#  'KR_7142959943',
#  'KR_7142954479',
#  'KR_7142942688',
#  'KR_7142886359',
#  'KR_7142859675',
#  'KR_7142815002',
#  'KR_7142590331',
#  'KR_7141778327',
#  'KR_7140677213',
#  'KR_7140631840',
#  'KR_7140611752',
#  'KR_7140548598',
#  'KR_7140494447',
#  'KR_7140447633',
#  'KR_7136496793',
#  'KR_7136490179']

# %%
import requests
 
api_key = "RGAPI-dca92473-57ec-4764-a5b1-33eb5e36bb00"
header = {"X-Riot-Token" : api_key}
 
def match(matchId):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{matchId}"
    
    return requests.get(url, headers=header)

# %%
matchId = temp_match_list[0]
temp_match_data = match(matchId).json()
temp_match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_7180464646',
#   'participants': ['wyLAxR9edOThxUqpqOn15LT1nm8_0TaXHym7TxeEeVieyEjAnvMjVpVylg4HQXXrYAweazE_wNJ3_Q',
#    'DqXnoKoSfaioqNY4naS3YTOJ0_yPRbTF_K2N6z6FJAMvABZ_uJpsO9a49hvWZFqSJs9C8_fbp1kJ9Q',
#    '0FBMODS1toxMv1XDsdt6A49mp3ZNYVA5xOD8gO8AnOEklTEPqNOlVT2LRuGWm-uY0ZvAIQbgltENzA',
#    'IqFsLwBHNZU25ocjV_7rp6QjwQ3hCcvguWfcynXV7EGvo3NWNtpQo7S-ZXNMMnCTKbQwGEqdxHbDxg',
#    'LMJ7J_qRHk0_4MQS91JY_jMaH9xQ1YMjFGHw8QcEjR-w2bdrQ9tgA-vDDvk5UcPmTba1h5vpV21Clg',
#    'LPd1KERkv3Ol60alze92LTflCrJKPyEUy-nHV0Rh50KeTi1pVZif8JwZWuX-z8KlAt6UpYy-EPEZHg',
#    '9BdGvJe5JDLTVCmSDpvojDdj8wFvJIQBFIcXPalFUT3iTbbbP8zfGX7A1Dt9olySqul-QoaWHqZRJw',
#    'L_UhGnM0aqfnWUPuI7_jMSNqvzRRSGYpHp9B49qM4EjC1zFCiXSJURFc8Aq9rn3lxAAJ74SOAv2ffA',
#    'Zdu9sOJuQSRyeVcivC8gdXfJpgPwMA14gRStmTqtsjH2S7NAw5s71lTgARV7gtuPcPkr-iSsog5WWQ',
#    '2lRHMhM5p3ra5nQB4lDx3WcDOErS0EIc3LuoroOGsKD8_b_57nW8Tde0gjxzlefFdi7KZVn4aFmQKA']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1721933710119,
#   'gameDuration': 1343,
#   'gameEndTimestamp': 1721935066933,
#   'gameId': 7180464646,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-7180464646',
#   'gameStartTimestamp': 1721933723498,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '14.14.603.4237',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 5,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 284,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 150,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7595490347402619,
#      'controlWardsPlaced': 3,
#      'damagePerMinute': 806.0057799795459,
#      'damageTakenOnTeamPercentage': 0.1468382221225847,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 22,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1343.718360993,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 403.22274981760296,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.25,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.5,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 3,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 63,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6698, 6697],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 0,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 13,
#      'skillshotsHit': 20,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 1,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 9,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.22109915392925802,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.6875826120376587,
#      'visionScorePerMinute': 0.7522345652460666,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 0},
#     'champExperience': 10995,
#     'champLevel': 13,
#     'championId': 246,
#     'championName': 'Qiyana',
#     'championTransform': 0,
#     'commandPings': 22,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 636,
#     'damageDealtToObjectives': 636,
#     'damageDealtToTurrets': 636,
#     'damageSelfMitigated': 7928,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 9,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'getBackPings': 11,
#     'goldEarned': 9030,
#     'goldSpent': 8450,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6698,
#     'item1': 3158,
#     'item2': 1037,
#     'item3': 6697,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 19,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 722,
#     'magicDamageDealt': 8093,
#     'magicDamageDealtToChampions': 1603,
#     'magicDamageTaken': 7466,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 11,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 1033, 'var2': 0, 'var3': 0},
#         {'perk': 8143, 'var1': 606, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 10, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8017, 'var1': 1018, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 1612, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 92024,
#     'physicalDamageDealtToChampions': 15753,
#     'physicalDamageTaken': 7728,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6,
#     'pushPings': 0,
#     'puuid': 'wyLAxR9edOThxUqpqOn15LT1nm8_0TaXHym7TxeEeVieyEjAnvMjVpVylg4HQXXrYAweazE_wNJ3_Q',
#     'quadraKills': 0,
#     'riotIdGameName': 'chendian',
#     'riotIdTagline': 'KR1',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 107,
#     'spell2Casts': 142,
#     'spell3Casts': 28,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 12,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'JIhwtqL3wQVmR5q0WPqzH6bPu-HLhYgekezYaodwEs0-oBVMeii3v6LenA',
#     'summonerLevel': 141,
#     'summonerName': 'chendian',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 16,
#     'timePlayed': 1343,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 100871,
#     'totalDamageDealtToChampions': 18050,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 16564,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 871,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 153,
#     'totalTimeCCDealt': 79,
#     'totalTimeSpentDead': 97,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 753,
#     'trueDamageDealtToChampions': 693,
#     'trueDamageTaken': 1369,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 16,
#     'visionWardsBoughtInGame': 3,
#     'wardsKilled': 3,
#     'wardsPlaced': 4,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 5,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 208,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.622953316934962,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 719.3634347263231,
#      'damageTakenOnTeamPercentage': 0.13339783916543554,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 5,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 57.952423095703125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 21,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1343.718360993,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 358.7987677947727,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.4,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.3888888888888889,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 59,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [2503, 6653],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 8,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 7,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 12,
#      'skillshotsHit': 11,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 7,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 1,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 7,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1973318935624399,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.1443764567375183,
#      'visionScorePerMinute': 0.7939695425037812,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 0},
#     'champExperience': 10411,
#     'champLevel': 13,
#     'championId': 910,
#     'championName': 'Hwei',
#     'championTransform': 0,
#     'commandPings': 6,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 1742,
#     'damageDealtToObjectives': 1742,
#     'damageDealtToTurrets': 1742,
#     'damageSelfMitigated': 7951,
#     'dangerPings': 0,
#     'deaths': 5,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'getBackPings': 0,
#     'goldEarned': 8035,
#     'goldSpent': 7450,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6653,
#     'item1': 3158,
#     'item2': 2503,
#     'item3': 1052,
#     'item4': 0,
#     'item5': 1056,
#     'item6': 3363,
#     'itemsPurchased': 19,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 455,
#     'magicDamageDealt': 89004,
#     'magicDamageDealtToChampions': 15064,
#     'magicDamageTaken': 5279,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 2,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8229, 'var1': 1106, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 890, 'var3': 0},
#         {'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 486, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5}],
#        'style': 8300}]},
#     'physicalDamageDealt': 12587,
#     'physicalDamageDealtToChampions': 789,
#     'physicalDamageTaken': 9616,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3791,
#     'pushPings': 0,
#     'puuid': 'DqXnoKoSfaioqNY4naS3YTOJ0_yPRbTF_K2N6z6FJAMvABZ_uJpsO9a49hvWZFqSJs9C8_fbp1kJ9Q',
#     'quadraKills': 0,
#     'riotIdGameName': '오직 유 빛날 빈',
#     'riotIdTagline': 'KR1',
#     'role': 'DUO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 97,
#     'spell2Casts': 59,
#     'spell3Casts': 44,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 12,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'clff7WXV6JSjzypKfp79OjdTsyjKjG9TjgR1mQioJ_DRGQ',
#     'summonerLevel': 567,
#     'summonerName': '오직 유 빛날 빈',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 21,
#     'timePlayed': 1343,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 103133,
#     'totalDamageDealtToChampions': 16110,
#     'totalDamageShieldedOnTeammates': 57,
#     'totalDamageTaken': 15047,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1718,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 180,
#     'totalTimeCCDealt': 703,
#     'totalTimeSpentDead': 80,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1541,
#     'trueDamageDealtToChampions': 255,
#     'trueDamageTaken': 152,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 3,
#     'wardsPlaced': 10,
#     'win': False},
#    {'allInPings': 11,
#     'assistMePings': 9,
#     'assists': 3,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 145,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 59,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5961546610355302,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 706.4082750419415,
#      'damageTakenOnTeamPercentage': 0.20836055560478564,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 7,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1343.718360993,
#      'goldPerMinute': 431.460304214389,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 65.75000008940697,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.2857142857142858,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.5,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnLanersEarlyJungleAsJungler': 2,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 4,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6676, 6673],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 7.750000029802322,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -45.000000059604645,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 1,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 16,
#      'skillshotsHit': 27,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 3,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 9,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.19377810410288054,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.15824973583221436,
#      'visionScorePerMinute': 0.9904152505001195,
#      'voidMonsterKill': 3,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 0},
#     'champExperience': 10639,
#     'champLevel': 13,
#     'championId': 104,
#     'championName': 'Graves',
#     'championTransform': 0,
#     'commandPings': 11,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 429,
#     'damageDealtToObjectives': 8070,
#     'damageDealtToTurrets': 429,
#     'damageSelfMitigated': 17372,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 10,
#     'enemyVisionPings': 8,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'getBackPings': 26,
#     'goldEarned': 9662,
#     'goldSpent': 9150,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3123,
#     'item1': 1036,
#     'item2': 1036,
#     'item3': 3047,
#     'item4': 6673,
#     'item5': 6676,
#     'item6': 3364,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 367,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 658,
#     'magicDamageDealt': 2611,
#     'magicDamageDealtToChampions': 449,
#     'magicDamageTaken': 6563,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 117,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 40,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 1887, 'var2': 1520, 'var3': 0},
#         {'perk': 9111, 'var1': 393, 'var2': 180, 'var3': 0},
#         {'perk': 9104, 'var1': 12, 'var2': 10, 'var3': 0},
#         {'perk': 8014, 'var1': 331, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 126581,
#     'physicalDamageDealtToChampions': 14052,
#     'physicalDamageTaken': 15959,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5491,
#     'pushPings': 0,
#     'puuid': '0FBMODS1toxMv1XDsdt6A49mp3ZNYVA5xOD8gO8AnOEklTEPqNOlVT2LRuGWm-uY0ZvAIQbgltENzA',
#     'quadraKills': 0,
#     'riotIdGameName': 'lose jug',
#     'riotIdTagline': '315',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 73,
#     'spell2Casts': 31,
#     'spell3Casts': 32,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 16,
#     'summoner2Id': 11,
#     'summonerId': 'KcKYsWQhS1ZrC8XjmFGYn6-SEUMRJnZG1BOpMqR9TbpX6hfDEuHsX2rgLg',
#     'summonerLevel': 250,
#     'summonerName': 'jin jiu shu',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 16,
#     'timePlayed': 1343,
#     'totalAllyJungleMinionsKilled': 88,
#     'totalDamageDealt': 178577,
#     'totalDamageDealtToChampions': 15820,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 23504,
#     'totalEnemyJungleMinionsKilled': 8,
#     'totalHeal': 9097,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 40,
#     'totalTimeCCDealt': 631,
#     'totalTimeSpentDead': 185,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 49384,
#     'trueDamageDealtToChampions': 1318,
#     'trueDamageTaken': 981,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 22,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 3,
#     'wardsPlaced': 7,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 4,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 295,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 1125.5255996835922,
#      'damageTakenOnTeamPercentage': 0.3342465195574944,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 6,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 43,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1343.718360993,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 346.876604816337,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.5,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.5,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 6,
#      'landSkillShotsEarlyGame': 4,
#      'laneMinionsFirst10Minutes': 53,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6610],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 2,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 7,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 13,
#      'skillshotsHit': 18,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 9,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 5,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.30874810577918954,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.2770256996154785,
#      'visionScorePerMinute': 0.6263293024394452,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 3,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 1},
#     'champExperience': 9397,
#     'champLevel': 12,
#     'championId': 266,
#     'championName': 'Aatrox',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 720,
#     'damageDealtToObjectives': 720,
#     'damageDealtToTurrets': 720,
#     'damageSelfMitigated': 24081,
#     'dangerPings': 0,
#     'deaths': 6,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'getBackPings': 0,
#     'goldEarned': 7768,
#     'goldSpent': 7375,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 0,
#     'item1': 3047,
#     'item2': 6610,
#     'item3': 2021,
#     'item4': 1037,
#     'item5': 1028,
#     'item6': 3364,
#     'itemsPurchased': 21,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'TOP',
#     'largestCriticalStrike': 310,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 362,
#     'magicDamageDealt': 5574,
#     'magicDamageDealtToChampions': 4011,
#     'magicDamageTaken': 7862,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 5,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 915, 'var2': 0, 'var3': 0},
#         {'perk': 9101, 'var1': 815, 'var2': 0, 'var3': 0},
#         {'perk': 9105, 'var1': 15, 'var2': 40, 'var3': 0},
#         {'perk': 8299, 'var1': 1112, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8444, 'var1': 1493, 'var2': 0, 'var3': 0},
#         {'perk': 8451, 'var1': 161, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 75283,
#     'physicalDamageDealtToChampions': 20186,
#     'physicalDamageTaken': 22862,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6631,
#     'pushPings': 0,
#     'puuid': 'IqFsLwBHNZU25ocjV_7rp6QjwQ3hCcvguWfcynXV7EGvo3NWNtpQo7S-ZXNMMnCTKbQwGEqdxHbDxg',
#     'quadraKills': 0,
#     'riotIdGameName': 'NS Ady',
#     'riotIdTagline': '안성탕면맨',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 142,
#     'spell2Casts': 36,
#     'spell3Casts': 109,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 12,
#     'summonerId': 'uWNS7eqHJHkSprdxLt6W3QD2FHR3irAIm3Pg06RdCPfapvo',
#     'summonerLevel': 641,
#     'summonerName': 'FA ady',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 26,
#     'timePlayed': 1343,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 85170,
#     'totalDamageDealtToChampions': 25206,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 37704,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 14348,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 115,
#     'totalTimeCCDealt': 270,
#     'totalTimeSpentDead': 118,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 4313,
#     'trueDamageDealtToChampions': 1008,
#     'trueDamageTaken': 6979,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 14,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 3,
#     'wardsPlaced': 6,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 2,
#     'assists': 9,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 119,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 300,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 1,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.24458936444696838,
#      'controlWardsPlaced': 6,
#      'damagePerMinute': 288.1463193774257,
#      'damageTakenOnTeamPercentage': 0.1771568635496997,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 3150.876708984375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 19,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1343.718360993,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 274.0005066587521,
#      'hadOpenNexus': 0,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 1.1111111111111112,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.5555555555555556,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 11,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3869, 3050],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 4,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 14,
#      'skillshotsHit': 29,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 17,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 10,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 7,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.07904274262623197,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.3432748317718506,
#      'visionScorePerMinute': 3.479819624193566,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 11,
#      'wardTakedownsBefore20M': 11,
#      'wardsGuarded': 0},
#     'champExperience': 6332,
#     'champLevel': 10,
#     'championId': 497,
#     'championName': 'Rakan',
#     'championTransform': 0,
#     'commandPings': 22,
#     'consumablesPurchased': 9,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 55,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 16386,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 6,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 33,
#     'enemyVisionPings': 25,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'getBackPings': 2,
#     'goldEarned': 6136,
#     'goldSpent': 5975,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3158,
#     'item1': 3869,
#     'item2': 2055,
#     'item3': 1011,
#     'item4': 3050,
#     'item5': 3066,
#     'item6': 3364,
#     'itemsPurchased': 23,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 454,
#     'magicDamageDealt': 5742,
#     'magicDamageDealtToChampions': 4908,
#     'magicDamageTaken': 4169,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 17,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5010, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8465, 'var1': 1089, 'var2': 0, 'var3': 0},
#         {'perk': 8463, 'var1': 443, 'var2': 0, 'var3': 0},
#         {'perk': 8473, 'var1': 428, 'var2': 0, 'var3': 0},
#         {'perk': 8451, 'var1': 132, 'var2': 0, 'var3': 0}],
#        'style': 8400},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8136, 'var1': 12, 'var2': 30, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 2415,
#     'physicalDamageDealtToChampions': 797,
#     'physicalDamageTaken': 14117,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6591,
#     'pushPings': 0,
#     'puuid': 'LMJ7J_qRHk0_4MQS91JY_jMaH9xQ1YMjFGHw8QcEjR-w2bdrQ9tgA-vDDvk5UcPmTba1h5vpV21Clg',
#     'quadraKills': 0,
#     'riotIdGameName': 'player1',
#     'riotIdTagline': 'wywq',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 43,
#     'spell2Casts': 32,
#     'spell3Casts': 38,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 14,
#     'summonerId': 'vJ3pjMTqXEMg_LZn_910Tv7QZ8mfuxWt4LjBx1t3Pen6xB2QN4AbsXEEeA',
#     'summonerLevel': 60,
#     'summonerName': '',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 20,
#     'timePlayed': 1343,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 10779,
#     'totalDamageDealtToChampions': 6453,
#     'totalDamageShieldedOnTeammates': 1634,
#     'totalDamageTaken': 19984,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3671,
#     'totalHealsOnTeammates': 1516,
#     'totalMinionsKilled': 19,
#     'totalTimeCCDealt': 69,
#     'totalTimeSpentDead': 133,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 2621,
#     'trueDamageDealtToChampions': 747,
#     'trueDamageTaken': 1696,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 77,
#     'visionWardsBoughtInGame': 7,
#     'wardsKilled': 11,
#     'wardsPlaced': 35,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 6,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 6,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 250,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 4,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.30136685467834395,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 1492.9415471166956,
#      'damageTakenOnTeamPercentage': 0.2604416292184519,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1249.063337258,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 3358.552734375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 2,
#      'enemyJungleMonsterKills': 2,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 916.222228057,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 0,
#      'gameLength': 1343.718360993,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 580.4116746923077,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 1,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.75,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.4838709677419355,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 2,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 4,
#      'laneMinionsFirst10Minutes': 70,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3074, 3078, 6333],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 72.60000002384186,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
# ...
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 12,
#      'skillshotsHit': 14,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 11,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 7,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.19453819057979413,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.16873836517333984,
#      'visionScorePerMinute': 0.9279426222227579,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 8,
#      'wardTakedownsBefore20M': 7,
#      'wardsGuarded': 1},
#     'champExperience': 11166,
#     'champLevel': 13,
#     'championId': 145,
#     'championName': 'Kaisa',
#     'championTransform': 0,
#     'commandPings': 8,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 1453,
#     'damageDealtToObjectives': 16645,
#     'damageDealtToTurrets': 1453,
#     'damageSelfMitigated': 10319,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 11,
#     'enemyVisionPings': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'getBackPings': 1,
#     'goldEarned': 9875,
#     'goldSpent': 9000,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3087,
#     'item1': 3124,
#     'item2': 1026,
#     'item3': 3006,
#     'item4': 1055,
#     'item5': 3108,
#     'item6': 3363,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 593,
#     'magicDamageDealt': 32772,
#     'magicDamageDealtToChampions': 6484,
#     'magicDamageTaken': 9088,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 14,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 25,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2197, 'var2': 2129, 'var3': 0},
#         {'perk': 9101, 'var1': 1154, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 12, 'var2': 20, 'var3': 0},
#         {'perk': 8017, 'var1': 921, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 94072,
#     'physicalDamageDealtToChampions': 12254,
#     'physicalDamageTaken': 9181,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4417,
#     'pushPings': 0,
#     'puuid': 'Zdu9sOJuQSRyeVcivC8gdXfJpgPwMA14gRStmTqtsjH2S7NAw5s71lTgARV7gtuPcPkr-iSsog5WWQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'Pangjin',
#     'riotIdTagline': 'kr2',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 64,
#     'spell2Casts': 33,
#     'spell3Casts': 49,
#     'spell4Casts': 4,
#     'subteamPlacement': 0,
#     'summoner1Casts': 1,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 21,
#     'summonerId': 'HUKstLatFwr8EBgjjk4JhhtPHQmltr4u6aZ4FFhm8rblEfk',
#     'summonerLevel': 926,
#     'summonerName': 'FA pangjin',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 1,
#     'timePlayed': 1343,
#     'totalAllyJungleMinionsKilled': 2,
#     'totalDamageDealt': 134056,
#     'totalDamageDealtToChampions': 18868,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 18871,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 6136,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 176,
#     'totalTimeCCDealt': 31,
#     'totalTimeSpentDead': 81,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 7211,
#     'trueDamageDealtToChampions': 130,
#     'trueDamageTaken': 600,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 20,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 8,
#     'wardsPlaced': 7,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 2,
#     'assists': 4,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 2,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 178,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.514449649219016,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 842.4814934626002,
#      'damageTakenOnTeamPercentage': 0.14895081179067585,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1249.063337258,
#      'earliestDragonTakedown': 850.530896675,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 5,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 916.222228057,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 1,
#      'fullTeamTakedown': 0,
#      'gameLength': 1343.718360993,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 473.3862913746504,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 1,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.2903225806451613,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 1,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 96,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3115, 3157],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 56,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 4,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 18,
#      'skillshotsHit': 5,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 4,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 9,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.19452481982977274,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.40743643045425415,
#      'visionScorePerMinute': 0.4457468205321276,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 13228,
#     'champLevel': 15,
#     'championId': 268,
#     'championName': 'Azir',
#     'championTransform': 0,
#     'commandPings': 2,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 6354,
#     'damageDealtToObjectives': 13131,
#     'damageDealtToTurrets': 6354,
#     'damageSelfMitigated': 14094,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 9,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': True,
#     'getBackPings': 5,
#     'goldEarned': 10601,
#     'goldSpent': 9150,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3157,
#     'item1': 2031,
#     'item2': 1058,
#     'item3': 3115,
#     'item4': 0,
#     'item5': 3020,
#     'item6': 3363,
#     'itemsPurchased': 18,
#     'killingSprees': 2,
#     'kills': 5,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 596,
#     'magicDamageDealt': 107079,
#     'magicDamageDealtToChampions': 17318,
#     'magicDamageTaken': 3633,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 7,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2261, 'var2': 2251, 'var3': 0},
#         {'perk': 9101, 'var1': 1498, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 12, 'var2': 10, 'var3': 0},
#         {'perk': 8017, 'var1': 958, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 7064,
#     'physicalDamageDealtToChampions': 661,
#     'physicalDamageTaken': 13834,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5073,
#     'pushPings': 0,
#     'puuid': '2lRHMhM5p3ra5nQB4lDx3WcDOErS0EIc3LuoroOGsKD8_b_57nW8Tde0gjxzlefFdi7KZVn4aFmQKA',
#     'quadraKills': 0,
#     'riotIdGameName': 'livinli',
#     'riotIdTagline': 'KR1',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 41,
#     'spell2Casts': 126,
#     'spell3Casts': 5,
#     'spell4Casts': 6,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 4,
#     'summoner2Casts': 3,
#     'summoner2Id': 12,
#     'summonerId': 'LBSYtbn7luIaQNz13rfOKKIGqCpuRchQhDFHWeVUk8hTbBhP9CDz8N5s5A',
#     'summonerLevel': 210,
#     'summonerName': 'livinli',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 14,
#     'timePlayed': 1343,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 118309,
#     'totalDamageDealtToChampions': 18867,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 18028,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 5542,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 198,
#     'totalTimeCCDealt': 162,
#     'totalTimeSpentDead': 102,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 4165,
#     'trueDamageDealtToChampions': 887,
#     'trueDamageTaken': 560,
#     'turretKills': 2,
#     'turretTakedowns': 2,
#     'turretsLost': 1,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 9,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 1,
#     'wardsPlaced': 9,
#     'win': True}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': -1, 'pickTurn': 1},
#      {'championId': 22, 'pickTurn': 2},
#      {'championId': 7, 'pickTurn': 3},
#      {'championId': 555, 'pickTurn': 4},
#      {'championId': 89, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 18},
#      'dragon': {'first': False, 'kills': 0},
#      'horde': {'first': True, 'kills': 3},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 1}},
#     'teamId': 100,
#     'win': False},
#    {'bans': [{'championId': 85, 'pickTurn': 6},
#      {'championId': 893, 'pickTurn': 7},
#      {'championId': 81, 'pickTurn': 8},
#      {'championId': 9, 'pickTurn': 9},
#      {'championId': 76, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 31},
#      'dragon': {'first': True, 'kills': 3},
#      'horde': {'first': False, 'kills': 3},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 5}},
#     'teamId': 200,
#     'win': True}],
#   'tournamentCode': ''}}

# %%
temp_match_data['metadata']
# Out:
# ['wyLAxR9edOThxUqpqOn15LT1nm8_0TaXHym7TxeEeVieyEjAnvMjVpVylg4HQXXrYAweazE_wNJ3_Q',
#  'DqXnoKoSfaioqNY4naS3YTOJ0_yPRbTF_K2N6z6FJAMvABZ_uJpsO9a49hvWZFqSJs9C8_fbp1kJ9Q',
#  '0FBMODS1toxMv1XDsdt6A49mp3ZNYVA5xOD8gO8AnOEklTEPqNOlVT2LRuGWm-uY0ZvAIQbgltENzA',
#  'IqFsLwBHNZU25ocjV_7rp6QjwQ3hCcvguWfcynXV7EGvo3NWNtpQo7S-ZXNMMnCTKbQwGEqdxHbDxg',
#  'LMJ7J_qRHk0_4MQS91JY_jMaH9xQ1YMjFGHw8QcEjR-w2bdrQ9tgA-vDDvk5UcPmTba1h5vpV21Clg',
#  'LPd1KERkv3Ol60alze92LTflCrJKPyEUy-nHV0Rh50KeTi1pVZif8JwZWuX-z8KlAt6UpYy-EPEZHg',
#  '9BdGvJe5JDLTVCmSDpvojDdj8wFvJIQBFIcXPalFUT3iTbbbP8zfGX7A1Dt9olySqul-QoaWHqZRJw',
#  'L_UhGnM0aqfnWUPuI7_jMSNqvzRRSGYpHp9B49qM4EjC1zFCiXSJURFc8Aq9rn3lxAAJ74SOAv2ffA',
#  'Zdu9sOJuQSRyeVcivC8gdXfJpgPwMA14gRStmTqtsjH2S7NAw5s71lTgARV7gtuPcPkr-iSsog5WWQ',
#  '2lRHMhM5p3ra5nQB4lDx3WcDOErS0EIc3LuoroOGsKD8_b_57nW8Tde0gjxzlefFdi7KZVn4aFmQKA']

# %%
len(temp_match_data['metadata']['participants'])
# Out:
# 10

# %%
temp_match_data['info']
# Out:
# {'endOfGameResult': 'GameComplete',
#  'gameCreation': 1721933710119,
#  'gameDuration': 1343,
#  'gameEndTimestamp': 1721935066933,
#  'gameId': 7180464646,
#  'gameMode': 'CLASSIC',
#  'gameName': 'teambuilder-match-7180464646',
#  'gameStartTimestamp': 1721933723498,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '14.14.603.4237',
#  'mapId': 11,
#  'participants': [{'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 5,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 284,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 150,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7595490347402619,
#     'controlWardsPlaced': 3,
#     'damagePerMinute': 806.0057799795459,
#     'damageTakenOnTeamPercentage': 0.1468382221225847,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 4,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 22,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1343.718360993,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 403.22274981760296,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 5,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 2.25,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.5,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 1,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 1,
#     'knockEnemyIntoTeamAndKill': 3,
#     'landSkillShotsEarlyGame': 2,
#     'laneMinionsFirst10Minutes': 63,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [6698, 6697],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 0,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 8,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 13,
#     'skillshotsHit': 20,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 1,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 9,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 6,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.22109915392925802,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 1,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.6875826120376587,
#     'visionScorePerMinute': 0.7522345652460666,
#     'voidMonsterKill': 0,
#     'wardTakedowns': 3,
#     'wardTakedownsBefore20M': 3,
#     'wardsGuarded': 0},
#    'champExperience': 10995,
#    'champLevel': 13,
#    'championId': 246,
#    'championName': 'Qiyana',
#    'championTransform': 0,
#    'commandPings': 22,
#    'consumablesPurchased': 3,
#    'damageDealtToBuildings': 636,
#    'damageDealtToObjectives': 636,
#    'damageDealtToTurrets': 636,
#    'damageSelfMitigated': 7928,
#    'dangerPings': 0,
#    'deaths': 4,
#    'detectorWardsPlaced': 3,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 9,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 11,
#    'goldEarned': 9030,
#    'goldSpent': 8450,
#    'holdPings': 0,
#    'individualPosition': 'MIDDLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 6698,
#    'item1': 3158,
#    'item2': 1037,
#    'item3': 6697,
#    'item4': 0,
#    'item5': 0,
#    'item6': 3364,
#    'itemsPurchased': 19,
#    'killingSprees': 1,
#    'kills': 4,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 722,
#    'magicDamageDealt': 8093,
#    'magicDamageDealtToChampions': 1603,
#    'magicDamageTaken': 7466,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 11,
#    'participantId': 1,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8112, 'var1': 1033, 'var2': 0, 'var3': 0},
#        {'perk': 8143, 'var1': 606, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 10, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8017, 'var1': 1018, 'var2': 0, 'var3': 0},
#        {'perk': 8009, 'var1': 1612, 'var2': 0, 'var3': 0}],
#       'style': 8000}]},
#    'physicalDamageDealt': 92024,
#    'physicalDamageDealtToChampions': 15753,
#    'physicalDamageTaken': 7728,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6,
#    'pushPings': 0,
#    'puuid': 'wyLAxR9edOThxUqpqOn15LT1nm8_0TaXHym7TxeEeVieyEjAnvMjVpVylg4HQXXrYAweazE_wNJ3_Q',
#    'quadraKills': 0,
#    'riotIdGameName': 'chendian',
#    'riotIdTagline': 'KR1',
#    'role': 'DUO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 107,
#    'spell2Casts': 142,
#    'spell3Casts': 28,
#    'spell4Casts': 7,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 12,
#    'summoner2Casts': 2,
#    'summoner2Id': 4,
#    'summonerId': 'JIhwtqL3wQVmR5q0WPqzH6bPu-HLhYgekezYaodwEs0-oBVMeii3v6LenA',
#    'summonerLevel': 141,
#    'summonerName': 'chendian',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 16,
#    'timePlayed': 1343,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 100871,
#    'totalDamageDealtToChampions': 18050,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 16564,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 871,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 153,
#    'totalTimeCCDealt': 79,
#    'totalTimeSpentDead': 97,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 753,
#    'trueDamageDealtToChampions': 693,
#    'trueDamageTaken': 1369,
#    'turretKills': 1,
#    'turretTakedowns': 1,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 16,
#    'visionWardsBoughtInGame': 3,
#    'wardsKilled': 3,
#    'wardsPlaced': 4,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 5,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 208,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.622953316934962,
#     'controlWardsPlaced': 2,
#     'damagePerMinute': 719.3634347263231,
#     'damageTakenOnTeamPercentage': 0.13339783916543554,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 5,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 57.952423095703125,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 21,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1343.718360993,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 358.7987677947727,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 3,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 1.4,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.3888888888888889,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 2,
#     'landSkillShotsEarlyGame': 0,
#     'laneMinionsFirst10Minutes': 59,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [2503, 6653],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 8,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 7,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 12,
#     'skillshotsHit': 11,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 7,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 1,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 7,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 4,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.1973318935624399,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 0,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.1443764567375183,
#     'visionScorePerMinute': 0.7939695425037812,
#     'voidMonsterKill': 0,
#     'wardTakedowns': 3,
#     'wardTakedownsBefore20M': 3,
#     'wardsGuarded': 0},
#    'champExperience': 10411,
#    'champLevel': 13,
#    'championId': 910,
#    'championName': 'Hwei',
#    'championTransform': 0,
#    'commandPings': 6,
#    'consumablesPurchased': 4,
#    'damageDealtToBuildings': 1742,
#    'damageDealtToObjectives': 1742,
#    'damageDealtToTurrets': 1742,
#    'damageSelfMitigated': 7951,
#    'dangerPings': 0,
#    'deaths': 5,
#    'detectorWardsPlaced': 2,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 0,
#    'goldEarned': 8035,
#    'goldSpent': 7450,
#    'holdPings': 0,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 6653,
#    'item1': 3158,
#    'item2': 2503,
#    'item3': 1052,
#    'item4': 0,
#    'item5': 1056,
#    'item6': 3363,
#    'itemsPurchased': 19,
#    'killingSprees': 0,
#    'kills': 2,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 455,
#    'magicDamageDealt': 89004,
#    'magicDamageDealtToChampions': 15064,
#    'magicDamageTaken': 5279,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 2,
#    'participantId': 2,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8229, 'var1': 1106, 'var2': 0, 'var3': 0},
#        {'perk': 8226, 'var1': 250, 'var2': 890, 'var3': 0},
#        {'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0},
#        {'perk': 8237, 'var1': 486, 'var2': 0, 'var3': 0}],
#       'style': 8200},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0},
#        {'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5}],
#       'style': 8300}]},
#    'physicalDamageDealt': 12587,
#    'physicalDamageDealtToChampions': 789,
#    'physicalDamageTaken': 9616,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 3791,
#    'pushPings': 0,
#    'puuid': 'DqXnoKoSfaioqNY4naS3YTOJ0_yPRbTF_K2N6z6FJAMvABZ_uJpsO9a49hvWZFqSJs9C8_fbp1kJ9Q',
#    'quadraKills': 0,
#    'riotIdGameName': '오직 유 빛날 빈',
#    'riotIdTagline': 'KR1',
#    'role': 'DUO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 97,
#    'spell2Casts': 59,
#    'spell3Casts': 44,
#    'spell4Casts': 8,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 12,
#    'summoner2Casts': 2,
#    'summoner2Id': 4,
#    'summonerId': 'clff7WXV6JSjzypKfp79OjdTsyjKjG9TjgR1mQioJ_DRGQ',
#    'summonerLevel': 567,
#    'summonerName': '오직 유 빛날 빈',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 21,
#    'timePlayed': 1343,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 103133,
#    'totalDamageDealtToChampions': 16110,
#    'totalDamageShieldedOnTeammates': 57,
#    'totalDamageTaken': 15047,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 1718,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 180,
#    'totalTimeCCDealt': 703,
#    'totalTimeSpentDead': 80,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 1541,
#    'trueDamageDealtToChampions': 255,
#    'trueDamageTaken': 152,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 17,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 3,
#    'wardsPlaced': 10,
#    'win': False},
#   {'allInPings': 11,
#    'assistMePings': 9,
#    'assists': 3,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 145,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 59,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 1,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5961546610355302,
#     'controlWardsPlaced': 4,
#     'damagePerMinute': 706.4082750419415,
#     'damageTakenOnTeamPercentage': 0.20836055560478564,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 7,
#     'dodgeSkillShotsSmallWindow': 1,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 0,
#     'enemyJungleMonsterKills': 7,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1343.718360993,
#     'goldPerMinute': 431.460304214389,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 0,
#     'initialBuffCount': 2,
#     'initialCrabCount': 1,
#     'jungleCsBefore10Minutes': 65.75000008940697,
#     'junglerKillsEarlyJungle': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 1.2857142857142858,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.5,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnLanersEarlyJungleAsJungler': 2,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 4,
#     'laneMinionsFirst10Minutes': 9,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [6676, 6673],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 7.750000029802322,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': -45.000000059604645,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 1,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 8,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 2,
#     'skillshotsDodged': 16,
#     'skillshotsHit': 27,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'stealthWardsPlaced': 3,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 9,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 4,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.19377810410288054,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 0,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.15824973583221436,
#     'visionScorePerMinute': 0.9904152505001195,
#     'voidMonsterKill': 3,
#     'wardTakedowns': 3,
#     'wardTakedownsBefore20M': 3,
#     'wardsGuarded': 0},
#    'champExperience': 10639,
#    'champLevel': 13,
#    'championId': 104,
#    'championName': 'Graves',
#    'championTransform': 0,
#    'commandPings': 11,
#    'consumablesPurchased': 4,
#    'damageDealtToBuildings': 429,
#    'damageDealtToObjectives': 8070,
#    'damageDealtToTurrets': 429,
#    'damageSelfMitigated': 17372,
#    'dangerPings': 0,
#    'deaths': 7,
#    'detectorWardsPlaced': 4,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 10,
#    'enemyVisionPings': 8,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 26,
#    'goldEarned': 9662,
#    'goldSpent': 9150,
#    'holdPings': 0,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 3123,
#    'item1': 1036,
#    'item2': 1036,
#    'item3': 3047,
#    'item4': 6673,
#    'item5': 6676,
#    'item6': 3364,
#    'itemsPurchased': 20,
#    'killingSprees': 1,
#    'kills': 6,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 367,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 658,
#    'magicDamageDealt': 2611,
#    'magicDamageDealtToChampions': 449,
#    'magicDamageTaken': 6563,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 117,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 40,
#    'participantId': 3,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 1887, 'var2': 1520, 'var3': 0},
#        {'perk': 9111, 'var1': 393, 'var2': 180, 'var3': 0},
#        {'perk': 9104, 'var1': 12, 'var2': 10, 'var3': 0},
#        {'perk': 8014, 'var1': 331, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 126581,
#    'physicalDamageDealtToChampions': 14052,
#    'physicalDamageTaken': 15959,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 5491,
#    'pushPings': 0,
#    'puuid': '0FBMODS1toxMv1XDsdt6A49mp3ZNYVA5xOD8gO8AnOEklTEPqNOlVT2LRuGWm-uY0ZvAIQbgltENzA',
#    'quadraKills': 0,
#    'riotIdGameName': 'lose jug',
#    'riotIdTagline': '315',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 73,
#    'spell2Casts': 31,
#    'spell3Casts': 32,
#    'spell4Casts': 9,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 16,
#    'summoner2Id': 11,
#    'summonerId': 'KcKYsWQhS1ZrC8XjmFGYn6-SEUMRJnZG1BOpMqR9TbpX6hfDEuHsX2rgLg',
#    'summonerLevel': 250,
#    'summonerName': 'jin jiu shu',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'JUNGLE',
#    'timeCCingOthers': 16,
#    'timePlayed': 1343,
#    'totalAllyJungleMinionsKilled': 88,
#    'totalDamageDealt': 178577,
#    'totalDamageDealtToChampions': 15820,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 23504,
#    'totalEnemyJungleMinionsKilled': 8,
#    'totalHeal': 9097,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 40,
#    'totalTimeCCDealt': 631,
#    'totalTimeSpentDead': 185,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 49384,
#    'trueDamageDealtToChampions': 1318,
#    'trueDamageTaken': 981,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 22,
#    'visionWardsBoughtInGame': 4,
#    'wardsKilled': 3,
#    'wardsPlaced': 7,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 4,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 295,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 300,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 2,
#     'damagePerMinute': 1125.5255996835922,
#     'damageTakenOnTeamPercentage': 0.3342465195574944,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 6,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 43,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1343.718360993,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 346.876604816337,
#     'hadOpenNexus': 0,
#     'highestCrowdControlScore': 1,
#     'immobilizeAndKillWithAlly': 5,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 1.5,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.5,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 6,
#     'landSkillShotsEarlyGame': 4,
#     'laneMinionsFirst10Minutes': 53,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [6610],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 2,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 7,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 13,
#     'skillshotsHit': 18,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'stealthWardsPlaced': 4,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 9,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 5,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.30874810577918954,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 0,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.2770256996154785,
#     'visionScorePerMinute': 0.6263293024394452,
#     'voidMonsterKill': 0,
#     'wardTakedowns': 3,
#     'wardTakedownsBefore20M': 1,
#     'wardsGuarded': 1},
#    'champExperience': 9397,
#    'champLevel': 12,
#    'championId': 266,
#    'championName': 'Aatrox',
#    'championTransform': 0,
#    'commandPings': 0,
#    'consumablesPurchased': 4,
#    'damageDealtToBuildings': 720,
#    'damageDealtToObjectives': 720,
#    'damageDealtToTurrets': 720,
#    'damageSelfMitigated': 24081,
#    'dangerPings': 0,
#    'deaths': 6,
#    'detectorWardsPlaced': 2,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 0,
#    'goldEarned': 7768,
#    'goldSpent': 7375,
#    'holdPings': 0,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 0,
#    'item1': 3047,
#    'item2': 6610,
#    'item3': 2021,
#    'item4': 1037,
#    'item5': 1028,
#    'item6': 3364,
#    'itemsPurchased': 21,
#    'killingSprees': 1,
#    'kills': 5,
#    'lane': 'TOP',
#    'largestCriticalStrike': 310,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 362,
#    'magicDamageDealt': 5574,
#    'magicDamageDealtToChampions': 4011,
#    'magicDamageTaken': 7862,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 5,
#    'participantId': 4,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 915, 'var2': 0, 'var3': 0},
#        {'perk': 9101, 'var1': 815, 'var2': 0, 'var3': 0},
#        {'perk': 9105, 'var1': 15, 'var2': 40, 'var3': 0},
#        {'perk': 8299, 'var1': 1112, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8444, 'var1': 1493, 'var2': 0, 'var3': 0},
#        {'perk': 8451, 'var1': 161, 'var2': 0, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 75283,
#    'physicalDamageDealtToChampions': 20186,
#    'physicalDamageTaken': 22862,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6631,
#    'pushPings': 0,
#    'puuid': 'IqFsLwBHNZU25ocjV_7rp6QjwQ3hCcvguWfcynXV7EGvo3NWNtpQo7S-ZXNMMnCTKbQwGEqdxHbDxg',
#    'quadraKills': 0,
#    'riotIdGameName': 'NS Ady',
#    'riotIdTagline': '안성탕면맨',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 142,
#    'spell2Casts': 36,
#    'spell3Casts': 109,
#    'spell4Casts': 8,
#    'subteamPlacement': 0,
#    'summoner1Casts': 4,
#    'summoner1Id': 4,
#    'summoner2Casts': 3,
#    'summoner2Id': 12,
#    'summonerId': 'uWNS7eqHJHkSprdxLt6W3QD2FHR3irAIm3Pg06RdCPfapvo',
#    'summonerLevel': 641,
#    'summonerName': 'FA ady',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 26,
#    'timePlayed': 1343,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 85170,
#    'totalDamageDealtToChampions': 25206,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 37704,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 14348,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 115,
#    'totalTimeCCDealt': 270,
#    'totalTimeSpentDead': 118,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 4313,
#    'trueDamageDealtToChampions': 1008,
#    'trueDamageTaken': 6979,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 14,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 3,
#    'wardsPlaced': 6,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 2,
#    'assists': 9,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 119,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 300,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 1,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.24458936444696838,
#     'controlWardsPlaced': 6,
#     'damagePerMinute': 288.1463193774257,
#     'damageTakenOnTeamPercentage': 0.1771568635496997,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 9,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 3150.876708984375,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 19,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1343.718360993,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 274.0005066587521,
#     'hadOpenNexus': 0,
#     'highestWardKills': 1,
#     'immobilizeAndKillWithAlly': 5,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 1.1111111111111112,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.5555555555555556,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 11,
#     'laneMinionsFirst10Minutes': 9,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3869, 3050],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 4,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 9,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 14,
#     'skillshotsHit': 29,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 17,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 10,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 7,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.07904274262623197,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 0,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.3432748317718506,
#     'visionScorePerMinute': 3.479819624193566,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 11,
#     'wardTakedownsBefore20M': 11,
#     'wardsGuarded': 0},
#    'champExperience': 6332,
#    'champLevel': 10,
#    'championId': 497,
#    'championName': 'Rakan',
#    'championTransform': 0,
#    'commandPings': 22,
#    'consumablesPurchased': 9,
#    'damageDealtToBuildings': 0,
#    'damageDealtToObjectives': 55,
#    'damageDealtToTurrets': 0,
#    'damageSelfMitigated': 16386,
#    'dangerPings': 0,
#    'deaths': 9,
#    'detectorWardsPlaced': 6,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 33,
#    'enemyVisionPings': 25,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 2,
#    'goldEarned': 6136,
#    'goldSpent': 5975,
#    'holdPings': 0,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 3158,
#    'item1': 3869,
#    'item2': 2055,
#    'item3': 1011,
#    'item4': 3050,
#    'item5': 3066,
#    'item6': 3364,
#    'itemsPurchased': 23,
#    'killingSprees': 0,
#    'kills': 1,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 454,
#    'magicDamageDealt': 5742,
#    'magicDamageDealtToChampions': 4908,
#    'magicDamageTaken': 4169,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 17,
#    'participantId': 5,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5010, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8465, 'var1': 1089, 'var2': 0, 'var3': 0},
#        {'perk': 8463, 'var1': 443, 'var2': 0, 'var3': 0},
#        {'perk': 8473, 'var1': 428, 'var2': 0, 'var3': 0},
#        {'perk': 8451, 'var1': 132, 'var2': 0, 'var3': 0}],
#       'style': 8400},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8136, 'var1': 12, 'var2': 30, 'var3': 0},
#        {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 2415,
#    'physicalDamageDealtToChampions': 797,
#    'physicalDamageTaken': 14117,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6591,
#    'pushPings': 0,
#    'puuid': 'LMJ7J_qRHk0_4MQS91JY_jMaH9xQ1YMjFGHw8QcEjR-w2bdrQ9tgA-vDDvk5UcPmTba1h5vpV21Clg',
#    'quadraKills': 0,
#    'riotIdGameName': 'player1',
#    'riotIdTagline': 'wywq',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 43,
#    'spell2Casts': 32,
#    'spell3Casts': 38,
#    'spell4Casts': 6,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 5,
#    'summoner2Id': 14,
#    'summonerId': 'vJ3pjMTqXEMg_LZn_910Tv7QZ8mfuxWt4LjBx1t3Pen6xB2QN4AbsXEEeA',
#    'summonerLevel': 60,
#    'summonerName': '',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'UTILITY',
#    'timeCCingOthers': 20,
#    'timePlayed': 1343,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 10779,
#    'totalDamageDealtToChampions': 6453,
#    'totalDamageShieldedOnTeammates': 1634,
#    'totalDamageTaken': 19984,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 3671,
#    'totalHealsOnTeammates': 1516,
#    'totalMinionsKilled': 19,
#    'totalTimeCCDealt': 69,
#    'totalTimeSpentDead': 133,
#    'totalUnitsHealed': 5,
#    'tripleKills': 0,
#    'trueDamageDealt': 2621,
#    'trueDamageDealtToChampions': 747,
#    'trueDamageTaken': 1696,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 77,
#    'visionWardsBoughtInGame': 7,
#    'wardsKilled': 11,
#    'wardsPlaced': 35,
#    'win': False},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 6,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 6,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 250,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 4,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.30136685467834395,
#     'controlWardsPlaced': 1,
#     'damagePerMinute': 1492.9415471166956,
#     'damageTakenOnTeamPercentage': 0.2604416292184519,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 4,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earliestBaron': 1249.063337258,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 3358.552734375,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 2,
#     'enemyJungleMonsterKills': 2,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 916.222228057,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 1,
#     'fullTeamTakedown': 0,
#     'gameLength': 1343.718360993,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 580.4116746923077,
#     'hadOpenNexus': 0,
#     'highestChampionDamage': 1,
#     'immobilizeAndKillWithAlly': 0,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 1,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3.75,
#     'killAfterHiddenWithAlly': 3,
#     'killParticipation': 0.4838709677419355,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 2,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 4,
#     'laneMinionsFirst10Minutes': 70,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3074, 3078, 6333],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 72.60000002384186,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 3,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 4,
#     'multikillsAfterAggressiveFlash': 2,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 11,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 12,
#     'skillshotsHit': 10,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'soloTurretsLategame': 2,
#     'stealthWardsPlaced': 6,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 4,
#     'takedownOnFirstTurret': 1,
#     'takedowns': 15,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 6,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.344712836688738,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 4,
#     'turretTakedowns': 3,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.3831750154495239,
#     'visionScorePerMinute': 0.8663230300187651,
#     'voidMonsterKill': 0,
#     'wardTakedowns': 6,
#     'wardTakedownsBefore20M': 5,
#     'wardsGuarded': 0},
#    'champExperience': 13901,
#    'champLevel': 15,
#    'championId': 114,
#    'championName': 'Fiora',
#    'championTransform': 0,
#    'commandPings': 3,
#    'consumablesPurchased': 3,
#    'damageDealtToBuildings': 8942,
#    'damageDealtToObjectives': 8942,
#    'damageDealtToTurrets': 8942,
#    'damageSelfMitigated': 33595,
#    'dangerPings': 0,
#    'deaths': 4,
#    'detectorWardsPlaced': 1,
#    'doubleKills': 3,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': True,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 0,
#    'goldEarned': 12998,
#    'goldSpent': 11608,
#    'holdPings': 0,
# ...
#     'laneMinionsFirst10Minutes': 75,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3087, 3124],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 19,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 8,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 2,
#     'skillshotsDodged': 12,
#     'skillshotsHit': 14,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'stealthWardsPlaced': 4,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 11,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 7,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.19453819057979413,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 1,
#     'turretTakedowns': 0,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.16873836517333984,
#     'visionScorePerMinute': 0.9279426222227579,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 8,
#     'wardTakedownsBefore20M': 7,
#     'wardsGuarded': 1},
#    'champExperience': 11166,
#    'champLevel': 13,
#    'championId': 145,
#    'championName': 'Kaisa',
#    'championTransform': 0,
#    'commandPings': 8,
#    'consumablesPurchased': 1,
#    'damageDealtToBuildings': 1453,
#    'damageDealtToObjectives': 16645,
#    'damageDealtToTurrets': 1453,
#    'damageSelfMitigated': 10319,
#    'dangerPings': 0,
#    'deaths': 3,
#    'detectorWardsPlaced': 0,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 11,
#    'enemyVisionPings': 1,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 1,
#    'goldEarned': 9875,
#    'goldSpent': 9000,
#    'holdPings': 0,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 3087,
#    'item1': 3124,
#    'item2': 1026,
#    'item3': 3006,
#    'item4': 1055,
#    'item5': 3108,
#    'item6': 3363,
#    'itemsPurchased': 20,
#    'killingSprees': 1,
#    'kills': 6,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 3,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 593,
#    'magicDamageDealt': 32772,
#    'magicDamageDealtToChampions': 6484,
#    'magicDamageTaken': 9088,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 14,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 25,
#    'participantId': 9,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 2197, 'var2': 2129, 'var3': 0},
#        {'perk': 9101, 'var1': 1154, 'var2': 0, 'var3': 0},
#        {'perk': 9104, 'var1': 12, 'var2': 20, 'var3': 0},
#        {'perk': 8017, 'var1': 921, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8304, 'var1': 9, 'var2': 4, 'var3': 5},
#        {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 94072,
#    'physicalDamageDealtToChampions': 12254,
#    'physicalDamageTaken': 9181,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4417,
#    'pushPings': 0,
#    'puuid': 'Zdu9sOJuQSRyeVcivC8gdXfJpgPwMA14gRStmTqtsjH2S7NAw5s71lTgARV7gtuPcPkr-iSsog5WWQ',
#    'quadraKills': 0,
#    'riotIdGameName': 'Pangjin',
#    'riotIdTagline': 'kr2',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 64,
#    'spell2Casts': 33,
#    'spell3Casts': 49,
#    'spell4Casts': 4,
#    'subteamPlacement': 0,
#    'summoner1Casts': 1,
#    'summoner1Id': 4,
#    'summoner2Casts': 4,
#    'summoner2Id': 21,
#    'summonerId': 'HUKstLatFwr8EBgjjk4JhhtPHQmltr4u6aZ4FFhm8rblEfk',
#    'summonerLevel': 926,
#    'summonerName': 'FA pangjin',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 1,
#    'timePlayed': 1343,
#    'totalAllyJungleMinionsKilled': 2,
#    'totalDamageDealt': 134056,
#    'totalDamageDealtToChampions': 18868,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 18871,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 6136,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 176,
#    'totalTimeCCDealt': 31,
#    'totalTimeSpentDead': 81,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 7211,
#    'trueDamageDealtToChampions': 130,
#    'trueDamageTaken': 600,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 1,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 20,
#    'visionWardsBoughtInGame': 0,
#    'wardsKilled': 8,
#    'wardsPlaced': 7,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 2,
#    'assists': 4,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 2,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 0,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 178,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.514449649219016,
#     'controlWardsPlaced': 2,
#     'damagePerMinute': 842.4814934626002,
#     'damageTakenOnTeamPercentage': 0.14895081179067585,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 3,
#     'dodgeSkillShotsSmallWindow': 1,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestBaron': 1249.063337258,
#     'earliestDragonTakedown': 850.530896675,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 5,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 916.222228057,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 1,
#     'fullTeamTakedown': 0,
#     'gameLength': 1343.718360993,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 473.3862913746504,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 1,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.2903225806451613,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 1,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 1,
#     'landSkillShotsEarlyGame': 0,
#     'laneMinionsFirst10Minutes': 96,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3115, 3157],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 56,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 2,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 4,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 18,
#     'skillshotsHit': 5,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'soloTurretsLategame': 1,
#     'stealthWardsPlaced': 4,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 4,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 9,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 6,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.19452481982977274,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 2,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.40743643045425415,
#     'visionScorePerMinute': 0.4457468205321276,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 1,
#     'wardTakedownsBefore20M': 1,
#     'wardsGuarded': 0},
#    'champExperience': 13228,
#    'champLevel': 15,
#    'championId': 268,
#    'championName': 'Azir',
#    'championTransform': 0,
#    'commandPings': 2,
#    'consumablesPurchased': 5,
#    'damageDealtToBuildings': 6354,
#    'damageDealtToObjectives': 13131,
#    'damageDealtToTurrets': 6354,
#    'damageSelfMitigated': 14094,
#    'dangerPings': 0,
#    'deaths': 3,
#    'detectorWardsPlaced': 2,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 9,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': True,
#    'getBackPings': 5,
#    'goldEarned': 10601,
#    'goldSpent': 9150,
#    'holdPings': 0,
#    'individualPosition': 'MIDDLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 0,
#    'item0': 3157,
#    'item1': 2031,
#    'item2': 1058,
#    'item3': 3115,
#    'item4': 0,
#    'item5': 3020,
#    'item6': 3363,
#    'itemsPurchased': 18,
#    'killingSprees': 2,
#    'kills': 5,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 2,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 596,
#    'magicDamageDealt': 107079,
#    'magicDamageDealtToChampions': 17318,
#    'magicDamageTaken': 3633,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 7,
#    'participantId': 10,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 2261, 'var2': 2251, 'var3': 0},
#        {'perk': 9101, 'var1': 1498, 'var2': 0, 'var3': 0},
#        {'perk': 9104, 'var1': 12, 'var2': 10, 'var3': 0},
#        {'perk': 8017, 'var1': 958, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8304, 'var1': 10, 'var2': 3, 'var3': 0},
#        {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 7064,
#    'physicalDamageDealtToChampions': 661,
#    'physicalDamageTaken': 13834,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 5073,
#    'pushPings': 0,
#    'puuid': '2lRHMhM5p3ra5nQB4lDx3WcDOErS0EIc3LuoroOGsKD8_b_57nW8Tde0gjxzlefFdi7KZVn4aFmQKA',
#    'quadraKills': 0,
#    'riotIdGameName': 'livinli',
#    'riotIdTagline': 'KR1',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 41,
#    'spell2Casts': 126,
#    'spell3Casts': 5,
#    'spell4Casts': 6,
#    'subteamPlacement': 0,
#    'summoner1Casts': 2,
#    'summoner1Id': 4,
#    'summoner2Casts': 3,
#    'summoner2Id': 12,
#    'summonerId': 'LBSYtbn7luIaQNz13rfOKKIGqCpuRchQhDFHWeVUk8hTbBhP9CDz8N5s5A',
#    'summonerLevel': 210,
#    'summonerName': 'livinli',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 14,
#    'timePlayed': 1343,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 118309,
#    'totalDamageDealtToChampions': 18867,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 18028,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 5542,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 198,
#    'totalTimeCCDealt': 162,
#    'totalTimeSpentDead': 102,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 4165,
#    'trueDamageDealtToChampions': 887,
#    'trueDamageTaken': 560,
#    'turretKills': 2,
#    'turretTakedowns': 2,
#    'turretsLost': 1,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 9,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 1,
#    'wardsPlaced': 9,
#    'win': True}],
#  'platformId': 'KR',
#  'queueId': 420,
#  'teams': [{'bans': [{'championId': -1, 'pickTurn': 1},
#     {'championId': 22, 'pickTurn': 2},
#     {'championId': 7, 'pickTurn': 3},
#     {'championId': 555, 'pickTurn': 4},
#     {'championId': 89, 'pickTurn': 5}],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': False, 'kills': 18},
#     'dragon': {'first': False, 'kills': 0},
#     'horde': {'first': True, 'kills': 3},
#     'inhibitor': {'first': False, 'kills': 0},
#     'riftHerald': {'first': False, 'kills': 0},
#     'tower': {'first': False, 'kills': 1}},
#    'teamId': 100,
#    'win': False},
#   {'bans': [{'championId': 85, 'pickTurn': 6},
#     {'championId': 893, 'pickTurn': 7},
#     {'championId': 81, 'pickTurn': 8},
#     {'championId': 9, 'pickTurn': 9},
#     {'championId': 76, 'pickTurn': 10}],
#    'objectives': {'baron': {'first': True, 'kills': 1},
#     'champion': {'first': True, 'kills': 31},
#     'dragon': {'first': True, 'kills': 3},
#     'horde': {'first': False, 'kills': 3},
#     'inhibitor': {'first': False, 'kills': 0},
#     'riftHerald': {'first': False, 'kills': 0},
#     'tower': {'first': True, 'kills': 5}},
#    'teamId': 200,
#    'win': True}],
#  'tournamentCode': ''}
