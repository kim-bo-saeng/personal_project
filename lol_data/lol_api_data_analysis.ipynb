# %%
import requests
import pandas as pd
import numpy as np

# %%
# 첼린저,그랜드마스터,마스터의 솔로랭크 정보를 가져오기 위한 함수 생성

import requests
 
api_key = "RGAPI-dca92473-57ec-4764-a5b1-33eb5e36bb00"
header = {"X-Riot-Token" : api_key}
 
def league_v4_tier(tier):
    # 솔랭 기준
    queue = 'RANKED_SOLO_5x5'
 
    if tier == 'challenger' :
        url = f"https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/{queue}"
    elif tier == 'grandmaster':
        url = f"https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/{queue}"
    else:
        url = f"https://kr.api.riotgames.com/lol/league/v4/masterleagues/by-queue/{queue}"
        
    return requests.get(url, headers=header)

# %%
# 티어별 솔로랭크 정보를 테이블로 만들기

challenger_data = pd.DataFrame(league_v4_tier('challenger').json())
grandmaster_data = pd.DataFrame(league_v4_tier('grandmaster').json())
master_data = pd.DataFrame(league_v4_tier('master').json())

# %%
# 첼린저 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

challenger_df = pd.DataFrame([challenger_data['entries'][0]])
data_size = len(challenger_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([challenger_data['entries'][i]])
    challenger_df = pd.concat([challenger_df,append_df],ignore_index = True)

challenger_df['tier'] = 'CHALLENGER'
challenger_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0      FBwrdSqebPVce3wKt2kpjJ4VcdBninKRrGaLaJdtfc2hDFM          1298    I
# 1    ZBYOvASQ_uLc6l2XNIieVeVYhKRPhgakwro_SnADwmU0UA...          1177    I
# 2      yNI4esTsLqoynflw0hEeyMkNopigQ7CeTuzbb4exoG-ENx4          1376    I
# 3    S3HKu4Nkprdu027neEZ2ahD0h5nHYBa9l8O_aC9im3372Q...          1122    I
# 4      oUoXjr5MSC1k9_OTWDduIw-etrMCs3xdn-gm0nYrDwsd9Js          1206    I
# ..                                                 ...           ...  ...
# 295   fUVWj4-b4adtALs4f0utKCbdW4btzMaWTxTkMipZYTbFWi4a          1170    I
# 296  rLnVSxusrKlrzdNQ-fEl7B_ZF7lLIEOoPzzWZLGFEWpg4P...          1261    I
# 297  4uiEUfnV8r0YkGguqg-0WUDMsL2ZCJSHK_GV5_qXYUhL9d...          1273    I
# 298  4pZLnzR2X-HYf8EJ5xFI1Aam485lvjphihn7oc3v5DUAv9...          1329    I
# 299    3-npzsJtKEJkzMiVS0L8Slllc8P6dyqJ1msEcRlOh3EacLM          1083    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak        tier
# 0     314     261     True     False       False       True  CHALLENGER
# 1     255     211     True     False       False      False  CHALLENGER
# 2     272     219     True     False       False      False  CHALLENGER
# 3     251     209    False     False       False       True  CHALLENGER
# 4     244     200    False     False        True      False  CHALLENGER
# ..    ...     ...      ...       ...         ...        ...         ...
# 295   191     154     True     False       False      False  CHALLENGER
# 296   245     196     True     False       False      False  CHALLENGER
# 297   139      92     True     False       False      False  CHALLENGER
# 298   388     342     True     False       False      False  CHALLENGER
# 299   195     162    False     False        True      False  CHALLENGER
#
# [300 rows x 10 columns]

# %%
# 그랜드마스터 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

grandmaster_df = pd.DataFrame([grandmaster_data['entries'][0]])
data_size = len(grandmaster_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([grandmaster_data['entries'][i]])
    grandmaster_df = pd.concat([grandmaster_df,append_df],ignore_index = True)

grandmaster_df['tier'] = 'GRANDMASTER'
grandmaster_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0      8Q8Lg9HiC_2LWfiCpzBPeyIhMxEVWgxCHyVkPOkuCfTDXmU           819    I
# 1      3c_sxY8cV9RWOfbXbxpN80g8Qky7I3Nk1qlEJRSrRkLLdZg          1052    I
# 2      T5wInxx32cP4mD5kfOzNstJ0eObLCx3PaGCRGaDPcnOc35w           847    I
# 3      teaVoEIOadz61aryQl5M2Od5areQbXlyGHs32TNi6SEilis           651    I
# 4    yFkN8vH43WqGUSnuY8HDKs0xqsMWvIkOiyAUffsNdC8nbo...           851    I
# ..                                                 ...           ...  ...
# 695  JSDhDGOolCji1hI1E4PK_BxROSswr7GtYAXMcA87ElFWjk...           820    I
# 696  jWzRbGmnCp5ruPvkwr9ZYlQbK9ZzGJHpWa7BjLQrk1hFn5...           756    I
# 697     kfbzs4oIBmZUHpj0cJopDvmiFv1XsDvNAWbbOflsC6A90g           993    I
# 698    Jdois7w4jd_OvEVxphFBOD33Dc0h12zIVMbX55uGUQImv1M           806    I
# 699  HHNv7Dh8_0MJ1SPs3De-E9jagVeFQxHXR8G9w9i6IZUQzd...           957    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak         tier
# 0     210     163    False     False       False      False  GRANDMASTER
# 1     150     106    False     False        True      False  GRANDMASTER
# 2     343     310    False     False       False      False  GRANDMASTER
# 3     116      90    False     False        True      False  GRANDMASTER
# 4     122      84    False     False        True      False  GRANDMASTER
# ..    ...     ...      ...       ...         ...        ...          ...
# 695   256     227     True     False       False       True  GRANDMASTER
# 696   162     130    False     False       False      False  GRANDMASTER
# 697   123      84    False     False       False      False  GRANDMASTER
# 698   142     104     True     False       False       True  GRANDMASTER
# 699   270     243    False     False       False      False  GRANDMASTER
#
# [700 rows x 10 columns]

# %%
# 마스터 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

master_df = pd.DataFrame([master_data['entries'][0]])
data_size = len(master_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([master_data['entries'][i]])
    master_df = pd.concat([master_df,append_df],ignore_index = True)

master_df['tier'] = 'MASTER'
master_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0        10CT74EsWtWKzLpDViE5RQ4ryw69WOakaCRalPzQQtsi6uA           101    I
# 1        7lNsnt6kPyvaFILthqHK05IFtUAtZve7QLusmTUMXuE2SFc            51    I
# 2        1QCRyRvQnye2U6-BRwrGBlNWV7pifquGJ45AboR5OL4XcGM            28    I
# 3        dEOJ3GOl2NfV1b15iwJ-C0jLQkvuRO95B4kw1kUBSnTSW9Q           490    I
# 4      0MZ383GTU42TaK6wrBoPxRq_Q8uvzDQb1rCzooF3UVMZE-...           128    I
# ...                                                  ...           ...  ...
# 13426  WR7bVq4Y4IkbT6S42lcZJl-XxQWC0TM68rD6la5EQtVFMA...           114    I
# 13427   ftxt3jgMz4tJe8xGV1YEdy3kpAfJQomg0NgC3tPeIEW1rS-f           533    I
# 13428  nIMPiooyh7fF-4vwzSU6k43cxsJnrZTJmI_EB6ELvGV5yX...           586    I
# 13429    3O4Gu10wKJgVZWfI5mpEVBSTlrOyAdPCz4t_OLtxBwO5BKI           383    I
# 13430    XW1OhcVs5w9u-rYVQAijOlBrtYGtQ8mzGJyOGLAjSEuCNxg           331    I
#
#        wins  losses  veteran  inactive  freshBlood  hotStreak    tier
# 0        52      37    False     False        True       True  MASTER
# 1        71      69    False     False       False      False  MASTER
# 2        94      84    False     False        True      False  MASTER
# 3       179     158     True     False       False       True  MASTER
# 4       146     137    False     False       False      False  MASTER
# ...     ...     ...      ...       ...         ...        ...     ...
# 13426   185     177     True     False       False      False  MASTER
# 13427    75      45    False     False       False       True  MASTER
# 13428   163     137     True     False       False      False  MASTER
# 13429   103      82     True     False       False       True  MASTER
# 13430    92      76     True     False       False      False  MASTER
#
# [13431 rows x 10 columns]

# %%
# 첼린저,그마,마스터 티어의 entries정보를 하나의 테이블로 합치기

top_class_df = pd.concat([challenger_df,grandmaster_df,master_df],ignore_index = True)
top_class_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0        FBwrdSqebPVce3wKt2kpjJ4VcdBninKRrGaLaJdtfc2hDFM          1298    I
# 1      ZBYOvASQ_uLc6l2XNIieVeVYhKRPhgakwro_SnADwmU0UA...          1177    I
# 2        yNI4esTsLqoynflw0hEeyMkNopigQ7CeTuzbb4exoG-ENx4          1376    I
# 3      S3HKu4Nkprdu027neEZ2ahD0h5nHYBa9l8O_aC9im3372Q...          1122    I
# 4        oUoXjr5MSC1k9_OTWDduIw-etrMCs3xdn-gm0nYrDwsd9Js          1206    I
# ...                                                  ...           ...  ...
# 14426  WR7bVq4Y4IkbT6S42lcZJl-XxQWC0TM68rD6la5EQtVFMA...           114    I
# 14427   ftxt3jgMz4tJe8xGV1YEdy3kpAfJQomg0NgC3tPeIEW1rS-f           533    I
# 14428  nIMPiooyh7fF-4vwzSU6k43cxsJnrZTJmI_EB6ELvGV5yX...           586    I
# 14429    3O4Gu10wKJgVZWfI5mpEVBSTlrOyAdPCz4t_OLtxBwO5BKI           383    I
# 14430    XW1OhcVs5w9u-rYVQAijOlBrtYGtQ8mzGJyOGLAjSEuCNxg           331    I
#
#        wins  losses  veteran  inactive  freshBlood  hotStreak        tier
# 0       314     261     True     False       False       True  CHALLENGER
# 1       255     211     True     False       False      False  CHALLENGER
# 2       272     219     True     False       False      False  CHALLENGER
# 3       251     209    False     False       False       True  CHALLENGER
# 4       244     200    False     False        True      False  CHALLENGER
# ...     ...     ...      ...       ...         ...        ...         ...
# 14426   185     177     True     False       False      False      MASTER
# 14427    75      45    False     False       False       True      MASTER
# 14428   163     137     True     False       False      False      MASTER
# 14429   103      82     True     False       False       True      MASTER
# 14430    92      76     True     False       False      False      MASTER
#
# [14431 rows x 10 columns]

# %%
# summonerid로 소환사 정보인 puuid를 가져오기 위한 API코드

import requests
 
api_key = "RGAPI-dca92473-57ec-4764-a5b1-33eb5e36bb00"
header = {"X-Riot-Token" : api_key}

def summoners(encryptedSummonerId):
    url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/{encryptedSummonerId}"
    
    return requests.get(url, headers = header)

# %%
encryptedSummonerId = top_class_df['summonerId'].loc[0]

temp_summoners = summoners(encryptedSummonerId).json()
temp_summoners
# Out:
# {'id': '9Ave2rsRb8fj7uWkpkHk6lbX66qYy_GFCc-TgPl3YJ0IiP4',
#  'accountId': '5cOWK_syczktZoZU0wdgARLNc_L1dHPOlgn_1a62QaS7heo',
#  'puuid': 'cjVfM5Nc7iO5gZN_hqouK6rinFXdxxsXcjpM7IQrQelVtvvXnOD4IV8WkNSAz-D-qzyY55LcGE9v6g',
#  'profileIconId': 5849,
#  'revisionDate': 1722008357912,
#  'summonerLevel': 569}

# %%
temp_summoners['puuid']
# Out:
# 'cjVfM5Nc7iO5gZN_hqouK6rinFXdxxsXcjpM7IQrQelVtvvXnOD4IV8WkNSAz-D-qzyY55LcGE9v6g'

# %%
def match_list(puuid):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?type=ranked&start={0}&count={100}"
    
    return requests.get(url, headers=header)

# %%
puuid = temp_summoners['puuid']

temp_match_list = match_list(puuid).json()
temp_match_list
# Out:
# ['KR_7182596737',
#  'KR_7180374933',
#  'KR_7180342729',
#  'KR_7180267271',
#  'KR_7177719869',
#  'KR_7177663737',
#  'KR_7177606085',
#  'KR_7177513452',
#  'KR_7174799522',
#  'KR_7174726780',
#  'KR_7174604539',
#  'KR_7174467198',
#  'KR_7171633891',
#  'KR_7171494087',
#  'KR_7171385473',
#  'KR_7171258022',
#  'KR_7167645378',
#  'KR_7167369066',
#  'KR_7167231832',
#  'KR_7167110706',
#  'KR_7158641536',
#  'KR_7158518921',
#  'KR_7155002851',
#  'KR_7154864923',
#  'KR_7151377443',
#  'KR_7151365248',
#  'KR_7151324829',
#  'KR_7151301050',
#  'KR_7150574739',
#  'KR_7150308028',
#  'KR_7150262403',
#  'KR_7150229702',
#  'KR_7150190659',
#  'KR_7149200707',
#  'KR_7149166546',
#  'KR_7149134065',
#  'KR_7149090047',
#  'KR_7143963274',
#  'KR_7143925352',
#  'KR_7143173808',
#  'KR_7143156579',
#  'KR_7141798737',
#  'KR_7141782086',
#  'KR_7141755626',
#  'KR_7141714795',
#  'KR_7140616921',
#  'KR_7140574899',
#  'KR_7140530875',
#  'KR_7139480167',
#  'KR_7139433453',
#  'KR_7139384533',
#  'KR_7139344364',
#  'KR_7137963053',
#  'KR_7137887360',
#  'KR_7137815171',
#  'KR_7137737479',
#  'KR_7136833225',
#  'KR_7136356732',
#  'KR_7136330339',
#  'KR_7135756402',
#  'KR_7135714084',
#  'KR_7135685645',
#  'KR_7135425222',
#  'KR_7135384193',
#  'KR_7135334210',
#  'KR_7135071759',
#  'KR_7135027098',
#  'KR_7134968586',
#  'KR_7133971865',
#  'KR_7133946858',
#  'KR_7133924502',
#  'KR_7133894464',
#  'KR_7133847800',
#  'KR_7127526724',
#  'KR_7127460921',
#  'KR_7127394125',
#  'KR_7125348417',
#  'KR_7125321150',
#  'KR_7125277618',
#  'KR_7124276764',
#  'KR_7124255657',
#  'KR_7124234439',
#  'KR_7123219114',
#  'KR_7123151689',
#  'KR_7123109589',
#  'KR_7123083712',
#  'KR_7122803237',
#  'KR_7122744720',
#  'KR_7122655086',
#  'KR_7122610193',
#  'KR_7122044054',
#  'KR_7121948243',
#  'KR_7121879522',
#  'KR_7121803769',
#  'KR_7121562824',
#  'KR_7121503184',
#  'KR_7121440671',
#  'KR_7120498151',
#  'KR_7120450927',
#  'KR_7118878648']

# %%
import requests
 
api_key = "RGAPI-dca92473-57ec-4764-a5b1-33eb5e36bb00"
header = {"X-Riot-Token" : api_key}
 
def match(matchId):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{matchId}"
    
    return requests.get(url, headers=header)

# %%
matchId = temp_match_list[0]
temp_match_data = match(matchId).json()
temp_match_data
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_7182596737',
#   'participants': ['cjVfM5Nc7iO5gZN_hqouK6rinFXdxxsXcjpM7IQrQelVtvvXnOD4IV8WkNSAz-D-qzyY55LcGE9v6g',
#    '4ILqnQdyG8IQf0iVo10Sf1jbPMX5HsxFn44tAmRMZtTc8to1SO0mqc_6FPdRcHAdKpB-xQygpHFJ2w',
#    'FsMN0rQNi9IbwZuGuIxM4gdNQjTYut-5TaHCQSIKctaOwGnUFljkRCja07vFateQ3o5A1PVEyS4KiQ',
#    'KpYl5i_jo6rySp5e5AvmM61Nf4RWVmU5oLgeTSZBu30XP8KQ37b7VAxzveCKsTH4uzKzb6zjVbpN3A',
#    'LPd1KERkv3Ol60alze92LTflCrJKPyEUy-nHV0Rh50KeTi1pVZif8JwZWuX-z8KlAt6UpYy-EPEZHg',
#    'Ba-E3YI4rY2Dk_10VY8JE-DgZDZJOyqij9t3-ucyp6IpM0jVFUX0hzK6flNQmZ6NwX4Hs_HBbE6_Jg',
#    '-Jh15h2hNci_4UVWknvb0tVZYOHHSeJjMHjZcWe-BI_vSJSCyEQFMjUxkzcqBzOlNleoe2ifg1m9Vg',
#    'k7SHhVZb57GEORwsw2b71hWZ-di-KW_f8kLNG88APAI8tp3RzFpzHX2Cj2bfagUmGbgfND5s8Dg6Gg',
#    'D2SBkIL5HA6dqxnIypndo3c19JHiJo9HdnqNecr58sdqv7Ok-7pud7rC08el4rrAv4SHyWBkDMEVcg',
#    '22CHQ3NCrz2ayiZgc8uqHNdlNrR1rwxPEgqyWJMHGhcCPeHQdPUYFt3vbZHxRxcb538-Yyku99sx9w']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1722006856858,
#   'gameDuration': 1485,
#   'gameEndTimestamp': 1722008355896,
#   'gameId': 7182596737,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-7182596737',
#   'gameStartTimestamp': 1722006870701,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '14.14.603.4237',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 6,
#     'assists': 17,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 5,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 7,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 245,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 1,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7337733952462397,
#      'controlWardsPlaced': 7,
#      'damagePerMinute': 827.0244475878159,
#      'damageTakenOnTeamPercentage': 0.1236575311941941,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 1,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1378.355049687,
#      'earliestDragonTakedown': 1196.540701356,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 6261.54833984375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 39,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 3,
#      'gameLength': 1485.479675233,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 383.8060680243391,
#      'hadOpenNexus': 0,
#      'highestCrowdControlScore': 1,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 13,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 22,
#      'killAfterHiddenWithAlly': 4,
#      'killParticipation': 0.8148148148148148,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 1,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 34,
#      'laneMinionsFirst10Minutes': 12,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3870, 6617, 2065],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 16,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 16,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 2,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#      'skillshotsDodged': 48,
#      'skillshotsHit': 156,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 25,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 22,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 5,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.21507518294396177,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 4,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 2,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.1744394302368164,
#      'visionScorePerMinute': 2.858796819045269,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 15,
#      'wardTakedownsBefore20M': 13,
#      'wardsGuarded': 1},
#     'champExperience': 9842,
#     'champLevel': 12,
#     'championId': 147,
#     'championName': 'Seraphine',
#     'championTransform': 0,
#     'commandPings': 12,
#     'consumablesPurchased': 12,
#     'damageDealtToBuildings': 667,
#     'damageDealtToObjectives': 4136,
#     'damageDealtToTurrets': 667,
#     'damageSelfMitigated': 7427,
#     'dangerPings': 0,
#     'deaths': 1,
#     'detectorWardsPlaced': 8,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 11,
#     'enemyVisionPings': 8,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 9502,
#     'goldSpent': 8300,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3870,
#     'item1': 2065,
#     'item2': 4638,
#     'item3': 6617,
#     'item4': 3158,
#     'item5': 3114,
#     'item6': 3364,
#     'itemsPurchased': 28,
#     'killingSprees': 1,
#     'kills': 5,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 789,
#     'magicDamageDealt': 38083,
#     'magicDamageDealtToChampions': 17997,
#     'magicDamageTaken': 5083,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 9,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8369, 'var1': 416, 'var2': 415, 'var3': 0},
#         {'perk': 8321, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8316, 'var1': 10, 'var2': 25, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8226, 'var1': 250, 'var2': 520, 'var3': 0},
#         {'perk': 8237, 'var1': 776, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 6646,
#     'physicalDamageDealtToChampions': 2090,
#     'physicalDamageTaken': 7695,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5849,
#     'pushPings': 0,
#     'puuid': 'cjVfM5Nc7iO5gZN_hqouK6rinFXdxxsXcjpM7IQrQelVtvvXnOD4IV8WkNSAz-D-qzyY55LcGE9v6g',
#     'quadraKills': 0,
#     'riotIdGameName': 'BeryL',
#     'riotIdTagline': '000',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 110,
#     'spell2Casts': 57,
#     'spell3Casts': 71,
#     'spell4Casts': 7,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 7,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': '9Ave2rsRb8fj7uWkpkHk6lbX66qYy_GFCc-TgPl3YJ0IiP4',
#     'summonerLevel': 569,
#     'summonerName': 'DRX B2ryL',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 44,
#     'timePlayed': 1485,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 46404,
#     'totalDamageDealtToChampions': 20475,
#     'totalDamageShieldedOnTeammates': 2530,
#     'totalDamageTaken': 13215,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 6975,
#     'totalHealsOnTeammates': 3730,
#     'totalMinionsKilled': 39,
#     'totalTimeCCDealt': 174,
#     'totalTimeSpentDead': 16,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 1673,
#     'trueDamageDealtToChampions': 387,
#     'trueDamageTaken': 436,
#     'turretKills': 0,
#     'turretTakedowns': 3,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 70,
#     'visionWardsBoughtInGame': 7,
#     'wardsKilled': 13,
#     'wardsPlaced': 33,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 15,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 5,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 319,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.568977553924747,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 528.0736248348256,
#      'damageTakenOnTeamPercentage': 0.12124764203392745,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 0,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1378.355049687,
#      'earliestDragonTakedown': 1196.540701356,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 7399.2548828125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 5,
#      'enemyJungleMonsterKills': 1,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 3,
#      'gameLength': 1485.479675233,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 450.63580686571953,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 3,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 19,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.7037037037037037,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 3,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 84,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3118, 4629, 3137],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 1,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 1,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 13,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#      'skillshotsDodged': 63,
#      'skillshotsHit': 19,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 19,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.13733031931582818,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'teleportTakedowns': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 5,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.15446388721466064,
#      'visionScorePerMinute': 0.8659395502027832,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 5,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 14352,
#     'champLevel': 15,
#     'championId': 43,
#     'championName': 'Karma',
#     'championTransform': 0,
#     'commandPings': 1,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 3581,
#     'damageDealtToObjectives': 9083,
#     'damageDealtToTurrets': 3581,
#     'damageSelfMitigated': 10645,
#     'dangerPings': 0,
#     'deaths': 0,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 1,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 7,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 11156,
#     'goldSpent': 10250,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3158,
#     'item1': 3118,
#     'item2': 3137,
#     'item3': 1056,
#     'item4': 4629,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 24,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 0,
#     'magicDamageDealt': 106352,
#     'magicDamageDealtToChampions': 12281,
#     'magicDamageTaken': 4934,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 5,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 5,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 811, 'var2': 833, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 835, 'var3': 0},
#         {'perk': 8210, 'var1': 13, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 457, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 377, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 14793,
#     'physicalDamageDealtToChampions': 415,
#     'physicalDamageTaken': 7813,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4080,
#     'pushPings': 0,
#     'puuid': '4ILqnQdyG8IQf0iVo10Sf1jbPMX5HsxFn44tAmRMZtTc8to1SO0mqc_6FPdRcHAdKpB-xQygpHFJ2w',
#     'quadraKills': 0,
#     'riotIdGameName': 'ad 미드 좋아해',
#     'riotIdTagline': 'jing',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 122,
#     'spell2Casts': 24,
#     'spell3Casts': 129,
#     'spell4Casts': 44,
#     'subteamPlacement': 0,
#     'summoner1Casts': 1,
#     'summoner1Id': 4,
#     'summoner2Casts': 4,
#     'summoner2Id': 12,
#     'summonerId': 'g9kHpvpql_Ci3ioM5SeRTaTVbucVAPTABBxiLJTOD0Tzz4M',
#     'summonerLevel': 68,
#     'summonerName': '73580818del',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 14,
#     'timePlayed': 1485,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 122223,
#     'totalDamageDealtToChampions': 13074,
#     'totalDamageShieldedOnTeammates': 7208,
#     'totalDamageTaken': 12958,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 2451,
#     'totalHealsOnTeammates': 190,
#     'totalMinionsKilled': 189,
#     'totalTimeCCDealt': 238,
#     'totalTimeSpentDead': 0,
#     'totalUnitsHealed': 2,
#     'tripleKills': 0,
#     'trueDamageDealt': 1077,
#     'trueDamageDealtToChampions': 377,
#     'trueDamageTaken': 210,
#     'turretKills': 1,
#     'turretTakedowns': 5,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 21,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 5,
#     'wardsPlaced': 8,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 10,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 1,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 3,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 163,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.14396952142980696,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 642.2063843454242,
#      'damageTakenOnTeamPercentage': 0.13783792975481027,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 4,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1378.355049687,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 17,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 3,
#      'gameLength': 1485.479675233,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 398.56944950349674,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 5,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.25,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.48148148148148145,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 78,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3087, 3094],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 34,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 34,
#      'skillshotsHit': 7,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 6,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 13,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.1670115750552901,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 3,
#      'turretTakedowns': 3,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.5726776123046875,
#      'visionScorePerMinute': 0.41233892693941027,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 11213,
#     'champLevel': 13,
#     'championId': 202,
#     'championName': 'Jhin',
#     'championTransform': 0,
#     'commandPings': 3,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 4632,
#     'damageDealtToObjectives': 7913,
#     'damageDealtToTurrets': 4632,
#     'damageSelfMitigated': 7606,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 15,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 9867,
#     'goldSpent': 8500,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 1,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 1018,
#     'item1': 1037,
#     'item2': 3009,
#     'item3': 3094,
#     'item4': 3087,
#     'item5': 1055,
#     'item6': 3363,
#     'itemsPurchased': 18,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 829,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 509,
#     'magicDamageDealt': 18097,
#     'magicDamageDealtToChampions': 1653,
#     'magicDamageTaken': 3579,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 7,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 1795, 'var2': 1799, 'var3': 0},
#         {'perk': 8009, 'var1': 1922, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 19, 'var2': 20, 'var3': 0},
#         {'perk': 8017, 'var1': 938, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 108023,
#     'physicalDamageDealtToChampions': 14246,
#     'physicalDamageTaken': 10889,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 4834,
#     'pushPings': 0,
#     'puuid': 'FsMN0rQNi9IbwZuGuIxM4gdNQjTYut-5TaHCQSIKctaOwGnUFljkRCja07vFateQ3o5A1PVEyS4KiQ',
#     'quadraKills': 0,
#     'riotIdGameName': '쪼사기',
#     'riotIdTagline': 'KR1',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 65,
#     'spell2Casts': 49,
#     'spell3Casts': 33,
#     'spell4Casts': 16,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 21,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'Fszfd1mLLW05ylSHW2d-1h5zhL4s2uyGwsvae8WJCnfJo9o',
#     'summonerLevel': 437,
#     'summonerName': '쪼사기',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 29,
#     'timePlayed': 1485,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 129125,
#     'totalDamageDealtToChampions': 15899,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 14731,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3633,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 199,
#     'totalTimeCCDealt': 139,
#     'totalTimeSpentDead': 102,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 3005,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 262,
#     'turretKills': 1,
#     'turretTakedowns': 3,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 10,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 8,
#     'win': True},
#    {'allInPings': 5,
#     'assistMePings': 9,
#     'assists': 8,
#     'baronKills': 1,
#     'basicPings': 0,
#     'bountyLevel': 6,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 9,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 396,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 87,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 375,
#      'buffsStolen': 2,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6778053802002181,
#      'controlWardsPlaced': 5,
#      'damagePerMinute': 808.729299720352,
#      'damageTakenOnTeamPercentage': 0.33946842344364003,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 6,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestBaron': 1378.355049687,
#      'earliestDragonTakedown': 1196.540701356,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 19,
#      'enemyJungleMonsterKills': 12,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 3,
#      'gameLength': 1485.479675233,
#      'goldPerMinute': 498.3726362724412,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 12,
#      'initialBuffCount': 2,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 68.00000008940697,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 1,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 5.666666666666667,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.6296296296296297,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 0,
#      'killsOnLanersEarlyJungleAsJungler': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 2,
#      'laneMinionsFirst10Minutes': 3,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6672,
#       6672,
#       3087,
#       6672,
#       3094,
#       6672,
#       6672,
#       6664,
#       6672,
#       3100,
#       6672,
#       3087,
#       3046,
#       6672,
#       6610,
#       3142,
#       3877,
#       6672,
#       6610,
#       3094,
#       6672,
#       6672,
#       6610,
#       3100,
#       6672,
#       6610,
#       3053,
#       6664,
#       6672,
#       3053,
#       6610],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 49.15000006556511,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -46.50000008940697,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 2,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 14,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 5,
#      'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#      'skillshotsDodged': 67,
#      'skillshotsHit': 15,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 1,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 17,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 7,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.21031736437395654,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.06280851364135742,
#      'visionScorePerMinute': 1.1584860479915973,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 7,
#      'wardTakedownsBefore20M': 7,
#      'wardsGuarded': 1},
#     'champExperience': 13651,
#     'champLevel': 15,
#     'championId': 234,
#     'championName': 'Viego',
#     'championTransform': 0,
#     'commandPings': 27,
#     'consumablesPurchased': 6,
#     'damageDealtToBuildings': 1676,
#     'damageDealtToObjectives': 12049,
#     'damageDealtToTurrets': 1676,
#     'damageSelfMitigated': 25266,
#     'dangerPings': 0,
#     'deaths': 3,
#     'detectorWardsPlaced': 5,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 9,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 4,
#     'goldEarned': 12338,
#     'goldSpent': 11425,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 6610,
#     'item1': 6672,
#     'item2': 0,
#     'item3': 1036,
#     'item4': 3053,
#     'item5': 3111,
#     'item6': 3364,
#     'itemsPurchased': 21,
#     'killingSprees': 2,
#     'kills': 9,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 318,
#     'largestKillingSpree': 6,
#     'largestMultiKill': 3,
#     'longestTimeSpentLiving': 362,
#     'magicDamageDealt': 7540,
#     'magicDamageDealtToChampions': 2683,
#     'magicDamageTaken': 10502,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 168,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 43,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 625, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 1413, 'var2': 340, 'var3': 0},
#         {'perk': 9104, 'var1': 10, 'var2': 50, 'var3': 0},
#         {'perk': 8014, 'var1': 631, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 9, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 159728,
#     'physicalDamageDealtToChampions': 16828,
#     'physicalDamageTaken': 24818,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6631,
#     'pushPings': 0,
#     'puuid': 'KpYl5i_jo6rySp5e5AvmM61Nf4RWVmU5oLgeTSZBu30XP8KQ37b7VAxzveCKsTH4uzKzb6zjVbpN3A',
#     'quadraKills': 0,
#     'riotIdGameName': 'HLE',
#     'riotIdTagline': '0205',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 179,
#     'spell2Casts': 132,
#     'spell3Casts': 68,
#     'spell4Casts': 17,
#     'subteamPlacement': 0,
#     'summoner1Casts': 13,
#     'summoner1Id': 11,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'n7197s3SbRj7KIeSLuYpKNI2qw_npW1blRFprEY7vFIa7mZXLjIU89ydEA',
#     'summonerLevel': 422,
#     'summonerName': '날씨좋은날1',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 24,
#     'timePlayed': 1485,
#     'totalAllyJungleMinionsKilled': 121,
#     'totalDamageDealt': 223076,
#     'totalDamageDealtToChampions': 20022,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 36280,
#     'totalEnemyJungleMinionsKilled': 15,
#     'totalHeal': 21690,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 14,
#     'totalTimeCCDealt': 264,
#     'totalTimeSpentDead': 58,
#     'totalUnitsHealed': 1,
#     'tripleKills': 1,
#     'trueDamageDealt': 55806,
#     'trueDamageDealtToChampions': 510,
#     'trueDamageTaken': 959,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 28,
#     'visionWardsBoughtInGame': 11,
#     'wardsKilled': 7,
#     'wardsPlaced': 6,
#     'win': True},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 8,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 4,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 10,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 267,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 1,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6179873640923488,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 1039.246932187312,
#      'damageTakenOnTeamPercentage': 0.2777884735734281,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 10,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1378.355049687,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 2504.55224609375,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 3,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 2,
#      'fullTeamTakedown': 3,
#      'gameLength': 1485.479675233,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 496.76362317731076,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 1,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 3.5,
#      'killAfterHiddenWithAlly': 0,
#      'killParticipation': 0.5185185185185185,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 5,
#      'laneMinionsFirst10Minutes': 55,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3074, 3078, 6333],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 6.5,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 4,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 8,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'shortestTimeToAceFromFirstTakedown': 41.0937624820001,
#      'skillshotsDodged': 75,
#      'skillshotsHit': 17,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'soloTurretsLategame': 3,
#      'stealthWardsPlaced': 8,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 14,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.27026555831096344,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 6,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.07654917240142822,
#      'visionScorePerMinute': 0.928378229167042,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 8,
#      'wardTakedownsBefore20M': 5,
#      'wardsGuarded': 0},
#     'champExperience': 13696,
#     'champLevel': 15,
#     'championId': 114,
#     'championName': 'Fiora',
#     'championTransform': 0,
#     'commandPings': 10,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 11675,
#     'damageDealtToObjectives': 15009,
#     'damageDealtToTurrets': 11675,
#     'damageSelfMitigated': 29734,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 1,
#     'goldEarned': 12298,
#     'goldSpent': 11633,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3074,
#     'item1': 3078,
#     'item2': 2055,
#     'item3': 6333,
#     'item4': 3047,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 22,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'TOP',
#     'largestCriticalStrike': 609,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 362,
#     'magicDamageDealt': 3385,
#     'magicDamageDealtToChampions': 1650,
#     'magicDamageTaken': 10090,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 3,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 2,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 2979, 'var2': 3819, 'var3': 0},
#         {'perk': 8009, 'var1': 2408, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 17, 'var2': 50, 'var3': 0},
#         {'perk': 8299, 'var1': 410, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8451, 'var1': 176, 'var2': 0, 'var3': 0},
#         {'perk': 8444, 'var1': 1359, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 130178,
#     'physicalDamageDealtToChampions': 17565,
#     'physicalDamageTaken': 18298,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6502,
#     'pushPings': 0,
#     'puuid': 'LPd1KERkv3Ol60alze92LTflCrJKPyEUy-nHV0Rh50KeTi1pVZif8JwZWuX-z8KlAt6UpYy-EPEZHg',
#     'quadraKills': 0,
#     'riotIdGameName': '어색했',
#     'riotIdTagline': 'KR1',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 180,
#     'spell2Casts': 25,
#     'spell3Casts': 54,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 12,
#     'summoner2Casts': 2,
#     'summoner2Id': 4,
#     'summonerId': 'bAAkqwo4qp_WYrSR6csuG5JzhO2htBUP-9yqCyWPBJkPvfg',
#     'summonerLevel': 527,
#     'summonerName': '어색했',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 15,
#     'timePlayed': 1485,
#     'totalAllyJungleMinionsKilled': 2,
#     'totalDamageDealt': 142791,
#     'totalDamageDealtToChampions': 25729,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 29688,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 17458,
#     'totalHealsOnTeammates': 2504,
#     'totalMinionsKilled': 192,
#     'totalTimeCCDealt': 170,
#     'totalTimeSpentDead': 66,
#     'totalUnitsHealed': 6,
#     'tripleKills': 0,
#     'trueDamageDealt': 9227,
#     'trueDamageDealtToChampions': 6513,
#     'trueDamageTaken': 1300,
#     'turretKills': 6,
#     'turretTakedowns': 6,
#     'turretsLost': 5,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 22,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 5,
#     'wardsPlaced': 10,
#     'win': True},
#    {'allInPings': 3,
#     'assistMePings': 2,
#     'assists': 5,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 5,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 753,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 4,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7647381175227564,
#      'controlWardsPlaced': 3,
#      'damagePerMinute': 1127.6329971830557,
#      'damageTakenOnTeamPercentage': 0.1837177767205851,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 3,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 2,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
# ...
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 1,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 42,
#      'skillshotsHit': 22,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 3,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 1,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 1,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.09867205751563979,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 1.340153455734253,
#      'visionScorePerMinute': 0.9649363432595157,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 10,
#      'wardTakedownsBefore20M': 8,
#      'wardsGuarded': 0},
#     'champExperience': 10177,
#     'champLevel': 13,
#     'championId': 516,
#     'championName': 'Ornn',
#     'championTransform': 0,
#     'commandPings': 19,
#     'consumablesPurchased': 5,
#     'damageDealtToBuildings': 718,
#     'damageDealtToObjectives': 940,
#     'damageDealtToTurrets': 718,
#     'damageSelfMitigated': 30339,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 3,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 6,
#     'enemyVisionPings': 4,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 10,
#     'goldEarned': 7857,
#     'goldSpent': 7075,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6664,
#     'item1': 3076,
#     'item2': 1011,
#     'item3': 1054,
#     'item4': 3082,
#     'item5': 3047,
#     'item6': 3364,
#     'itemsPurchased': 24,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 4,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 464,
#     'magicDamageDealt': 45386,
#     'magicDamageDealtToChampions': 4886,
#     'magicDamageTaken': 10170,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 24,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5001, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8360, 'var1': 5, 'var2': 0, 'var3': 0},
#         {'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#         {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8444, 'var1': 1395, 'var2': 0, 'var3': 0},
#         {'perk': 8451, 'var1': 210, 'var2': 0, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 38178,
#     'physicalDamageDealtToChampions': 2728,
#     'physicalDamageTaken': 16268,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 7,
#     'pushPings': 0,
#     'puuid': 'D2SBkIL5HA6dqxnIypndo3c19JHiJo9HdnqNecr58sdqv7Ok-7pud7rC08el4rrAv4SHyWBkDMEVcg',
#     'quadraKills': 0,
#     'riotIdGameName': '장미장미',
#     'riotIdTagline': 'KR1',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 66,
#     'spell2Casts': 58,
#     'spell3Casts': 25,
#     'spell4Casts': 14,
#     'subteamPlacement': 0,
#     'summoner1Casts': 3,
#     'summoner1Id': 4,
#     'summoner2Casts': 8,
#     'summoner2Id': 12,
#     'summonerId': '5UvCuYhJhdvtDQ6ul6vJs_MxsrL1I9aSgpCICzSoMf1KfdI',
#     'summonerLevel': 250,
#     'summonerName': '장미장미',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 21,
#     'timePlayed': 1485,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 89432,
#     'totalDamageDealtToChampions': 7730,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 29520,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 373,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 177,
#     'totalTimeCCDealt': 372,
#     'totalTimeSpentDead': 209,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 5867,
#     'trueDamageDealtToChampions': 116,
#     'trueDamageTaken': 3081,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 8,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 23,
#     'visionWardsBoughtInGame': 4,
#     'wardsKilled': 8,
#     'wardsPlaced': 7,
#     'win': False},
#    {'allInPings': 1,
#     'assistMePings': 3,
#     'assists': 5,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 2,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 833,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 58,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 1,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7726749525542762,
#      'controlWardsPlaced': 4,
#      'damagePerMinute': 479.7764887254092,
#      'damageTakenOnTeamPercentage': 0.26985949667519893,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 844.445840157,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 3735.291015625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 9,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 733.4644541480001,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1485.479675233,
#      'goldPerMinute': 331.46466535145873,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 58.50000008940697,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.8888888888888888,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.6666666666666666,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 1,
#      'killsOnLanersEarlyJungleAsJungler': 1,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 3,
#      'laneMinionsFirst10Minutes': 5,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3100, 6653],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 4,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -59.50000008940697,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 1,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 5,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 1,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 2,
#      'skillshotsDodged': 22,
#      'skillshotsHit': 16,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 2,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 8,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1516058861665225,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 1,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.05909675359725952,
#      'visionScorePerMinute': 1.0900232491893052,
#      'voidMonsterKill': 7,
#      'wardTakedowns': 7,
#      'wardTakedownsBefore20M': 6,
#      'wardsGuarded': 0},
#     'champExperience': 8747,
#     'champLevel': 12,
#     'championId': 76,
#     'championName': 'Nidalee',
#     'championTransform': 0,
#     'commandPings': 7,
#     'consumablesPurchased': 7,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 35356,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 16737,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 4,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 5,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 8206,
#     'goldSpent': 8100,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 1,
#     'item0': 6653,
#     'item1': 3100,
#     'item2': 2055,
#     'item3': 3020,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 23,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 405,
#     'magicDamageDealt': 105814,
#     'magicDamageDealtToChampions': 9041,
#     'magicDamageTaken': 9661,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 118,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 41,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 425, 'var2': 0, 'var3': 0},
#         {'perk': 8143, 'var1': 435, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 16, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 210, 'var2': 3, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 4, 'var2': 40, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 16177,
#     'physicalDamageDealtToChampions': 1156,
#     'physicalDamageTaken': 22861,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3495,
#     'pushPings': 1,
#     'puuid': '22CHQ3NCrz2ayiZgc8uqHNdlNrR1rwxPEgqyWJMHGhcCPeHQdPUYFt3vbZHxRxcb538-Yyku99sx9w',
#     'quadraKills': 0,
#     'riotIdGameName': '치킨사줬더니닭다리만골라먹는김견',
#     'riotIdTagline': '김 견',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 210,
#     'spell2Casts': 248,
#     'spell3Casts': 134,
#     'spell4Casts': 241,
#     'subteamPlacement': 0,
#     'summoner1Casts': 15,
#     'summoner1Id': 11,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'bJoj1swEs9VNsAlI9h6jCrVTFn3FsXswXNpE1zFCFcCI1d14',
#     'summonerLevel': 740,
#     'summonerName': '나는 멍청이 우우',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 8,
#     'timePlayed': 1485,
#     'totalAllyJungleMinionsKilled': 79,
#     'totalDamageDealt': 180061,
#     'totalDamageDealtToChampions': 11878,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 33163,
#     'totalEnemyJungleMinionsKilled': 10,
#     'totalHeal': 17210,
#     'totalHealsOnTeammates': 3735,
#     'totalMinionsKilled': 15,
#     'totalTimeCCDealt': 67,
#     'totalTimeSpentDead': 212,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 58069,
#     'trueDamageDealtToChampions': 1680,
#     'trueDamageTaken': 641,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 8,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 26,
#     'visionWardsBoughtInGame': 6,
#     'wardsKilled': 7,
#     'wardsPlaced': 6,
#     'win': False}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 85, 'pickTurn': 1},
#      {'championId': 910, 'pickTurn': 2},
#      {'championId': 119, 'pickTurn': 3},
#      {'championId': 35, 'pickTurn': 4},
#      {'championId': 893, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': True, 'kills': 28},
#      'dragon': {'first': False, 'kills': 1},
#      'horde': {'first': False, 'kills': 0},
#      'inhibitor': {'first': True, 'kills': 1},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 8}},
#     'teamId': 100,
#     'win': True},
#    {'bans': [{'championId': 81, 'pickTurn': 6},
#      {'championId': 64, 'pickTurn': 7},
#      {'championId': 893, 'pickTurn': 8},
#      {'championId': 33, 'pickTurn': 9},
#      {'championId': 35, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': False, 'kills': 12},
#      'dragon': {'first': True, 'kills': 1},
#      'horde': {'first': True, 'kills': 6},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': True, 'kills': 1},
#      'tower': {'first': True, 'kills': 5}},
#     'teamId': 200,
#     'win': False}],
#   'tournamentCode': ''}}

# %%
temp_match_data['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_7182596737',
#  'participants': ['cjVfM5Nc7iO5gZN_hqouK6rinFXdxxsXcjpM7IQrQelVtvvXnOD4IV8WkNSAz-D-qzyY55LcGE9v6g',
#   '4ILqnQdyG8IQf0iVo10Sf1jbPMX5HsxFn44tAmRMZtTc8to1SO0mqc_6FPdRcHAdKpB-xQygpHFJ2w',
#   'FsMN0rQNi9IbwZuGuIxM4gdNQjTYut-5TaHCQSIKctaOwGnUFljkRCja07vFateQ3o5A1PVEyS4KiQ',
#   'KpYl5i_jo6rySp5e5AvmM61Nf4RWVmU5oLgeTSZBu30XP8KQ37b7VAxzveCKsTH4uzKzb6zjVbpN3A',
#   'LPd1KERkv3Ol60alze92LTflCrJKPyEUy-nHV0Rh50KeTi1pVZif8JwZWuX-z8KlAt6UpYy-EPEZHg',
#   'Ba-E3YI4rY2Dk_10VY8JE-DgZDZJOyqij9t3-ucyp6IpM0jVFUX0hzK6flNQmZ6NwX4Hs_HBbE6_Jg',
#   '-Jh15h2hNci_4UVWknvb0tVZYOHHSeJjMHjZcWe-BI_vSJSCyEQFMjUxkzcqBzOlNleoe2ifg1m9Vg',
#   'k7SHhVZb57GEORwsw2b71hWZ-di-KW_f8kLNG88APAI8tp3RzFpzHX2Cj2bfagUmGbgfND5s8Dg6Gg',
#   'D2SBkIL5HA6dqxnIypndo3c19JHiJo9HdnqNecr58sdqv7Ok-7pud7rC08el4rrAv4SHyWBkDMEVcg',
#   '22CHQ3NCrz2ayiZgc8uqHNdlNrR1rwxPEgqyWJMHGhcCPeHQdPUYFt3vbZHxRxcb538-Yyku99sx9w']}

# %%
temp_match_data['info']
# Out:
# {'endOfGameResult': 'GameComplete',
#  'gameCreation': 1722006856858,
#  'gameDuration': 1485,
#  'gameEndTimestamp': 1722008355896,
#  'gameId': 7182596737,
#  'gameMode': 'CLASSIC',
#  'gameName': 'teambuilder-match-7182596737',
#  'gameStartTimestamp': 1722006870701,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '14.14.603.4237',
#  'mapId': 11,
#  'participants': [{'allInPings': 0,
#    'assistMePings': 6,
#    'assists': 17,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 5,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 7,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 245,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 1,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7337733952462397,
#     'controlWardsPlaced': 7,
#     'damagePerMinute': 827.0244475878159,
#     'damageTakenOnTeamPercentage': 0.1236575311941941,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 1,
#     'dodgeSkillShotsSmallWindow': 3,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestBaron': 1378.355049687,
#     'earliestDragonTakedown': 1196.540701356,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 6261.54833984375,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 39,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 3,
#     'gameLength': 1485.479675233,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 383.8060680243391,
#     'hadOpenNexus': 0,
#     'highestCrowdControlScore': 1,
#     'highestWardKills': 1,
#     'immobilizeAndKillWithAlly': 13,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 22,
#     'killAfterHiddenWithAlly': 4,
#     'killParticipation': 0.8148148148148148,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 0,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 34,
#     'laneMinionsFirst10Minutes': 12,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3870, 6617, 2065],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 16,
#     'maxKillDeficit': 2,
#     'maxLevelLeadLaneOpponent': 2,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 16,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 2,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#     'skillshotsDodged': 48,
#     'skillshotsHit': 156,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 25,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 22,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 5,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.21507518294396177,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 4,
#     'turretTakedowns': 3,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 2,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.1744394302368164,
#     'visionScorePerMinute': 2.858796819045269,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 15,
#     'wardTakedownsBefore20M': 13,
#     'wardsGuarded': 1},
#    'champExperience': 9842,
#    'champLevel': 12,
#    'championId': 147,
#    'championName': 'Seraphine',
#    'championTransform': 0,
#    'commandPings': 12,
#    'consumablesPurchased': 12,
#    'damageDealtToBuildings': 667,
#    'damageDealtToObjectives': 4136,
#    'damageDealtToTurrets': 667,
#    'damageSelfMitigated': 7427,
#    'dangerPings': 0,
#    'deaths': 1,
#    'detectorWardsPlaced': 8,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 11,
#    'enemyVisionPings': 8,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 9502,
#    'goldSpent': 8300,
#    'holdPings': 0,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 3870,
#    'item1': 2065,
#    'item2': 4638,
#    'item3': 6617,
#    'item4': 3158,
#    'item5': 3114,
#    'item6': 3364,
#    'itemsPurchased': 28,
#    'killingSprees': 1,
#    'kills': 5,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 5,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 789,
#    'magicDamageDealt': 38083,
#    'magicDamageDealtToChampions': 17997,
#    'magicDamageTaken': 5083,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 1,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 9,
#    'participantId': 1,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5007},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8369, 'var1': 416, 'var2': 415, 'var3': 0},
#        {'perk': 8321, 'var1': 0, 'var2': 0, 'var3': 0},
#        {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8316, 'var1': 10, 'var2': 25, 'var3': 0}],
#       'style': 8300},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8226, 'var1': 250, 'var2': 520, 'var3': 0},
#        {'perk': 8237, 'var1': 776, 'var2': 0, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 6646,
#    'physicalDamageDealtToChampions': 2090,
#    'physicalDamageTaken': 7695,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 5849,
#    'pushPings': 0,
#    'puuid': 'cjVfM5Nc7iO5gZN_hqouK6rinFXdxxsXcjpM7IQrQelVtvvXnOD4IV8WkNSAz-D-qzyY55LcGE9v6g',
#    'quadraKills': 0,
#    'riotIdGameName': 'BeryL',
#    'riotIdTagline': '000',
#    'role': 'SUPPORT',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 110,
#    'spell2Casts': 57,
#    'spell3Casts': 71,
#    'spell4Casts': 7,
#    'subteamPlacement': 0,
#    'summoner1Casts': 5,
#    'summoner1Id': 7,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': '9Ave2rsRb8fj7uWkpkHk6lbX66qYy_GFCc-TgPl3YJ0IiP4',
#    'summonerLevel': 569,
#    'summonerName': 'DRX B2ryL',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'UTILITY',
#    'timeCCingOthers': 44,
#    'timePlayed': 1485,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 46404,
#    'totalDamageDealtToChampions': 20475,
#    'totalDamageShieldedOnTeammates': 2530,
#    'totalDamageTaken': 13215,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 6975,
#    'totalHealsOnTeammates': 3730,
#    'totalMinionsKilled': 39,
#    'totalTimeCCDealt': 174,
#    'totalTimeSpentDead': 16,
#    'totalUnitsHealed': 5,
#    'tripleKills': 0,
#    'trueDamageDealt': 1673,
#    'trueDamageDealtToChampions': 387,
#    'trueDamageTaken': 436,
#    'turretKills': 0,
#    'turretTakedowns': 3,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 70,
#    'visionWardsBoughtInGame': 7,
#    'wardsKilled': 13,
#    'wardsPlaced': 33,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 15,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 4,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 5,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 319,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.568977553924747,
#     'controlWardsPlaced': 4,
#     'damagePerMinute': 528.0736248348256,
#     'damageTakenOnTeamPercentage': 0.12124764203392745,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 0,
#     'dodgeSkillShotsSmallWindow': 4,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestBaron': 1378.355049687,
#     'earliestDragonTakedown': 1196.540701356,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 7399.2548828125,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 5,
#     'enemyJungleMonsterKills': 1,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 3,
#     'gameLength': 1485.479675233,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 450.63580686571953,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 3,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 19,
#     'killAfterHiddenWithAlly': 1,
#     'killParticipation': 0.7037037037037037,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 3,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 1,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 3,
#     'laneMinionsFirst10Minutes': 84,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3118, 4629, 3137],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 1,
#     'maxKillDeficit': 2,
#     'maxLevelLeadLaneOpponent': 2,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 13,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#     'skillshotsDodged': 63,
#     'skillshotsHit': 19,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 4,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 19,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 4,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.13733031931582818,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'teleportTakedowns': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 1,
#     'turretTakedowns': 5,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.15446388721466064,
#     'visionScorePerMinute': 0.8659395502027832,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 5,
#     'wardTakedownsBefore20M': 1,
#     'wardsGuarded': 0},
#    'champExperience': 14352,
#    'champLevel': 15,
#    'championId': 43,
#    'championName': 'Karma',
#    'championTransform': 0,
#    'commandPings': 1,
#    'consumablesPurchased': 6,
#    'damageDealtToBuildings': 3581,
#    'damageDealtToObjectives': 9083,
#    'damageDealtToTurrets': 3581,
#    'damageSelfMitigated': 10645,
#    'dangerPings': 0,
#    'deaths': 0,
#    'detectorWardsPlaced': 4,
#    'doubleKills': 1,
#    'dragonKills': 1,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 7,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 11156,
#    'goldSpent': 10250,
#    'holdPings': 0,
#    'individualPosition': 'MIDDLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 3158,
#    'item1': 3118,
#    'item2': 3137,
#    'item3': 1056,
#    'item4': 4629,
#    'item5': 0,
#    'item6': 3364,
#    'itemsPurchased': 24,
#    'killingSprees': 1,
#    'kills': 4,
#    'lane': 'MIDDLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 2,
#    'longestTimeSpentLiving': 0,
#    'magicDamageDealt': 106352,
#    'magicDamageDealtToChampions': 12281,
#    'magicDamageTaken': 4934,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 5,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 5,
#    'participantId': 2,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8214, 'var1': 811, 'var2': 833, 'var3': 0},
#        {'perk': 8226, 'var1': 250, 'var2': 835, 'var3': 0},
#        {'perk': 8210, 'var1': 13, 'var2': 0, 'var3': 0},
#        {'perk': 8237, 'var1': 457, 'var2': 0, 'var3': 0}],
#       'style': 8200},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8126, 'var1': 377, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#       'style': 8100}]},
#    'physicalDamageDealt': 14793,
#    'physicalDamageDealtToChampions': 415,
#    'physicalDamageTaken': 7813,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4080,
#    'pushPings': 0,
#    'puuid': '4ILqnQdyG8IQf0iVo10Sf1jbPMX5HsxFn44tAmRMZtTc8to1SO0mqc_6FPdRcHAdKpB-xQygpHFJ2w',
#    'quadraKills': 0,
#    'riotIdGameName': 'ad 미드 좋아해',
#    'riotIdTagline': 'jing',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 122,
#    'spell2Casts': 24,
#    'spell3Casts': 129,
#    'spell4Casts': 44,
#    'subteamPlacement': 0,
#    'summoner1Casts': 1,
#    'summoner1Id': 4,
#    'summoner2Casts': 4,
#    'summoner2Id': 12,
#    'summonerId': 'g9kHpvpql_Ci3ioM5SeRTaTVbucVAPTABBxiLJTOD0Tzz4M',
#    'summonerLevel': 68,
#    'summonerName': '73580818del',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'MIDDLE',
#    'timeCCingOthers': 14,
#    'timePlayed': 1485,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 122223,
#    'totalDamageDealtToChampions': 13074,
#    'totalDamageShieldedOnTeammates': 7208,
#    'totalDamageTaken': 12958,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 2451,
#    'totalHealsOnTeammates': 190,
#    'totalMinionsKilled': 189,
#    'totalTimeCCDealt': 238,
#    'totalTimeSpentDead': 0,
#    'totalUnitsHealed': 2,
#    'tripleKills': 0,
#    'trueDamageDealt': 1077,
#    'trueDamageDealtToChampions': 377,
#    'trueDamageTaken': 210,
#    'turretKills': 1,
#    'turretTakedowns': 5,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 21,
#    'visionWardsBoughtInGame': 4,
#    'wardsKilled': 5,
#    'wardsPlaced': 8,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 10,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 1,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 3,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 163,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 0,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.14396952142980696,
#     'controlWardsPlaced': 1,
#     'damagePerMinute': 642.2063843454242,
#     'damageTakenOnTeamPercentage': 0.13783792975481027,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 4,
#     'dodgeSkillShotsSmallWindow': 4,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earliestBaron': 1378.355049687,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 17,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 3,
#     'gameLength': 1485.479675233,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 398.56944950349674,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 5,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3.25,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.48148148148148145,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 0,
#     'laneMinionsFirst10Minutes': 78,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3087, 3094],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 34,
#     'maxKillDeficit': 2,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 9,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 34,
#     'skillshotsHit': 7,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 6,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 13,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 4,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.1670115750552901,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 3,
#     'turretTakedowns': 3,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.5726776123046875,
#     'visionScorePerMinute': 0.41233892693941027,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 1,
#     'wardTakedownsBefore20M': 0,
#     'wardsGuarded': 0},
#    'champExperience': 11213,
#    'champLevel': 13,
#    'championId': 202,
#    'championName': 'Jhin',
#    'championTransform': 0,
#    'commandPings': 3,
#    'consumablesPurchased': 2,
#    'damageDealtToBuildings': 4632,
#    'damageDealtToObjectives': 7913,
#    'damageDealtToTurrets': 4632,
#    'damageSelfMitigated': 7606,
#    'dangerPings': 0,
#    'deaths': 4,
#    'detectorWardsPlaced': 1,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 15,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 9867,
#    'goldSpent': 8500,
#    'holdPings': 0,
#    'individualPosition': 'BOTTOM',
#    'inhibitorKills': 1,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 1018,
#    'item1': 1037,
#    'item2': 3009,
#    'item3': 3094,
#    'item4': 3087,
#    'item5': 1055,
#    'item6': 3363,
#    'itemsPurchased': 18,
#    'killingSprees': 0,
#    'kills': 3,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 829,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 509,
#    'magicDamageDealt': 18097,
#    'magicDamageDealtToChampions': 1653,
#    'magicDamageTaken': 3579,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 7,
#    'participantId': 3,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 1795, 'var2': 1799, 'var3': 0},
#        {'perk': 8009, 'var1': 1922, 'var2': 0, 'var3': 0},
#        {'perk': 9103, 'var1': 19, 'var2': 20, 'var3': 0},
#        {'perk': 8017, 'var1': 938, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 108023,
#    'physicalDamageDealtToChampions': 14246,
#    'physicalDamageTaken': 10889,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 4834,
#    'pushPings': 0,
#    'puuid': 'FsMN0rQNi9IbwZuGuIxM4gdNQjTYut-5TaHCQSIKctaOwGnUFljkRCja07vFateQ3o5A1PVEyS4KiQ',
#    'quadraKills': 0,
#    'riotIdGameName': '쪼사기',
#    'riotIdTagline': 'KR1',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 65,
#    'spell2Casts': 49,
#    'spell3Casts': 33,
#    'spell4Casts': 16,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 21,
#    'summoner2Casts': 3,
#    'summoner2Id': 4,
#    'summonerId': 'Fszfd1mLLW05ylSHW2d-1h5zhL4s2uyGwsvae8WJCnfJo9o',
#    'summonerLevel': 437,
#    'summonerName': '쪼사기',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 29,
#    'timePlayed': 1485,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 129125,
#    'totalDamageDealtToChampions': 15899,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 14731,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 3633,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 199,
#    'totalTimeCCDealt': 139,
#    'totalTimeSpentDead': 102,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 3005,
#    'trueDamageDealtToChampions': 0,
#    'trueDamageTaken': 262,
#    'turretKills': 1,
#    'turretTakedowns': 3,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 10,
#    'visionWardsBoughtInGame': 1,
#    'wardsKilled': 1,
#    'wardsPlaced': 8,
#    'win': True},
#   {'allInPings': 5,
#    'assistMePings': 9,
#    'assists': 8,
#    'baronKills': 1,
#    'basicPings': 0,
#    'bountyLevel': 6,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 9,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 396,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 87,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 375,
#     'buffsStolen': 2,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6778053802002181,
#     'controlWardsPlaced': 5,
#     'damagePerMinute': 808.729299720352,
#     'damageTakenOnTeamPercentage': 0.33946842344364003,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 3,
#     'dodgeSkillShotsSmallWindow': 6,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestBaron': 1378.355049687,
#     'earliestDragonTakedown': 1196.540701356,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 19,
#     'enemyJungleMonsterKills': 12,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 3,
#     'gameLength': 1485.479675233,
#     'goldPerMinute': 498.3726362724412,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 12,
#     'initialBuffCount': 2,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 68.00000008940697,
#     'junglerKillsEarlyJungle': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 1,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 5.666666666666667,
#     'killAfterHiddenWithAlly': 3,
#     'killParticipation': 0.6296296296296297,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 0,
#     'killsOnLanersEarlyJungleAsJungler': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 2,
#     'laneMinionsFirst10Minutes': 3,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [6672,
#      6672,
#      3087,
#      6672,
#      3094,
#      6672,
#      6672,
#      6664,
#      6672,
#      3100,
#      6672,
#      3087,
#      3046,
#      6672,
#      6610,
#      3142,
#      3877,
#      6672,
#      6610,
#      3094,
#      6672,
#      6672,
#      6610,
#      3100,
#      6672,
#      6610,
#      3053,
#      6664,
#      6672,
#      3053,
#      6610],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 49.15000006556511,
#     'maxKillDeficit': 2,
#     'maxLevelLeadLaneOpponent': 3,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': -46.50000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 2,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 2,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 14,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 5,
#     'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#     'skillshotsDodged': 67,
#     'skillshotsHit': 15,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 1,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 17,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 7,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.21031736437395654,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 0,
#     'turretTakedowns': 2,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 0.06280851364135742,
#     'visionScorePerMinute': 1.1584860479915973,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 7,
#     'wardTakedownsBefore20M': 7,
#     'wardsGuarded': 1},
#    'champExperience': 13651,
#    'champLevel': 15,
#    'championId': 234,
#    'championName': 'Viego',
#    'championTransform': 0,
#    'commandPings': 27,
#    'consumablesPurchased': 6,
#    'damageDealtToBuildings': 1676,
#    'damageDealtToObjectives': 12049,
#    'damageDealtToTurrets': 1676,
#    'damageSelfMitigated': 25266,
#    'dangerPings': 0,
#    'deaths': 3,
#    'detectorWardsPlaced': 5,
#    'doubleKills': 1,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 9,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': True,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 4,
#    'goldEarned': 12338,
#    'goldSpent': 11425,
#    'holdPings': 0,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 6610,
#    'item1': 6672,
#    'item2': 0,
#    'item3': 1036,
#    'item4': 3053,
#    'item5': 3111,
#    'item6': 3364,
#    'itemsPurchased': 21,
#    'killingSprees': 2,
#    'kills': 9,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 318,
#    'largestKillingSpree': 6,
#    'largestMultiKill': 3,
#    'longestTimeSpentLiving': 362,
#    'magicDamageDealt': 7540,
#    'magicDamageDealtToChampions': 2683,
#    'magicDamageTaken': 10502,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 168,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 43,
#    'participantId': 4,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8010, 'var1': 625, 'var2': 0, 'var3': 0},
#        {'perk': 9111, 'var1': 1413, 'var2': 340, 'var3': 0},
#        {'perk': 9104, 'var1': 10, 'var2': 50, 'var3': 0},
#        {'perk': 8014, 'var1': 631, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8304, 'var1': 9, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300}]},
#    'physicalDamageDealt': 159728,
#    'physicalDamageDealtToChampions': 16828,
#    'physicalDamageTaken': 24818,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6631,
#    'pushPings': 0,
#    'puuid': 'KpYl5i_jo6rySp5e5AvmM61Nf4RWVmU5oLgeTSZBu30XP8KQ37b7VAxzveCKsTH4uzKzb6zjVbpN3A',
#    'quadraKills': 0,
#    'riotIdGameName': 'HLE',
#    'riotIdTagline': '0205',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 179,
#    'spell2Casts': 132,
#    'spell3Casts': 68,
#    'spell4Casts': 17,
#    'subteamPlacement': 0,
#    'summoner1Casts': 13,
#    'summoner1Id': 11,
#    'summoner2Casts': 4,
#    'summoner2Id': 4,
#    'summonerId': 'n7197s3SbRj7KIeSLuYpKNI2qw_npW1blRFprEY7vFIa7mZXLjIU89ydEA',
#    'summonerLevel': 422,
#    'summonerName': '날씨좋은날1',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'JUNGLE',
#    'timeCCingOthers': 24,
#    'timePlayed': 1485,
#    'totalAllyJungleMinionsKilled': 121,
#    'totalDamageDealt': 223076,
#    'totalDamageDealtToChampions': 20022,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 36280,
#    'totalEnemyJungleMinionsKilled': 15,
#    'totalHeal': 21690,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 14,
#    'totalTimeCCDealt': 264,
#    'totalTimeSpentDead': 58,
#    'totalUnitsHealed': 1,
#    'tripleKills': 1,
#    'trueDamageDealt': 55806,
#    'trueDamageDealtToChampions': 510,
#    'trueDamageTaken': 959,
#    'turretKills': 0,
#    'turretTakedowns': 2,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 28,
#    'visionWardsBoughtInGame': 11,
#    'wardsKilled': 7,
#    'wardsPlaced': 6,
#    'win': True},
#   {'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 8,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 4,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 10,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 267,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 1,
#     'baronBuffGoldAdvantageOverThreshold': 1,
#     'baronTakedowns': 1,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6179873640923488,
#     'controlWardsPlaced': 1,
#     'damagePerMinute': 1039.246932187312,
#     'damageTakenOnTeamPercentage': 0.2777884735734281,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 4,
#     'dodgeSkillShotsSmallWindow': 10,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earliestBaron': 1378.355049687,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 2504.55224609375,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 3,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 0,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 2,
#     'fullTeamTakedown': 3,
#     'gameLength': 1485.479675233,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 496.76362317731076,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 2,
#     'initialBuffCount': 0,
#     'initialCrabCount': 0,
#     'jungleCsBefore10Minutes': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 1,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 3.5,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.5185185185185185,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 0,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 2,
#     'killsWithHelpFromEpicMonster': 1,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 5,
#     'laneMinionsFirst10Minutes': 55,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3074, 3078, 6333],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 6.5,
#     'maxKillDeficit': 2,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 4,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 8,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'shortestTimeToAceFromFirstTakedown': 41.0937624820001,
#     'skillshotsDodged': 75,
#     'skillshotsHit': 17,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'soloTurretsLategame': 3,
#     'stealthWardsPlaced': 8,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 2,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 14,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 3,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 1,
#     'teamDamagePercentage': 0.27026555831096344,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 0,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 1,
#     'turretTakedowns': 6,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.07654917240142822,
#     'visionScorePerMinute': 0.928378229167042,
#     'voidMonsterKill': 1,
#     'wardTakedowns': 8,
#     'wardTakedownsBefore20M': 5,
#     'wardsGuarded': 0},
#    'champExperience': 13696,
#    'champLevel': 15,
#    'championId': 114,
#    'championName': 'Fiora',
#    'championTransform': 0,
#    'commandPings': 10,
#    'consumablesPurchased': 3,
#    'damageDealtToBuildings': 11675,
#    'damageDealtToObjectives': 15009,
#    'damageDealtToTurrets': 11675,
#    'damageSelfMitigated': 29734,
#    'dangerPings': 0,
#    'deaths': 4,
#    'detectorWardsPlaced': 1,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 0,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': True,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 1,
#    'goldEarned': 12298,
#    'goldSpent': 11633,
#    'holdPings': 0,
#    'individualPosition': 'TOP',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 1,
#    'inhibitorsLost': 0,
#    'item0': 3074,
#    'item1': 3078,
#    'item2': 2055,
#    'item3': 6333,
#    'item4': 3047,
#    'item5': 0,
#    'item6': 3340,
#    'itemsPurchased': 22,
#    'killingSprees': 1,
#    'kills': 6,
#    'lane': 'TOP',
#    'largestCriticalStrike': 609,
#    'largestKillingSpree': 4,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 362,
#    'magicDamageDealt': 3385,
#    'magicDamageDealtToChampions': 1650,
#    'magicDamageTaken': 10090,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 3,
#    'nexusKills': 0,
#    'nexusLost': 0,
#    'nexusTakedowns': 1,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 2,
#    'participantId': 5,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8021, 'var1': 2979, 'var2': 3819, 'var3': 0},
#        {'perk': 8009, 'var1': 2408, 'var2': 0, 'var3': 0},
#        {'perk': 9104, 'var1': 17, 'var2': 50, 'var3': 0},
#        {'perk': 8299, 'var1': 410, 'var2': 0, 'var3': 0}],
#       'style': 8000},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8451, 'var1': 176, 'var2': 0, 'var3': 0},
#        {'perk': 8444, 'var1': 1359, 'var2': 0, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 130178,
#    'physicalDamageDealtToChampions': 17565,
#    'physicalDamageTaken': 18298,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 6502,
#    'pushPings': 0,
#    'puuid': 'LPd1KERkv3Ol60alze92LTflCrJKPyEUy-nHV0Rh50KeTi1pVZif8JwZWuX-z8KlAt6UpYy-EPEZHg',
#    'quadraKills': 0,
#    'riotIdGameName': '어색했',
#    'riotIdTagline': 'KR1',
#    'role': 'SOLO',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 180,
#    'spell2Casts': 25,
#    'spell3Casts': 54,
#    'spell4Casts': 8,
#    'subteamPlacement': 0,
#    'summoner1Casts': 4,
#    'summoner1Id': 12,
#    'summoner2Casts': 2,
#    'summoner2Id': 4,
#    'summonerId': 'bAAkqwo4qp_WYrSR6csuG5JzhO2htBUP-9yqCyWPBJkPvfg',
#    'summonerLevel': 527,
#    'summonerName': '어색했',
#    'teamEarlySurrendered': False,
#    'teamId': 100,
#    'teamPosition': 'TOP',
#    'timeCCingOthers': 15,
#    'timePlayed': 1485,
#    'totalAllyJungleMinionsKilled': 2,
#    'totalDamageDealt': 142791,
#    'totalDamageDealtToChampions': 25729,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 29688,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 17458,
#    'totalHealsOnTeammates': 2504,
#    'totalMinionsKilled': 192,
#    'totalTimeCCDealt': 170,
#    'totalTimeSpentDead': 66,
#    'totalUnitsHealed': 6,
#    'tripleKills': 0,
#    'trueDamageDealt': 9227,
#    'trueDamageDealtToChampions': 6513,
#    'trueDamageTaken': 1300,
#    'turretKills': 6,
#    'turretTakedowns': 6,
#    'turretsLost': 5,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 22,
#    'visionWardsBoughtInGame': 2,
#    'wardsKilled': 5,
#    'wardsPlaced': 10,
#    'win': True},
#   {'allInPings': 3,
#    'assistMePings': 2,
#    'assists': 5,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 5,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 753,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 4,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7647381175227564,
#     'controlWardsPlaced': 3,
#     'damagePerMinute': 1127.6329971830557,
#     'damageTakenOnTeamPercentage': 0.1837177767205851,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 3,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 0,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 0,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 2,
#     'enemyJungleMonsterKills': 0,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 733.4644541480001,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1485.479675233,
#     'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#     'goldPerMinute': 512.7827937795727,
#     'hadOpenNexus': 0,
#     'highestChampionDamage': 1,
#     'immobilizeAndKillWithAlly': 0,
#     'initialBuffCount': 0,
#     'initialCrabCount': 1,
#     'jungleCsBefore10Minutes': 4,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 2,
#     'kda': 3.3333333333333335,
#     'killAfterHiddenWithAlly': 0,
#     'killParticipation': 0.8333333333333334,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 1,
#     'killsNearEnemyTurret': 1,
#     'killsOnOtherLanesEarlyJungleAsLaner': 1,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 1,
#     'knockEnemyIntoTeamAndKill': 1,
#     'landSkillShotsEarlyGame': 34,
#     'laneMinionsFirst10Minutes': 101,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3087, 3046, 3031],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 42.25,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 1,
#     'multikillsAfterAggressiveFlash': 1,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 1,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 6,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 1,
#     'skillshotsDodged': 17,
#     'skillshotsHit': 475,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 1,
#     'stealthWardsPlaced': 3,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 10,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 6,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.35632383792443856,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
# ...
#     'killsUnderOwnTurret': 1,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 1,
#     'landSkillShotsEarlyGame': 4,
#     'laneMinionsFirst10Minutes': 51,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [6664],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 0,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 2,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': 0,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 0,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 1,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 0,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 0,
#     'skillshotsDodged': 42,
#     'skillshotsHit': 22,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 4,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 3,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 1,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 1,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.09867205751563979,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 1,
#     'turretTakedowns': 0,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': 1.340153455734253,
#     'visionScorePerMinute': 0.9649363432595157,
#     'voidMonsterKill': 0,
#     'wardTakedowns': 10,
#     'wardTakedownsBefore20M': 8,
#     'wardsGuarded': 0},
#    'champExperience': 10177,
#    'champLevel': 13,
#    'championId': 516,
#    'championName': 'Ornn',
#    'championTransform': 0,
#    'commandPings': 19,
#    'consumablesPurchased': 5,
#    'damageDealtToBuildings': 718,
#    'damageDealtToObjectives': 940,
#    'damageDealtToTurrets': 718,
#    'damageSelfMitigated': 30339,
#    'dangerPings': 0,
#    'deaths': 7,
#    'detectorWardsPlaced': 3,
#    'doubleKills': 0,
#    'dragonKills': 0,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 6,
#    'enemyVisionPings': 4,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 10,
#    'goldEarned': 7857,
#    'goldSpent': 7075,
#    'holdPings': 0,
#    'individualPosition': 'UTILITY',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 6664,
#    'item1': 3076,
#    'item2': 1011,
#    'item3': 1054,
#    'item4': 3082,
#    'item5': 3047,
#    'item6': 3364,
#    'itemsPurchased': 24,
#    'killingSprees': 0,
#    'kills': 1,
#    'lane': 'BOTTOM',
#    'largestCriticalStrike': 4,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 464,
#    'magicDamageDealt': 45386,
#    'magicDamageDealtToChampions': 4886,
#    'magicDamageTaken': 10170,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 0,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 24,
#    'participantId': 9,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5011, 'flex': 5001, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8360, 'var1': 5, 'var2': 0, 'var3': 0},
#        {'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#        {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#        {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#       'style': 8300},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8444, 'var1': 1395, 'var2': 0, 'var3': 0},
#        {'perk': 8451, 'var1': 210, 'var2': 0, 'var3': 0}],
#       'style': 8400}]},
#    'physicalDamageDealt': 38178,
#    'physicalDamageDealtToChampions': 2728,
#    'physicalDamageTaken': 16268,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 7,
#    'pushPings': 0,
#    'puuid': 'D2SBkIL5HA6dqxnIypndo3c19JHiJo9HdnqNecr58sdqv7Ok-7pud7rC08el4rrAv4SHyWBkDMEVcg',
#    'quadraKills': 0,
#    'riotIdGameName': '장미장미',
#    'riotIdTagline': 'KR1',
#    'role': 'CARRY',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 66,
#    'spell2Casts': 58,
#    'spell3Casts': 25,
#    'spell4Casts': 14,
#    'subteamPlacement': 0,
#    'summoner1Casts': 3,
#    'summoner1Id': 4,
#    'summoner2Casts': 8,
#    'summoner2Id': 12,
#    'summonerId': '5UvCuYhJhdvtDQ6ul6vJs_MxsrL1I9aSgpCICzSoMf1KfdI',
#    'summonerLevel': 250,
#    'summonerName': '장미장미',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'BOTTOM',
#    'timeCCingOthers': 21,
#    'timePlayed': 1485,
#    'totalAllyJungleMinionsKilled': 0,
#    'totalDamageDealt': 89432,
#    'totalDamageDealtToChampions': 7730,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 29520,
#    'totalEnemyJungleMinionsKilled': 0,
#    'totalHeal': 373,
#    'totalHealsOnTeammates': 0,
#    'totalMinionsKilled': 177,
#    'totalTimeCCDealt': 372,
#    'totalTimeSpentDead': 209,
#    'totalUnitsHealed': 1,
#    'tripleKills': 0,
#    'trueDamageDealt': 5867,
#    'trueDamageDealtToChampions': 116,
#    'trueDamageTaken': 3081,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 8,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 23,
#    'visionWardsBoughtInGame': 4,
#    'wardsKilled': 8,
#    'wardsPlaced': 7,
#    'win': False},
#   {'allInPings': 1,
#    'assistMePings': 3,
#    'assists': 5,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 0,
#    'challenges': {'12AssistStreakCount': 0,
#     'InfernalScalePickup': 2,
#     'SWARM_DefeatAatrox': 0,
#     'SWARM_DefeatBriar': 0,
#     'SWARM_DefeatMiniBosses': 0,
#     'SWARM_EvolveWeapon': 0,
#     'SWARM_Have3Passives': 0,
#     'SWARM_KillEnemy': 0,
#     'SWARM_PickupGold': 0,
#     'SWARM_ReachLevel50': 0,
#     'SWARM_Survive15Min': 0,
#     'SWARM_WinWith5EvolvedWeapons': 0,
#     'abilityUses': 833,
#     'acesBefore15Minutes': 0,
#     'alliedJungleMonsterKills': 58,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 0,
#     'buffsStolen': 1,
#     'completeSupportQuestInTime': 0,
#     'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7726749525542762,
#     'controlWardsPlaced': 4,
#     'damagePerMinute': 479.7764887254092,
#     'damageTakenOnTeamPercentage': 0.26985949667519893,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 8,
#     'dodgeSkillShotsSmallWindow': 0,
#     'doubleAces': 0,
#     'dragonTakedowns': 1,
#     'earliestDragonTakedown': 844.445840157,
#     'earlyLaningPhaseGoldExpAdvantage': 0,
#     'effectiveHealAndShielding': 3735.291015625,
#     'elderDragonKillsWithOpposingSoul': 0,
#     'elderDragonMultikills': 0,
#     'enemyChampionImmobilizations': 0,
#     'enemyJungleMonsterKills': 9,
#     'epicMonsterKillsNearEnemyJungler': 0,
#     'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#     'epicMonsterSteals': 0,
#     'epicMonsterStolenWithoutSmite': 0,
#     'firstTurretKilled': 1,
#     'firstTurretKilledTime': 733.4644541480001,
#     'fistBumpParticipation': 0,
#     'flawlessAces': 0,
#     'fullTeamTakedown': 0,
#     'gameLength': 1485.479675233,
#     'goldPerMinute': 331.46466535145873,
#     'hadOpenNexus': 0,
#     'immobilizeAndKillWithAlly': 0,
#     'initialBuffCount': 2,
#     'initialCrabCount': 1,
#     'jungleCsBefore10Minutes': 58.50000008940697,
#     'junglerKillsEarlyJungle': 0,
#     'junglerTakedownsNearDamagedEpicMonster': 0,
#     'kTurretsDestroyedBeforePlatesFall': 0,
#     'kda': 0.8888888888888888,
#     'killAfterHiddenWithAlly': 3,
#     'killParticipation': 0.6666666666666666,
#     'killedChampTookFullTeamDamageSurvived': 0,
#     'killingSprees': 0,
#     'killsNearEnemyTurret': 1,
#     'killsOnLanersEarlyJungleAsJungler': 1,
#     'killsOnRecentlyHealedByAramPack': 0,
#     'killsUnderOwnTurret': 0,
#     'killsWithHelpFromEpicMonster': 0,
#     'knockEnemyIntoTeamAndKill': 0,
#     'landSkillShotsEarlyGame': 3,
#     'laneMinionsFirst10Minutes': 5,
#     'laningPhaseGoldExpAdvantage': 0,
#     'legendaryCount': 0,
#     'legendaryItemUsed': [3100, 6653],
#     'lostAnInhibitor': 0,
#     'maxCsAdvantageOnLaneOpponent': 4,
#     'maxKillDeficit': 0,
#     'maxLevelLeadLaneOpponent': 1,
#     'mejaisFullStackInTime': 0,
#     'moreEnemyJungleThanOpponent': -59.50000008940697,
#     'multiKillOneSpell': 0,
#     'multiTurretRiftHeraldCount': 0,
#     'multikills': 0,
#     'multikillsAfterAggressiveFlash': 0,
#     'outerTurretExecutesBefore10Minutes': 1,
#     'outnumberedKills': 0,
#     'outnumberedNexusKill': 0,
#     'perfectDragonSoulsTaken': 0,
#     'perfectGame': 0,
#     'pickKillWithAlly': 5,
#     'playedChampSelectPosition': 1,
#     'poroExplosions': 0,
#     'quickCleanse': 0,
#     'quickFirstTurret': 0,
#     'quickSoloKills': 0,
#     'riftHeraldTakedowns': 1,
#     'saveAllyFromDeath': 0,
#     'scuttleCrabKills': 2,
#     'skillshotsDodged': 22,
#     'skillshotsHit': 16,
#     'snowballsHit': 0,
#     'soloBaronKills': 0,
#     'soloKills': 0,
#     'stealthWardsPlaced': 2,
#     'survivedSingleDigitHpCount': 0,
#     'survivedThreeImmobilizesInFight': 0,
#     'takedownOnFirstTurret': 0,
#     'takedowns': 8,
#     'takedownsAfterGainingLevelAdvantage': 0,
#     'takedownsBeforeJungleMinionSpawn': 0,
#     'takedownsFirstXMinutes': 6,
#     'takedownsInAlcove': 0,
#     'takedownsInEnemyFountain': 0,
#     'teamBaronKills': 0,
#     'teamDamagePercentage': 0.1516058861665225,
#     'teamElderDragonKills': 0,
#     'teamRiftHeraldKills': 1,
#     'tookLargeDamageSurvived': 0,
#     'turretPlatesTaken': 2,
#     'turretTakedowns': 0,
#     'turretsTakenWithRiftHerald': 0,
#     'twentyMinionsIn3SecondsCount': 0,
#     'twoWardsOneSweeperCount': 0,
#     'unseenRecalls': 0,
#     'visionScoreAdvantageLaneOpponent': -0.05909675359725952,
#     'visionScorePerMinute': 1.0900232491893052,
#     'voidMonsterKill': 7,
#     'wardTakedowns': 7,
#     'wardTakedownsBefore20M': 6,
#     'wardsGuarded': 0},
#    'champExperience': 8747,
#    'champLevel': 12,
#    'championId': 76,
#    'championName': 'Nidalee',
#    'championTransform': 0,
#    'commandPings': 7,
#    'consumablesPurchased': 7,
#    'damageDealtToBuildings': 0,
#    'damageDealtToObjectives': 35356,
#    'damageDealtToTurrets': 0,
#    'damageSelfMitigated': 16737,
#    'dangerPings': 0,
#    'deaths': 9,
#    'detectorWardsPlaced': 4,
#    'doubleKills': 0,
#    'dragonKills': 1,
#    'eligibleForProgression': True,
#    'enemyMissingPings': 5,
#    'enemyVisionPings': 0,
#    'firstBloodAssist': False,
#    'firstBloodKill': False,
#    'firstTowerAssist': False,
#    'firstTowerKill': False,
#    'gameEndedInEarlySurrender': False,
#    'gameEndedInSurrender': False,
#    'getBackPings': 0,
#    'goldEarned': 8206,
#    'goldSpent': 8100,
#    'holdPings': 0,
#    'individualPosition': 'JUNGLE',
#    'inhibitorKills': 0,
#    'inhibitorTakedowns': 0,
#    'inhibitorsLost': 1,
#    'item0': 6653,
#    'item1': 3100,
#    'item2': 2055,
#    'item3': 3020,
#    'item4': 0,
#    'item5': 0,
#    'item6': 3364,
#    'itemsPurchased': 23,
#    'killingSprees': 0,
#    'kills': 3,
#    'lane': 'JUNGLE',
#    'largestCriticalStrike': 0,
#    'largestKillingSpree': 0,
#    'largestMultiKill': 1,
#    'longestTimeSpentLiving': 405,
#    'magicDamageDealt': 105814,
#    'magicDamageDealtToChampions': 9041,
#    'magicDamageTaken': 9661,
#    'missions': {'playerScore0': 0,
#     'playerScore1': 0,
#     'playerScore2': 0,
#     'playerScore3': 0,
#     'playerScore4': 0,
#     'playerScore5': 0,
#     'playerScore6': 0,
#     'playerScore7': 0,
#     'playerScore8': 0,
#     'playerScore9': 0,
#     'playerScore10': 0,
#     'playerScore11': 0},
#    'needVisionPings': 0,
#    'neutralMinionsKilled': 118,
#    'nexusKills': 0,
#    'nexusLost': 1,
#    'nexusTakedowns': 0,
#    'objectivesStolen': 0,
#    'objectivesStolenAssists': 0,
#    'onMyWayPings': 41,
#    'participantId': 10,
#    'pentaKills': 0,
#    'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#     'styles': [{'description': 'primaryStyle',
#       'selections': [{'perk': 8112, 'var1': 425, 'var2': 0, 'var3': 0},
#        {'perk': 8143, 'var1': 435, 'var2': 0, 'var3': 0},
#        {'perk': 8138, 'var1': 16, 'var2': 0, 'var3': 0},
#        {'perk': 8135, 'var1': 210, 'var2': 3, 'var3': 0}],
#       'style': 8100},
#      {'description': 'subStyle',
#       'selections': [{'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0},
#        {'perk': 8232, 'var1': 4, 'var2': 40, 'var3': 0}],
#       'style': 8200}]},
#    'physicalDamageDealt': 16177,
#    'physicalDamageDealtToChampions': 1156,
#    'physicalDamageTaken': 22861,
#    'placement': 0,
#    'playerAugment1': 0,
#    'playerAugment2': 0,
#    'playerAugment3': 0,
#    'playerAugment4': 0,
#    'playerAugment5': 0,
#    'playerAugment6': 0,
#    'playerSubteamId': 0,
#    'profileIcon': 3495,
#    'pushPings': 1,
#    'puuid': '22CHQ3NCrz2ayiZgc8uqHNdlNrR1rwxPEgqyWJMHGhcCPeHQdPUYFt3vbZHxRxcb538-Yyku99sx9w',
#    'quadraKills': 0,
#    'riotIdGameName': '치킨사줬더니닭다리만골라먹는김견',
#    'riotIdTagline': '김 견',
#    'role': 'NONE',
#    'sightWardsBoughtInGame': 0,
#    'spell1Casts': 210,
#    'spell2Casts': 248,
#    'spell3Casts': 134,
#    'spell4Casts': 241,
#    'subteamPlacement': 0,
#    'summoner1Casts': 15,
#    'summoner1Id': 11,
#    'summoner2Casts': 3,
#    'summoner2Id': 4,
#    'summonerId': 'bJoj1swEs9VNsAlI9h6jCrVTFn3FsXswXNpE1zFCFcCI1d14',
#    'summonerLevel': 740,
#    'summonerName': '나는 멍청이 우우',
#    'teamEarlySurrendered': False,
#    'teamId': 200,
#    'teamPosition': 'JUNGLE',
#    'timeCCingOthers': 8,
#    'timePlayed': 1485,
#    'totalAllyJungleMinionsKilled': 79,
#    'totalDamageDealt': 180061,
#    'totalDamageDealtToChampions': 11878,
#    'totalDamageShieldedOnTeammates': 0,
#    'totalDamageTaken': 33163,
#    'totalEnemyJungleMinionsKilled': 10,
#    'totalHeal': 17210,
#    'totalHealsOnTeammates': 3735,
#    'totalMinionsKilled': 15,
#    'totalTimeCCDealt': 67,
#    'totalTimeSpentDead': 212,
#    'totalUnitsHealed': 5,
#    'tripleKills': 0,
#    'trueDamageDealt': 58069,
#    'trueDamageDealtToChampions': 1680,
#    'trueDamageTaken': 641,
#    'turretKills': 0,
#    'turretTakedowns': 0,
#    'turretsLost': 8,
#    'unrealKills': 0,
#    'visionClearedPings': 0,
#    'visionScore': 26,
#    'visionWardsBoughtInGame': 6,
#    'wardsKilled': 7,
#    'wardsPlaced': 6,
#    'win': False}],
#  'platformId': 'KR',
#  'queueId': 420,
#  'teams': [{'bans': [{'championId': 85, 'pickTurn': 1},
#     {'championId': 910, 'pickTurn': 2},
#     {'championId': 119, 'pickTurn': 3},
#     {'championId': 35, 'pickTurn': 4},
#     {'championId': 893, 'pickTurn': 5}],
#    'objectives': {'baron': {'first': True, 'kills': 1},
#     'champion': {'first': True, 'kills': 28},
#     'dragon': {'first': False, 'kills': 1},
#     'horde': {'first': False, 'kills': 0},
#     'inhibitor': {'first': True, 'kills': 1},
#     'riftHerald': {'first': False, 'kills': 0},
#     'tower': {'first': False, 'kills': 8}},
#    'teamId': 100,
#    'win': True},
#   {'bans': [{'championId': 81, 'pickTurn': 6},
#     {'championId': 64, 'pickTurn': 7},
#     {'championId': 893, 'pickTurn': 8},
#     {'championId': 33, 'pickTurn': 9},
#     {'championId': 35, 'pickTurn': 10}],
#    'objectives': {'baron': {'first': False, 'kills': 0},
#     'champion': {'first': False, 'kills': 12},
#     'dragon': {'first': True, 'kills': 1},
#     'horde': {'first': True, 'kills': 6},
#     'inhibitor': {'first': False, 'kills': 0},
#     'riftHerald': {'first': True, 'kills': 1},
#     'tower': {'first': True, 'kills': 5}},
#    'teamId': 200,
#    'win': False}],
#  'tournamentCode': ''}

# %%
temp_match_data['info']['participants']
# Out:
# [{'allInPings': 0,
#   'assistMePings': 6,
#   'assists': 17,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 5,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 7,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 245,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 0,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 1,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 1,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7337733952462397,
#    'controlWardsPlaced': 7,
#    'damagePerMinute': 827.0244475878159,
#    'damageTakenOnTeamPercentage': 0.1236575311941941,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 1,
#    'dodgeSkillShotsSmallWindow': 3,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestBaron': 1378.355049687,
#    'earliestDragonTakedown': 1196.540701356,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 6261.54833984375,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 39,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 2,
#    'fullTeamTakedown': 3,
#    'gameLength': 1485.479675233,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 383.8060680243391,
#    'hadOpenNexus': 0,
#    'highestCrowdControlScore': 1,
#    'highestWardKills': 1,
#    'immobilizeAndKillWithAlly': 13,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 22,
#    'killAfterHiddenWithAlly': 4,
#    'killParticipation': 0.8148148148148148,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 1,
#    'killsNearEnemyTurret': 0,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 1,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 34,
#    'laneMinionsFirst10Minutes': 12,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3870, 6617, 2065],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 16,
#    'maxKillDeficit': 2,
#    'maxLevelLeadLaneOpponent': 2,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 1,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 16,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 2,
#    'scuttleCrabKills': 0,
#    'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#    'skillshotsDodged': 48,
#    'skillshotsHit': 156,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 25,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 2,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 22,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 5,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 1,
#    'teamDamagePercentage': 0.21507518294396177,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 4,
#    'turretTakedowns': 3,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 2,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 0.1744394302368164,
#    'visionScorePerMinute': 2.858796819045269,
#    'voidMonsterKill': 1,
#    'wardTakedowns': 15,
#    'wardTakedownsBefore20M': 13,
#    'wardsGuarded': 1},
#   'champExperience': 9842,
#   'champLevel': 12,
#   'championId': 147,
#   'championName': 'Seraphine',
#   'championTransform': 0,
#   'commandPings': 12,
#   'consumablesPurchased': 12,
#   'damageDealtToBuildings': 667,
#   'damageDealtToObjectives': 4136,
#   'damageDealtToTurrets': 667,
#   'damageSelfMitigated': 7427,
#   'dangerPings': 0,
#   'deaths': 1,
#   'detectorWardsPlaced': 8,
#   'doubleKills': 0,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 11,
#   'enemyVisionPings': 8,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 0,
#   'goldEarned': 9502,
#   'goldSpent': 8300,
#   'holdPings': 0,
#   'individualPosition': 'UTILITY',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 3870,
#   'item1': 2065,
#   'item2': 4638,
#   'item3': 6617,
#   'item4': 3158,
#   'item5': 3114,
#   'item6': 3364,
#   'itemsPurchased': 28,
#   'killingSprees': 1,
#   'kills': 5,
#   'lane': 'BOTTOM',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 5,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 789,
#   'magicDamageDealt': 38083,
#   'magicDamageDealtToChampions': 17997,
#   'magicDamageTaken': 5083,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 0,
#   'nexusKills': 1,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 9,
#   'participantId': 1,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5007},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8369, 'var1': 416, 'var2': 415, 'var3': 0},
#       {'perk': 8321, 'var1': 0, 'var2': 0, 'var3': 0},
#       {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#       {'perk': 8316, 'var1': 10, 'var2': 25, 'var3': 0}],
#      'style': 8300},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8226, 'var1': 250, 'var2': 520, 'var3': 0},
#       {'perk': 8237, 'var1': 776, 'var2': 0, 'var3': 0}],
#      'style': 8200}]},
#   'physicalDamageDealt': 6646,
#   'physicalDamageDealtToChampions': 2090,
#   'physicalDamageTaken': 7695,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 5849,
#   'pushPings': 0,
#   'puuid': 'cjVfM5Nc7iO5gZN_hqouK6rinFXdxxsXcjpM7IQrQelVtvvXnOD4IV8WkNSAz-D-qzyY55LcGE9v6g',
#   'quadraKills': 0,
#   'riotIdGameName': 'BeryL',
#   'riotIdTagline': '000',
#   'role': 'SUPPORT',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 110,
#   'spell2Casts': 57,
#   'spell3Casts': 71,
#   'spell4Casts': 7,
#   'subteamPlacement': 0,
#   'summoner1Casts': 5,
#   'summoner1Id': 7,
#   'summoner2Casts': 4,
#   'summoner2Id': 4,
#   'summonerId': '9Ave2rsRb8fj7uWkpkHk6lbX66qYy_GFCc-TgPl3YJ0IiP4',
#   'summonerLevel': 569,
#   'summonerName': 'DRX B2ryL',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'UTILITY',
#   'timeCCingOthers': 44,
#   'timePlayed': 1485,
#   'totalAllyJungleMinionsKilled': 0,
#   'totalDamageDealt': 46404,
#   'totalDamageDealtToChampions': 20475,
#   'totalDamageShieldedOnTeammates': 2530,
#   'totalDamageTaken': 13215,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 6975,
#   'totalHealsOnTeammates': 3730,
#   'totalMinionsKilled': 39,
#   'totalTimeCCDealt': 174,
#   'totalTimeSpentDead': 16,
#   'totalUnitsHealed': 5,
#   'tripleKills': 0,
#   'trueDamageDealt': 1673,
#   'trueDamageDealtToChampions': 387,
#   'trueDamageTaken': 436,
#   'turretKills': 0,
#   'turretTakedowns': 3,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 70,
#   'visionWardsBoughtInGame': 7,
#   'wardsKilled': 13,
#   'wardsPlaced': 33,
#   'win': True},
#  {'allInPings': 0,
#   'assistMePings': 0,
#   'assists': 15,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 4,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 5,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 319,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 0,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 1,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.568977553924747,
#    'controlWardsPlaced': 4,
#    'damagePerMinute': 528.0736248348256,
#    'damageTakenOnTeamPercentage': 0.12124764203392745,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 0,
#    'dodgeSkillShotsSmallWindow': 4,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestBaron': 1378.355049687,
#    'earliestDragonTakedown': 1196.540701356,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 7399.2548828125,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 5,
#    'enemyJungleMonsterKills': 1,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 2,
#    'fullTeamTakedown': 3,
#    'gameLength': 1485.479675233,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 450.63580686571953,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 3,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 19,
#    'killAfterHiddenWithAlly': 1,
#    'killParticipation': 0.7037037037037037,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 1,
#    'killsNearEnemyTurret': 3,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 1,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 3,
#    'laneMinionsFirst10Minutes': 84,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3118, 4629, 3137],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 1,
#    'maxKillDeficit': 2,
#    'maxLevelLeadLaneOpponent': 2,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 1,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 13,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#    'skillshotsDodged': 63,
#    'skillshotsHit': 19,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 4,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 0,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 19,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 4,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 1,
#    'teamDamagePercentage': 0.13733031931582818,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'teleportTakedowns': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 1,
#    'turretTakedowns': 5,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.15446388721466064,
#    'visionScorePerMinute': 0.8659395502027832,
#    'voidMonsterKill': 1,
#    'wardTakedowns': 5,
#    'wardTakedownsBefore20M': 1,
#    'wardsGuarded': 0},
#   'champExperience': 14352,
#   'champLevel': 15,
#   'championId': 43,
#   'championName': 'Karma',
#   'championTransform': 0,
#   'commandPings': 1,
#   'consumablesPurchased': 6,
#   'damageDealtToBuildings': 3581,
#   'damageDealtToObjectives': 9083,
#   'damageDealtToTurrets': 3581,
#   'damageSelfMitigated': 10645,
#   'dangerPings': 0,
#   'deaths': 0,
#   'detectorWardsPlaced': 4,
#   'doubleKills': 1,
#   'dragonKills': 1,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 7,
#   'enemyVisionPings': 0,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 0,
#   'goldEarned': 11156,
#   'goldSpent': 10250,
#   'holdPings': 0,
#   'individualPosition': 'MIDDLE',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 3158,
#   'item1': 3118,
#   'item2': 3137,
#   'item3': 1056,
#   'item4': 4629,
#   'item5': 0,
#   'item6': 3364,
#   'itemsPurchased': 24,
#   'killingSprees': 1,
#   'kills': 4,
#   'lane': 'MIDDLE',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 4,
#   'largestMultiKill': 2,
#   'longestTimeSpentLiving': 0,
#   'magicDamageDealt': 106352,
#   'magicDamageDealtToChampions': 12281,
#   'magicDamageTaken': 4934,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 5,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 5,
#   'participantId': 2,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8214, 'var1': 811, 'var2': 833, 'var3': 0},
#       {'perk': 8226, 'var1': 250, 'var2': 835, 'var3': 0},
#       {'perk': 8210, 'var1': 13, 'var2': 0, 'var3': 0},
#       {'perk': 8237, 'var1': 457, 'var2': 0, 'var3': 0}],
#      'style': 8200},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8126, 'var1': 377, 'var2': 0, 'var3': 0},
#       {'perk': 8135, 'var1': 450, 'var2': 5, 'var3': 0}],
#      'style': 8100}]},
#   'physicalDamageDealt': 14793,
#   'physicalDamageDealtToChampions': 415,
#   'physicalDamageTaken': 7813,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 4080,
#   'pushPings': 0,
#   'puuid': '4ILqnQdyG8IQf0iVo10Sf1jbPMX5HsxFn44tAmRMZtTc8to1SO0mqc_6FPdRcHAdKpB-xQygpHFJ2w',
#   'quadraKills': 0,
#   'riotIdGameName': 'ad 미드 좋아해',
#   'riotIdTagline': 'jing',
#   'role': 'SOLO',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 122,
#   'spell2Casts': 24,
#   'spell3Casts': 129,
#   'spell4Casts': 44,
#   'subteamPlacement': 0,
#   'summoner1Casts': 1,
#   'summoner1Id': 4,
#   'summoner2Casts': 4,
#   'summoner2Id': 12,
#   'summonerId': 'g9kHpvpql_Ci3ioM5SeRTaTVbucVAPTABBxiLJTOD0Tzz4M',
#   'summonerLevel': 68,
#   'summonerName': '73580818del',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'MIDDLE',
#   'timeCCingOthers': 14,
#   'timePlayed': 1485,
#   'totalAllyJungleMinionsKilled': 0,
#   'totalDamageDealt': 122223,
#   'totalDamageDealtToChampions': 13074,
#   'totalDamageShieldedOnTeammates': 7208,
#   'totalDamageTaken': 12958,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 2451,
#   'totalHealsOnTeammates': 190,
#   'totalMinionsKilled': 189,
#   'totalTimeCCDealt': 238,
#   'totalTimeSpentDead': 0,
#   'totalUnitsHealed': 2,
#   'tripleKills': 0,
#   'trueDamageDealt': 1077,
#   'trueDamageDealtToChampions': 377,
#   'trueDamageTaken': 210,
#   'turretKills': 1,
#   'turretTakedowns': 5,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 21,
#   'visionWardsBoughtInGame': 4,
#   'wardsKilled': 5,
#   'wardsPlaced': 8,
#   'win': True},
#  {'allInPings': 0,
#   'assistMePings': 0,
#   'assists': 10,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 1,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 3,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 163,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 0,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 1,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.14396952142980696,
#    'controlWardsPlaced': 1,
#    'damagePerMinute': 642.2063843454242,
#    'damageTakenOnTeamPercentage': 0.13783792975481027,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 4,
#    'dodgeSkillShotsSmallWindow': 4,
#    'doubleAces': 0,
#    'dragonTakedowns': 0,
#    'earliestBaron': 1378.355049687,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 17,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 2,
#    'fullTeamTakedown': 3,
#    'gameLength': 1485.479675233,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 398.56944950349674,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 5,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 3.25,
#    'killAfterHiddenWithAlly': 0,
#    'killParticipation': 0.48148148148148145,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 0,
#    'killsNearEnemyTurret': 1,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 0,
#    'laneMinionsFirst10Minutes': 78,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3087, 3094],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 34,
#    'maxKillDeficit': 2,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 9,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'skillshotsDodged': 34,
#    'skillshotsHit': 7,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 6,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 0,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 13,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 4,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 1,
#    'teamDamagePercentage': 0.1670115750552901,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 3,
#    'turretTakedowns': 3,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.5726776123046875,
#    'visionScorePerMinute': 0.41233892693941027,
#    'voidMonsterKill': 1,
#    'wardTakedowns': 1,
#    'wardTakedownsBefore20M': 0,
#    'wardsGuarded': 0},
#   'champExperience': 11213,
#   'champLevel': 13,
#   'championId': 202,
#   'championName': 'Jhin',
#   'championTransform': 0,
#   'commandPings': 3,
#   'consumablesPurchased': 2,
#   'damageDealtToBuildings': 4632,
#   'damageDealtToObjectives': 7913,
#   'damageDealtToTurrets': 4632,
#   'damageSelfMitigated': 7606,
#   'dangerPings': 0,
#   'deaths': 4,
#   'detectorWardsPlaced': 1,
#   'doubleKills': 0,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 15,
#   'enemyVisionPings': 0,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 0,
#   'goldEarned': 9867,
#   'goldSpent': 8500,
#   'holdPings': 0,
#   'individualPosition': 'BOTTOM',
#   'inhibitorKills': 1,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 1018,
#   'item1': 1037,
#   'item2': 3009,
#   'item3': 3094,
#   'item4': 3087,
#   'item5': 1055,
#   'item6': 3363,
#   'itemsPurchased': 18,
#   'killingSprees': 0,
#   'kills': 3,
#   'lane': 'BOTTOM',
#   'largestCriticalStrike': 829,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 509,
#   'magicDamageDealt': 18097,
#   'magicDamageDealtToChampions': 1653,
#   'magicDamageTaken': 3579,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 0,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 0,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 7,
#   'participantId': 3,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5008},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8021, 'var1': 1795, 'var2': 1799, 'var3': 0},
#       {'perk': 8009, 'var1': 1922, 'var2': 0, 'var3': 0},
#       {'perk': 9103, 'var1': 19, 'var2': 20, 'var3': 0},
#       {'perk': 8017, 'var1': 938, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#       {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#      'style': 8300}]},
#   'physicalDamageDealt': 108023,
#   'physicalDamageDealtToChampions': 14246,
#   'physicalDamageTaken': 10889,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 4834,
#   'pushPings': 0,
#   'puuid': 'FsMN0rQNi9IbwZuGuIxM4gdNQjTYut-5TaHCQSIKctaOwGnUFljkRCja07vFateQ3o5A1PVEyS4KiQ',
#   'quadraKills': 0,
#   'riotIdGameName': '쪼사기',
#   'riotIdTagline': 'KR1',
#   'role': 'CARRY',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 65,
#   'spell2Casts': 49,
#   'spell3Casts': 33,
#   'spell4Casts': 16,
#   'subteamPlacement': 0,
#   'summoner1Casts': 3,
#   'summoner1Id': 21,
#   'summoner2Casts': 3,
#   'summoner2Id': 4,
#   'summonerId': 'Fszfd1mLLW05ylSHW2d-1h5zhL4s2uyGwsvae8WJCnfJo9o',
#   'summonerLevel': 437,
#   'summonerName': '쪼사기',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'BOTTOM',
#   'timeCCingOthers': 29,
#   'timePlayed': 1485,
#   'totalAllyJungleMinionsKilled': 0,
#   'totalDamageDealt': 129125,
#   'totalDamageDealtToChampions': 15899,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 14731,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 3633,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 199,
#   'totalTimeCCDealt': 139,
#   'totalTimeSpentDead': 102,
#   'totalUnitsHealed': 1,
#   'tripleKills': 0,
#   'trueDamageDealt': 3005,
#   'trueDamageDealtToChampions': 0,
#   'trueDamageTaken': 262,
#   'turretKills': 1,
#   'turretTakedowns': 3,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 10,
#   'visionWardsBoughtInGame': 1,
#   'wardsKilled': 1,
#   'wardsPlaced': 8,
#   'win': True},
#  {'allInPings': 5,
#   'assistMePings': 9,
#   'assists': 8,
#   'baronKills': 1,
#   'basicPings': 0,
#   'bountyLevel': 6,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 9,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 396,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 87,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 1,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 375,
#    'buffsStolen': 2,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6778053802002181,
#    'controlWardsPlaced': 5,
#    'damagePerMinute': 808.729299720352,
#    'damageTakenOnTeamPercentage': 0.33946842344364003,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 3,
#    'dodgeSkillShotsSmallWindow': 6,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestBaron': 1378.355049687,
#    'earliestDragonTakedown': 1196.540701356,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 19,
#    'enemyJungleMonsterKills': 12,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 2,
#    'fullTeamTakedown': 3,
#    'gameLength': 1485.479675233,
#    'goldPerMinute': 498.3726362724412,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 12,
#    'initialBuffCount': 2,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 68.00000008940697,
#    'junglerKillsEarlyJungle': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 1,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 5.666666666666667,
#    'killAfterHiddenWithAlly': 3,
#    'killParticipation': 0.6296296296296297,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 1,
#    'killsNearEnemyTurret': 0,
#    'killsOnLanersEarlyJungleAsJungler': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 2,
#    'laneMinionsFirst10Minutes': 3,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [6672,
#     6672,
#     3087,
#     6672,
#     3094,
#     6672,
#     6672,
#     6664,
#     6672,
#     3100,
#     6672,
#     3087,
#     3046,
#     6672,
#     6610,
#     3142,
#     3877,
#     6672,
#     6610,
#     3094,
#     6672,
#     6672,
#     6610,
#     3100,
#     6672,
#     6610,
#     3053,
#     6664,
#     6672,
#     3053,
#     6610],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 49.15000006556511,
#    'maxKillDeficit': 2,
#    'maxLevelLeadLaneOpponent': 3,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': -46.50000008940697,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 2,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 2,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 14,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 5,
#    'shortestTimeToAceFromFirstTakedown': 15.624629297999945,
#    'skillshotsDodged': 67,
#    'skillshotsHit': 15,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 1,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 2,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 17,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 7,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 1,
#    'teamDamagePercentage': 0.21031736437395654,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 0,
#    'turretTakedowns': 2,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 0.06280851364135742,
#    'visionScorePerMinute': 1.1584860479915973,
#    'voidMonsterKill': 1,
#    'wardTakedowns': 7,
#    'wardTakedownsBefore20M': 7,
#    'wardsGuarded': 1},
#   'champExperience': 13651,
#   'champLevel': 15,
#   'championId': 234,
#   'championName': 'Viego',
#   'championTransform': 0,
#   'commandPings': 27,
#   'consumablesPurchased': 6,
#   'damageDealtToBuildings': 1676,
#   'damageDealtToObjectives': 12049,
#   'damageDealtToTurrets': 1676,
#   'damageSelfMitigated': 25266,
#   'dangerPings': 0,
#   'deaths': 3,
#   'detectorWardsPlaced': 5,
#   'doubleKills': 1,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 9,
#   'enemyVisionPings': 0,
#   'firstBloodAssist': True,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 4,
#   'goldEarned': 12338,
#   'goldSpent': 11425,
#   'holdPings': 0,
#   'individualPosition': 'JUNGLE',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 6610,
#   'item1': 6672,
#   'item2': 0,
#   'item3': 1036,
#   'item4': 3053,
#   'item5': 3111,
#   'item6': 3364,
#   'itemsPurchased': 21,
#   'killingSprees': 2,
#   'kills': 9,
#   'lane': 'JUNGLE',
#   'largestCriticalStrike': 318,
#   'largestKillingSpree': 6,
#   'largestMultiKill': 3,
#   'longestTimeSpentLiving': 362,
#   'magicDamageDealt': 7540,
#   'magicDamageDealtToChampions': 2683,
#   'magicDamageTaken': 10502,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 168,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 43,
#   'participantId': 4,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8010, 'var1': 625, 'var2': 0, 'var3': 0},
#       {'perk': 9111, 'var1': 1413, 'var2': 340, 'var3': 0},
#       {'perk': 9104, 'var1': 10, 'var2': 50, 'var3': 0},
#       {'perk': 8014, 'var1': 631, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8304, 'var1': 9, 'var2': 0, 'var3': 0},
#       {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#      'style': 8300}]},
#   'physicalDamageDealt': 159728,
#   'physicalDamageDealtToChampions': 16828,
#   'physicalDamageTaken': 24818,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 6631,
#   'pushPings': 0,
#   'puuid': 'KpYl5i_jo6rySp5e5AvmM61Nf4RWVmU5oLgeTSZBu30XP8KQ37b7VAxzveCKsTH4uzKzb6zjVbpN3A',
#   'quadraKills': 0,
#   'riotIdGameName': 'HLE',
#   'riotIdTagline': '0205',
#   'role': 'NONE',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 179,
#   'spell2Casts': 132,
#   'spell3Casts': 68,
#   'spell4Casts': 17,
#   'subteamPlacement': 0,
#   'summoner1Casts': 13,
#   'summoner1Id': 11,
#   'summoner2Casts': 4,
#   'summoner2Id': 4,
#   'summonerId': 'n7197s3SbRj7KIeSLuYpKNI2qw_npW1blRFprEY7vFIa7mZXLjIU89ydEA',
#   'summonerLevel': 422,
#   'summonerName': '날씨좋은날1',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'JUNGLE',
#   'timeCCingOthers': 24,
#   'timePlayed': 1485,
#   'totalAllyJungleMinionsKilled': 121,
#   'totalDamageDealt': 223076,
#   'totalDamageDealtToChampions': 20022,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 36280,
#   'totalEnemyJungleMinionsKilled': 15,
#   'totalHeal': 21690,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 14,
#   'totalTimeCCDealt': 264,
#   'totalTimeSpentDead': 58,
#   'totalUnitsHealed': 1,
#   'tripleKills': 1,
#   'trueDamageDealt': 55806,
#   'trueDamageDealtToChampions': 510,
#   'trueDamageTaken': 959,
#   'turretKills': 0,
#   'turretTakedowns': 2,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 28,
#   'visionWardsBoughtInGame': 11,
#   'wardsKilled': 7,
#   'wardsPlaced': 6,
#   'win': True},
#  {'allInPings': 0,
#   'assistMePings': 0,
#   'assists': 8,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 4,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 10,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 267,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 1,
#    'baronBuffGoldAdvantageOverThreshold': 1,
#    'baronTakedowns': 1,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.6179873640923488,
#    'controlWardsPlaced': 1,
#    'damagePerMinute': 1039.246932187312,
#    'damageTakenOnTeamPercentage': 0.2777884735734281,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 4,
#    'dodgeSkillShotsSmallWindow': 10,
#    'doubleAces': 0,
#    'dragonTakedowns': 0,
#    'earliestBaron': 1378.355049687,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 2504.55224609375,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 3,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 0,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 2,
#    'fullTeamTakedown': 3,
#    'gameLength': 1485.479675233,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 496.76362317731076,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 2,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 1,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 3.5,
#    'killAfterHiddenWithAlly': 0,
#    'killParticipation': 0.5185185185185185,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 1,
#    'killsNearEnemyTurret': 1,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 2,
#    'killsWithHelpFromEpicMonster': 1,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 5,
#    'laneMinionsFirst10Minutes': 55,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3074, 3078, 6333],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 6.5,
#    'maxKillDeficit': 2,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 4,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 8,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'shortestTimeToAceFromFirstTakedown': 41.0937624820001,
#    'skillshotsDodged': 75,
#    'skillshotsHit': 17,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 1,
#    'soloTurretsLategame': 3,
#    'stealthWardsPlaced': 8,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 2,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 14,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 3,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 1,
#    'teamDamagePercentage': 0.27026555831096344,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 0,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 1,
#    'turretTakedowns': 6,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.07654917240142822,
#    'visionScorePerMinute': 0.928378229167042,
#    'voidMonsterKill': 1,
#    'wardTakedowns': 8,
#    'wardTakedownsBefore20M': 5,
#    'wardsGuarded': 0},
#   'champExperience': 13696,
#   'champLevel': 15,
#   'championId': 114,
#   'championName': 'Fiora',
#   'championTransform': 0,
#   'commandPings': 10,
#   'consumablesPurchased': 3,
#   'damageDealtToBuildings': 11675,
#   'damageDealtToObjectives': 15009,
#   'damageDealtToTurrets': 11675,
#   'damageSelfMitigated': 29734,
#   'dangerPings': 0,
#   'deaths': 4,
#   'detectorWardsPlaced': 1,
#   'doubleKills': 0,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 0,
#   'enemyVisionPings': 0,
#   'firstBloodAssist': False,
#   'firstBloodKill': True,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 1,
#   'goldEarned': 12298,
#   'goldSpent': 11633,
#   'holdPings': 0,
#   'individualPosition': 'TOP',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 1,
#   'inhibitorsLost': 0,
#   'item0': 3074,
#   'item1': 3078,
#   'item2': 2055,
#   'item3': 6333,
#   'item4': 3047,
#   'item5': 0,
#   'item6': 3340,
#   'itemsPurchased': 22,
#   'killingSprees': 1,
#   'kills': 6,
#   'lane': 'TOP',
#   'largestCriticalStrike': 609,
#   'largestKillingSpree': 4,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 362,
#   'magicDamageDealt': 3385,
#   'magicDamageDealtToChampions': 1650,
#   'magicDamageTaken': 10090,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 3,
#   'nexusKills': 0,
#   'nexusLost': 0,
#   'nexusTakedowns': 1,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 2,
#   'participantId': 5,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8021, 'var1': 2979, 'var2': 3819, 'var3': 0},
#       {'perk': 8009, 'var1': 2408, 'var2': 0, 'var3': 0},
#       {'perk': 9104, 'var1': 17, 'var2': 50, 'var3': 0},
#       {'perk': 8299, 'var1': 410, 'var2': 0, 'var3': 0}],
#      'style': 8000},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8451, 'var1': 176, 'var2': 0, 'var3': 0},
#       {'perk': 8444, 'var1': 1359, 'var2': 0, 'var3': 0}],
#      'style': 8400}]},
#   'physicalDamageDealt': 130178,
#   'physicalDamageDealtToChampions': 17565,
#   'physicalDamageTaken': 18298,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 6502,
#   'pushPings': 0,
#   'puuid': 'LPd1KERkv3Ol60alze92LTflCrJKPyEUy-nHV0Rh50KeTi1pVZif8JwZWuX-z8KlAt6UpYy-EPEZHg',
#   'quadraKills': 0,
#   'riotIdGameName': '어색했',
#   'riotIdTagline': 'KR1',
#   'role': 'SOLO',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 180,
#   'spell2Casts': 25,
#   'spell3Casts': 54,
#   'spell4Casts': 8,
#   'subteamPlacement': 0,
#   'summoner1Casts': 4,
#   'summoner1Id': 12,
#   'summoner2Casts': 2,
#   'summoner2Id': 4,
#   'summonerId': 'bAAkqwo4qp_WYrSR6csuG5JzhO2htBUP-9yqCyWPBJkPvfg',
#   'summonerLevel': 527,
#   'summonerName': '어색했',
#   'teamEarlySurrendered': False,
#   'teamId': 100,
#   'teamPosition': 'TOP',
#   'timeCCingOthers': 15,
#   'timePlayed': 1485,
#   'totalAllyJungleMinionsKilled': 2,
#   'totalDamageDealt': 142791,
#   'totalDamageDealtToChampions': 25729,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 29688,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 17458,
#   'totalHealsOnTeammates': 2504,
#   'totalMinionsKilled': 192,
#   'totalTimeCCDealt': 170,
#   'totalTimeSpentDead': 66,
#   'totalUnitsHealed': 6,
#   'tripleKills': 0,
#   'trueDamageDealt': 9227,
#   'trueDamageDealtToChampions': 6513,
#   'trueDamageTaken': 1300,
#   'turretKills': 6,
#   'turretTakedowns': 6,
#   'turretsLost': 5,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 22,
#   'visionWardsBoughtInGame': 2,
#   'wardsKilled': 5,
#   'wardsPlaced': 10,
#   'win': True},
#  {'allInPings': 3,
#   'assistMePings': 2,
#   'assists': 5,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 0,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 5,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 753,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 4,
#    'baronTakedowns': 0,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7647381175227564,
#    'controlWardsPlaced': 3,
#    'damagePerMinute': 1127.6329971830557,
#    'damageTakenOnTeamPercentage': 0.1837177767205851,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 3,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 0,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 2,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 733.4644541480001,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 0,
#    'gameLength': 1485.479675233,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 512.7827937795727,
#    'hadOpenNexus': 0,
#    'highestChampionDamage': 1,
#    'immobilizeAndKillWithAlly': 0,
#    'initialBuffCount': 0,
#    'initialCrabCount': 1,
#    'jungleCsBefore10Minutes': 4,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 2,
#    'kda': 3.3333333333333335,
#    'killAfterHiddenWithAlly': 0,
#    'killParticipation': 0.8333333333333334,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 1,
#    'killsNearEnemyTurret': 1,
#    'killsOnOtherLanesEarlyJungleAsLaner': 1,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 1,
#    'knockEnemyIntoTeamAndKill': 1,
#    'landSkillShotsEarlyGame': 34,
#    'laneMinionsFirst10Minutes': 101,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3087, 3046, 3031],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 42.25,
#    'maxKillDeficit': 0,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 1,
#    'multikillsAfterAggressiveFlash': 1,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 1,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 6,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 1,
#    'skillshotsDodged': 17,
#    'skillshotsHit': 475,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 1,
#    'stealthWardsPlaced': 3,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 0,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 10,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 6,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 0,
#    'teamDamagePercentage': 0.35632383792443856,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 5,
#    'turretTakedowns': 4,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 0.18268167972564697,
#    'visionScorePerMinute': 1.0241308031496723,
#    'voidMonsterKill': 0,
#    'wardTakedowns': 7,
#    'wardTakedownsBefore20M': 6,
#    'wardsGuarded': 0},
#   'champExperience': 12068,
#   'champLevel': 14,
#   'championId': 221,
#   'championName': 'Zeri',
#   'championTransform': 0,
#   'commandPings': 6,
#   'consumablesPurchased': 4,
#   'damageDealtToBuildings': 11675,
#   'damageDealtToObjectives': 12792,
#   'damageDealtToTurrets': 11675,
#   'damageSelfMitigated': 11116,
#   'dangerPings': 0,
#   'deaths': 3,
#   'detectorWardsPlaced': 3,
#   'doubleKills': 1,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 3,
#   'enemyVisionPings': 2,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 3,
#   'goldEarned': 12695,
#   'goldSpent': 12775,
#   'holdPings': 0,
#   'individualPosition': 'MIDDLE',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 1,
#   'item0': 3123,
#   'item1': 3006,
#   'item2': 3031,
#   'item3': 3087,
#   'item4': 3046,
#   'item5': 1053,
#   'item6': 3364,
#   'itemsPurchased': 19,
#   'killingSprees': 1,
#   'kills': 5,
#   'lane': 'MIDDLE',
#   'largestCriticalStrike': 495,
#   'largestKillingSpree': 4,
#   'largestMultiKill': 2,
#   'longestTimeSpentLiving': 740,
#   'magicDamageDealt': 36898,
#   'magicDamageDealtToChampions': 9395,
#   'magicDamageTaken': 8244,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
# ...
#    'alliedJungleMonsterKills': 0,
#    'baronTakedowns': 0,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 0,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5809648130740228,
#    'controlWardsPlaced': 3,
#    'damagePerMinute': 312.26052290718366,
#    'damageTakenOnTeamPercentage': 0.24021590570248022,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 7,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 0,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 0,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 25,
#    'enemyJungleMonsterKills': 0,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 733.4644541480001,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 0,
#    'gameLength': 1485.479675233,
#    'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#    'goldPerMinute': 317.3549947476099,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 1,
#    'initialBuffCount': 0,
#    'initialCrabCount': 0,
#    'jungleCsBefore10Minutes': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 0.14285714285714285,
#    'killAfterHiddenWithAlly': 0,
#    'killParticipation': 0.08333333333333333,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 0,
#    'killsNearEnemyTurret': 0,
#    'killsOnOtherLanesEarlyJungleAsLaner': 0,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 1,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 1,
#    'landSkillShotsEarlyGame': 4,
#    'laneMinionsFirst10Minutes': 51,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [6664],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 0,
#    'maxKillDeficit': 0,
#    'maxLevelLeadLaneOpponent': 2,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': 0,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 0,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 1,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 0,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 0,
#    'skillshotsDodged': 42,
#    'skillshotsHit': 22,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 4,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 3,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 1,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 1,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 0,
#    'teamDamagePercentage': 0.09867205751563979,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 1,
#    'turretTakedowns': 0,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': 1.340153455734253,
#    'visionScorePerMinute': 0.9649363432595157,
#    'voidMonsterKill': 0,
#    'wardTakedowns': 10,
#    'wardTakedownsBefore20M': 8,
#    'wardsGuarded': 0},
#   'champExperience': 10177,
#   'champLevel': 13,
#   'championId': 516,
#   'championName': 'Ornn',
#   'championTransform': 0,
#   'commandPings': 19,
#   'consumablesPurchased': 5,
#   'damageDealtToBuildings': 718,
#   'damageDealtToObjectives': 940,
#   'damageDealtToTurrets': 718,
#   'damageSelfMitigated': 30339,
#   'dangerPings': 0,
#   'deaths': 7,
#   'detectorWardsPlaced': 3,
#   'doubleKills': 0,
#   'dragonKills': 0,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 6,
#   'enemyVisionPings': 4,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 10,
#   'goldEarned': 7857,
#   'goldSpent': 7075,
#   'holdPings': 0,
#   'individualPosition': 'UTILITY',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 1,
#   'item0': 6664,
#   'item1': 3076,
#   'item2': 1011,
#   'item3': 1054,
#   'item4': 3082,
#   'item5': 3047,
#   'item6': 3364,
#   'itemsPurchased': 24,
#   'killingSprees': 0,
#   'kills': 1,
#   'lane': 'BOTTOM',
#   'largestCriticalStrike': 4,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 464,
#   'magicDamageDealt': 45386,
#   'magicDamageDealtToChampions': 4886,
#   'magicDamageTaken': 10170,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 0,
#   'nexusKills': 0,
#   'nexusLost': 1,
#   'nexusTakedowns': 0,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 24,
#   'participantId': 9,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5011, 'flex': 5001, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8360, 'var1': 5, 'var2': 0, 'var3': 0},
#       {'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#       {'perk': 8345, 'var1': 3, 'var2': 0, 'var3': 0},
#       {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#      'style': 8300},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8444, 'var1': 1395, 'var2': 0, 'var3': 0},
#       {'perk': 8451, 'var1': 210, 'var2': 0, 'var3': 0}],
#      'style': 8400}]},
#   'physicalDamageDealt': 38178,
#   'physicalDamageDealtToChampions': 2728,
#   'physicalDamageTaken': 16268,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 7,
#   'pushPings': 0,
#   'puuid': 'D2SBkIL5HA6dqxnIypndo3c19JHiJo9HdnqNecr58sdqv7Ok-7pud7rC08el4rrAv4SHyWBkDMEVcg',
#   'quadraKills': 0,
#   'riotIdGameName': '장미장미',
#   'riotIdTagline': 'KR1',
#   'role': 'CARRY',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 66,
#   'spell2Casts': 58,
#   'spell3Casts': 25,
#   'spell4Casts': 14,
#   'subteamPlacement': 0,
#   'summoner1Casts': 3,
#   'summoner1Id': 4,
#   'summoner2Casts': 8,
#   'summoner2Id': 12,
#   'summonerId': '5UvCuYhJhdvtDQ6ul6vJs_MxsrL1I9aSgpCICzSoMf1KfdI',
#   'summonerLevel': 250,
#   'summonerName': '장미장미',
#   'teamEarlySurrendered': False,
#   'teamId': 200,
#   'teamPosition': 'BOTTOM',
#   'timeCCingOthers': 21,
#   'timePlayed': 1485,
#   'totalAllyJungleMinionsKilled': 0,
#   'totalDamageDealt': 89432,
#   'totalDamageDealtToChampions': 7730,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 29520,
#   'totalEnemyJungleMinionsKilled': 0,
#   'totalHeal': 373,
#   'totalHealsOnTeammates': 0,
#   'totalMinionsKilled': 177,
#   'totalTimeCCDealt': 372,
#   'totalTimeSpentDead': 209,
#   'totalUnitsHealed': 1,
#   'tripleKills': 0,
#   'trueDamageDealt': 5867,
#   'trueDamageDealtToChampions': 116,
#   'trueDamageTaken': 3081,
#   'turretKills': 0,
#   'turretTakedowns': 0,
#   'turretsLost': 8,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 23,
#   'visionWardsBoughtInGame': 4,
#   'wardsKilled': 8,
#   'wardsPlaced': 7,
#   'win': False},
#  {'allInPings': 1,
#   'assistMePings': 3,
#   'assists': 5,
#   'baronKills': 0,
#   'basicPings': 0,
#   'bountyLevel': 0,
#   'challenges': {'12AssistStreakCount': 0,
#    'InfernalScalePickup': 2,
#    'SWARM_DefeatAatrox': 0,
#    'SWARM_DefeatBriar': 0,
#    'SWARM_DefeatMiniBosses': 0,
#    'SWARM_EvolveWeapon': 0,
#    'SWARM_Have3Passives': 0,
#    'SWARM_KillEnemy': 0,
#    'SWARM_PickupGold': 0,
#    'SWARM_ReachLevel50': 0,
#    'SWARM_Survive15Min': 0,
#    'SWARM_WinWith5EvolvedWeapons': 0,
#    'abilityUses': 833,
#    'acesBefore15Minutes': 0,
#    'alliedJungleMonsterKills': 58,
#    'baronTakedowns': 0,
#    'blastConeOppositeOpponentCount': 0,
#    'bountyGold': 0,
#    'buffsStolen': 1,
#    'completeSupportQuestInTime': 0,
#    'controlWardTimeCoverageInRiverOrEnemyHalf': 0.7726749525542762,
#    'controlWardsPlaced': 4,
#    'damagePerMinute': 479.7764887254092,
#    'damageTakenOnTeamPercentage': 0.26985949667519893,
#    'dancedWithRiftHerald': 0,
#    'deathsByEnemyChamps': 8,
#    'dodgeSkillShotsSmallWindow': 0,
#    'doubleAces': 0,
#    'dragonTakedowns': 1,
#    'earliestDragonTakedown': 844.445840157,
#    'earlyLaningPhaseGoldExpAdvantage': 0,
#    'effectiveHealAndShielding': 3735.291015625,
#    'elderDragonKillsWithOpposingSoul': 0,
#    'elderDragonMultikills': 0,
#    'enemyChampionImmobilizations': 0,
#    'enemyJungleMonsterKills': 9,
#    'epicMonsterKillsNearEnemyJungler': 0,
#    'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#    'epicMonsterSteals': 0,
#    'epicMonsterStolenWithoutSmite': 0,
#    'firstTurretKilled': 1,
#    'firstTurretKilledTime': 733.4644541480001,
#    'fistBumpParticipation': 0,
#    'flawlessAces': 0,
#    'fullTeamTakedown': 0,
#    'gameLength': 1485.479675233,
#    'goldPerMinute': 331.46466535145873,
#    'hadOpenNexus': 0,
#    'immobilizeAndKillWithAlly': 0,
#    'initialBuffCount': 2,
#    'initialCrabCount': 1,
#    'jungleCsBefore10Minutes': 58.50000008940697,
#    'junglerKillsEarlyJungle': 0,
#    'junglerTakedownsNearDamagedEpicMonster': 0,
#    'kTurretsDestroyedBeforePlatesFall': 0,
#    'kda': 0.8888888888888888,
#    'killAfterHiddenWithAlly': 3,
#    'killParticipation': 0.6666666666666666,
#    'killedChampTookFullTeamDamageSurvived': 0,
#    'killingSprees': 0,
#    'killsNearEnemyTurret': 1,
#    'killsOnLanersEarlyJungleAsJungler': 1,
#    'killsOnRecentlyHealedByAramPack': 0,
#    'killsUnderOwnTurret': 0,
#    'killsWithHelpFromEpicMonster': 0,
#    'knockEnemyIntoTeamAndKill': 0,
#    'landSkillShotsEarlyGame': 3,
#    'laneMinionsFirst10Minutes': 5,
#    'laningPhaseGoldExpAdvantage': 0,
#    'legendaryCount': 0,
#    'legendaryItemUsed': [3100, 6653],
#    'lostAnInhibitor': 0,
#    'maxCsAdvantageOnLaneOpponent': 4,
#    'maxKillDeficit': 0,
#    'maxLevelLeadLaneOpponent': 1,
#    'mejaisFullStackInTime': 0,
#    'moreEnemyJungleThanOpponent': -59.50000008940697,
#    'multiKillOneSpell': 0,
#    'multiTurretRiftHeraldCount': 0,
#    'multikills': 0,
#    'multikillsAfterAggressiveFlash': 0,
#    'outerTurretExecutesBefore10Minutes': 1,
#    'outnumberedKills': 0,
#    'outnumberedNexusKill': 0,
#    'perfectDragonSoulsTaken': 0,
#    'perfectGame': 0,
#    'pickKillWithAlly': 5,
#    'playedChampSelectPosition': 1,
#    'poroExplosions': 0,
#    'quickCleanse': 0,
#    'quickFirstTurret': 0,
#    'quickSoloKills': 0,
#    'riftHeraldTakedowns': 1,
#    'saveAllyFromDeath': 0,
#    'scuttleCrabKills': 2,
#    'skillshotsDodged': 22,
#    'skillshotsHit': 16,
#    'snowballsHit': 0,
#    'soloBaronKills': 0,
#    'soloKills': 0,
#    'stealthWardsPlaced': 2,
#    'survivedSingleDigitHpCount': 0,
#    'survivedThreeImmobilizesInFight': 0,
#    'takedownOnFirstTurret': 0,
#    'takedowns': 8,
#    'takedownsAfterGainingLevelAdvantage': 0,
#    'takedownsBeforeJungleMinionSpawn': 0,
#    'takedownsFirstXMinutes': 6,
#    'takedownsInAlcove': 0,
#    'takedownsInEnemyFountain': 0,
#    'teamBaronKills': 0,
#    'teamDamagePercentage': 0.1516058861665225,
#    'teamElderDragonKills': 0,
#    'teamRiftHeraldKills': 1,
#    'tookLargeDamageSurvived': 0,
#    'turretPlatesTaken': 2,
#    'turretTakedowns': 0,
#    'turretsTakenWithRiftHerald': 0,
#    'twentyMinionsIn3SecondsCount': 0,
#    'twoWardsOneSweeperCount': 0,
#    'unseenRecalls': 0,
#    'visionScoreAdvantageLaneOpponent': -0.05909675359725952,
#    'visionScorePerMinute': 1.0900232491893052,
#    'voidMonsterKill': 7,
#    'wardTakedowns': 7,
#    'wardTakedownsBefore20M': 6,
#    'wardsGuarded': 0},
#   'champExperience': 8747,
#   'champLevel': 12,
#   'championId': 76,
#   'championName': 'Nidalee',
#   'championTransform': 0,
#   'commandPings': 7,
#   'consumablesPurchased': 7,
#   'damageDealtToBuildings': 0,
#   'damageDealtToObjectives': 35356,
#   'damageDealtToTurrets': 0,
#   'damageSelfMitigated': 16737,
#   'dangerPings': 0,
#   'deaths': 9,
#   'detectorWardsPlaced': 4,
#   'doubleKills': 0,
#   'dragonKills': 1,
#   'eligibleForProgression': True,
#   'enemyMissingPings': 5,
#   'enemyVisionPings': 0,
#   'firstBloodAssist': False,
#   'firstBloodKill': False,
#   'firstTowerAssist': False,
#   'firstTowerKill': False,
#   'gameEndedInEarlySurrender': False,
#   'gameEndedInSurrender': False,
#   'getBackPings': 0,
#   'goldEarned': 8206,
#   'goldSpent': 8100,
#   'holdPings': 0,
#   'individualPosition': 'JUNGLE',
#   'inhibitorKills': 0,
#   'inhibitorTakedowns': 0,
#   'inhibitorsLost': 1,
#   'item0': 6653,
#   'item1': 3100,
#   'item2': 2055,
#   'item3': 3020,
#   'item4': 0,
#   'item5': 0,
#   'item6': 3364,
#   'itemsPurchased': 23,
#   'killingSprees': 0,
#   'kills': 3,
#   'lane': 'JUNGLE',
#   'largestCriticalStrike': 0,
#   'largestKillingSpree': 0,
#   'largestMultiKill': 1,
#   'longestTimeSpentLiving': 405,
#   'magicDamageDealt': 105814,
#   'magicDamageDealtToChampions': 9041,
#   'magicDamageTaken': 9661,
#   'missions': {'playerScore0': 0,
#    'playerScore1': 0,
#    'playerScore2': 0,
#    'playerScore3': 0,
#    'playerScore4': 0,
#    'playerScore5': 0,
#    'playerScore6': 0,
#    'playerScore7': 0,
#    'playerScore8': 0,
#    'playerScore9': 0,
#    'playerScore10': 0,
#    'playerScore11': 0},
#   'needVisionPings': 0,
#   'neutralMinionsKilled': 118,
#   'nexusKills': 0,
#   'nexusLost': 1,
#   'nexusTakedowns': 0,
#   'objectivesStolen': 0,
#   'objectivesStolenAssists': 0,
#   'onMyWayPings': 41,
#   'participantId': 10,
#   'pentaKills': 0,
#   'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#    'styles': [{'description': 'primaryStyle',
#      'selections': [{'perk': 8112, 'var1': 425, 'var2': 0, 'var3': 0},
#       {'perk': 8143, 'var1': 435, 'var2': 0, 'var3': 0},
#       {'perk': 8138, 'var1': 16, 'var2': 0, 'var3': 0},
#       {'perk': 8135, 'var1': 210, 'var2': 3, 'var3': 0}],
#      'style': 8100},
#     {'description': 'subStyle',
#      'selections': [{'perk': 8210, 'var1': 0, 'var2': 0, 'var3': 0},
#       {'perk': 8232, 'var1': 4, 'var2': 40, 'var3': 0}],
#      'style': 8200}]},
#   'physicalDamageDealt': 16177,
#   'physicalDamageDealtToChampions': 1156,
#   'physicalDamageTaken': 22861,
#   'placement': 0,
#   'playerAugment1': 0,
#   'playerAugment2': 0,
#   'playerAugment3': 0,
#   'playerAugment4': 0,
#   'playerAugment5': 0,
#   'playerAugment6': 0,
#   'playerSubteamId': 0,
#   'profileIcon': 3495,
#   'pushPings': 1,
#   'puuid': '22CHQ3NCrz2ayiZgc8uqHNdlNrR1rwxPEgqyWJMHGhcCPeHQdPUYFt3vbZHxRxcb538-Yyku99sx9w',
#   'quadraKills': 0,
#   'riotIdGameName': '치킨사줬더니닭다리만골라먹는김견',
#   'riotIdTagline': '김 견',
#   'role': 'NONE',
#   'sightWardsBoughtInGame': 0,
#   'spell1Casts': 210,
#   'spell2Casts': 248,
#   'spell3Casts': 134,
#   'spell4Casts': 241,
#   'subteamPlacement': 0,
#   'summoner1Casts': 15,
#   'summoner1Id': 11,
#   'summoner2Casts': 3,
#   'summoner2Id': 4,
#   'summonerId': 'bJoj1swEs9VNsAlI9h6jCrVTFn3FsXswXNpE1zFCFcCI1d14',
#   'summonerLevel': 740,
#   'summonerName': '나는 멍청이 우우',
#   'teamEarlySurrendered': False,
#   'teamId': 200,
#   'teamPosition': 'JUNGLE',
#   'timeCCingOthers': 8,
#   'timePlayed': 1485,
#   'totalAllyJungleMinionsKilled': 79,
#   'totalDamageDealt': 180061,
#   'totalDamageDealtToChampions': 11878,
#   'totalDamageShieldedOnTeammates': 0,
#   'totalDamageTaken': 33163,
#   'totalEnemyJungleMinionsKilled': 10,
#   'totalHeal': 17210,
#   'totalHealsOnTeammates': 3735,
#   'totalMinionsKilled': 15,
#   'totalTimeCCDealt': 67,
#   'totalTimeSpentDead': 212,
#   'totalUnitsHealed': 5,
#   'tripleKills': 0,
#   'trueDamageDealt': 58069,
#   'trueDamageDealtToChampions': 1680,
#   'trueDamageTaken': 641,
#   'turretKills': 0,
#   'turretTakedowns': 0,
#   'turretsLost': 8,
#   'unrealKills': 0,
#   'visionClearedPings': 0,
#   'visionScore': 26,
#   'visionWardsBoughtInGame': 6,
#   'wardsKilled': 7,
#   'wardsPlaced': 6,
#   'win': False}]

# %%
match_info_data_df = pd.DataFrame(temp_match_data['info']['participants'])
match_info_data_df
# Out:
#    allInPings  assistMePings  assists  baronKills  basicPings  bountyLevel  \
# 0           0              6       17           0           0            5
# 1           0              0       15           0           0            4
# 2           0              0       10           0           0            1
# 3           5              9        8           1           0            6
# 4           0              0        8           0           0            4
# 5           3              2        5           0           0            0
# 6           5              1        6           0           0            0
# 7           0              5        6           0           0            0
# 8           1              4        0           0           0            0
# 9           1              3        5           0           0            0
#
#                                           challenges  champExperience  \
# 0  {'12AssistStreakCount': 0, 'InfernalScalePicku...             9842
# 1  {'12AssistStreakCount': 0, 'InfernalScalePicku...            14352
# 2  {'12AssistStreakCount': 0, 'InfernalScalePicku...            11213
# 3  {'12AssistStreakCount': 0, 'InfernalScalePicku...            13651
# 4  {'12AssistStreakCount': 0, 'InfernalScalePicku...            13696
# 5  {'12AssistStreakCount': 0, 'InfernalScalePicku...            12068
# 6  {'12AssistStreakCount': 0, 'InfernalScalePicku...            11473
# 7  {'12AssistStreakCount': 0, 'InfernalScalePicku...             6490
# 8  {'12AssistStreakCount': 0, 'InfernalScalePicku...            10177
# 9  {'12AssistStreakCount': 0, 'InfernalScalePicku...             8747
#
#    champLevel  championId  ... turretKills  turretTakedowns  turretsLost  \
# 0          12         147  ...           0                3            5
# 1          15          43  ...           1                5            5
# 2          13         202  ...           1                3            5
# 3          15         234  ...           0                2            5
# 4          15         114  ...           6                6            5
# 5          14         221  ...           3                4            8
# 6          14           4  ...           1                1            8
# 7          10         235  ...           1                2            8
# 8          13         516  ...           0                0            8
# 9          12          76  ...           0                0            8
#
#    unrealKills  visionClearedPings  visionScore  visionWardsBoughtInGame  \
# 0            0                   0           70                        7
# 1            0                   0           21                        4
# 2            0                   0           10                        1
# 3            0                   0           28                       11
# 4            0                   0           22                        2
# 5            0                   0           25                        3
# 6            0                   0           24                        6
# 7            0                   0           60                        7
# 8            0                   0           23                        4
# 9            0                   0           26                        6
#
#    wardsKilled  wardsPlaced    win
# 0           13           33   True
# 1            5            8   True
# 2            1            8   True
# 3            7            6   True
# 4            5           10   True
# 5            7            6  False
# 6            3           14  False
# 7            6           30  False
# 8            8            7  False
# 9            7            6  False
#
# [10 rows x 132 columns]

# %%
match_info_data_df[['teamId','summonerId','summonerName','summoner1Id','summoner2Id','teamPosition','championId','kills','deaths','assists','challenges','neutralMinionsKilled','totalMinionsKilled']]
# Out:
#    teamId                                         summonerId summonerName  \
# 0     100    9Ave2rsRb8fj7uWkpkHk6lbX66qYy_GFCc-TgPl3YJ0IiP4    DRX B2ryL
# 1     100    g9kHpvpql_Ci3ioM5SeRTaTVbucVAPTABBxiLJTOD0Tzz4M  73580818del
# 2     100    Fszfd1mLLW05ylSHW2d-1h5zhL4s2uyGwsvae8WJCnfJo9o          쪼사기
# 3     100  n7197s3SbRj7KIeSLuYpKNI2qw_npW1blRFprEY7vFIa7m...       날씨좋은날1
# 4     100    bAAkqwo4qp_WYrSR6csuG5JzhO2htBUP-9yqCyWPBJkPvfg          어색했
# 5     200  z1kw1nVI6EuA0lC4Z7BeD1V1fTspT5h_g-ZUMcvYKoPdq4...        아OI보리
# 6     200    XSKX9AjPjo14TcZLWnZc4UK7aV-PaAp-ho2Ujs-hbUJxhuw      Castlng
# 7     200   w08-n46Aa-NDrTvjE748q6BdEl1W_i13xxYyn8emTWj9HaRB     농심라면다내꺼야
# 8     200    5UvCuYhJhdvtDQ6ul6vJs_MxsrL1I9aSgpCICzSoMf1KfdI         장미장미
# 9     200   bJoj1swEs9VNsAlI9h6jCrVTFn3FsXswXNpE1zFCFcCI1d14    나는 멍청이 우우
#
#    summoner1Id  summoner2Id teamPosition  championId  kills  deaths  assists  \
# 0            7            4      UTILITY         147      5       1       17
# 1            4           12       MIDDLE          43      4       0       15
# 2           21            4       BOTTOM         202      3       4       10
# 3           11            4       JUNGLE         234      9       3        8
# 4           12            4          TOP         114      6       4        8
# 5            4           12       MIDDLE         221      5       3        5
# 6            6            4          TOP           4      1       4        6
# 7            4           21      UTILITY         235      2       5        6
# 8            4           12       BOTTOM         516      1       7        0
# 9           11            4       JUNGLE          76      3       9        5
#
#                                           challenges  neutralMinionsKilled  \
# 0  {'12AssistStreakCount': 0, 'InfernalScalePicku...                     0
# 1  {'12AssistStreakCount': 0, 'InfernalScalePicku...                     5
# 2  {'12AssistStreakCount': 0, 'InfernalScalePicku...                     0
# 3  {'12AssistStreakCount': 0, 'InfernalScalePicku...                   168
# 4  {'12AssistStreakCount': 0, 'InfernalScalePicku...                     3
# 5  {'12AssistStreakCount': 0, 'InfernalScalePicku...                    12
# 6  {'12AssistStreakCount': 0, 'InfernalScalePicku...                    14
# 7  {'12AssistStreakCount': 0, 'InfernalScalePicku...                     0
# 8  {'12AssistStreakCount': 0, 'InfernalScalePicku...                     0
# 9  {'12AssistStreakCount': 0, 'InfernalScalePicku...                   118
#
#    totalMinionsKilled
# 0                  39
# 1                 189
# 2                 199
# 3                  14
# 4                 192
# 5                 221
# 6                 177
# 7                  23
# 8                 177
# 9                  15
