# %%
import requests
import pandas as pd
import numpy as np
import time

# %%
# 매번 사용한 api_key값과 header를 생성한다.
import requests
 
api_key = "RGAPI-f50bfd14-2d9e-400e-ac9c-62f05873d338"
header = {"X-Riot-Token" : api_key}

# %%
# 첼린저,그랜드마스터,마스터의 솔로랭크 정보를 가져오기 위한 함수 생성

def league_v4_tier(tier):
    # 솔랭 기준
    queue = 'RANKED_SOLO_5x5'
 
    if tier == 'challenger' :
        url = f"https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/{queue}"
    elif tier == 'grandmaster':
        url = f"https://kr.api.riotgames.com/lol/league/v4/grandmasterleagues/by-queue/{queue}"
    else:
        url = f"https://kr.api.riotgames.com/lol/league/v4/masterleagues/by-queue/{queue}"
        
    return requests.get(url, headers=header)

# %%
# 티어별 솔로랭크 정보를 테이블로 만들기

challenger_data = pd.DataFrame(league_v4_tier('challenger').json())
grandmaster_data = pd.DataFrame(league_v4_tier('grandmaster').json())
master_data = pd.DataFrame(league_v4_tier('master').json())

# %%
# 첼린저 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

challenger_df = pd.DataFrame([challenger_data['entries'][0]])
data_size = len(challenger_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([challenger_data['entries'][i]])
    challenger_df = pd.concat([challenger_df,append_df],ignore_index = True)

challenger_df['tier'] = 'CHALLENGER'
challenger_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0    8wRb-eVFQ8pKxEb01nX5Wld8QS0TqVKOyufApX3SZcxja-...          1206    I
# 1    YVLH_wOkUXCfJS_n1tm5guE-IFWu0rWDz2ushzuC-WUnXB...          1087    I
# 2      REpIcOlW4VlWAqJqjjhgu2I_yHIJfw1-2T5-UGUq3aBg5NE          1097    I
# 3    006zqZuubVqBRf9kegTZzLzm96Vv_7eoJ46Ql2HJnst8cE...          1165    I
# 4    IvwprQKIMWS0tYA2N5-xCmyRMzAjLGInrlZP0lHbHIO35F...          1093    I
# ..                                                 ...           ...  ...
# 295  rLnVSxusrKlrzdNQ-fEl7B_ZF7lLIEOoPzzWZLGFEWpg4P...          1234    I
# 296    73ePdQ3oO88gKXnp_d85vPahs63KxQ-oIQv3idBvnaBu8kA          1396    I
# 297    kQ7FfdusHiiIc-zDNPHF9ipc-GsvlLX6Wwn5wxwapWTcaBk          1752    I
# 298  3p79XN6s5oXzYz3-g0cizfRn7RPtker2ZAnZT7FxleMRRy...          1099    I
# 299    Zq1nwsmhF_rJYwV12Y9oMN9rSeSNhGBFQ4FR760pIVs4OHw          1296    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak        tier
# ...

# %%
# 그랜드마스터 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

grandmaster_df = pd.DataFrame([grandmaster_data['entries'][0]])
data_size = len(grandmaster_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([grandmaster_data['entries'][i]])
    grandmaster_df = pd.concat([grandmaster_df,append_df],ignore_index = True)

grandmaster_df['tier'] = 'GRANDMASTER'
grandmaster_df
# Out:
#                                             summonerId  leaguePoints rank  \
# 0      3oxCABREglIjog6HNVl19bXdzcZjYwv2TIPN5sIBkvpbMIk           746    I
# 1      n8emo8T_mCbbwFL2Q8ZBf6MNCLa-vMiml3YCr8o-AVKNmoE           749    I
# 2    83wzsY8H2NcLMsztQWAaoTffVWXjmF_P1-u2pNqbBBLMTv...           812    I
# 3      EVypLXLcGxSHFzYsHH2BxmB1eOQxYZV98Nswf2sWrrSYYnk           738    I
# 4    B9DuXwDYGxKh0rXBbOxtgtTgld1fEjLOBz5dJ3Wn8cQsZU...           785    I
# ..                                                 ...           ...  ...
# 695  cerWLtyeN8XPSmFKqniEUFvX9r9KfRST_ddR7f4tilYulZ...           779    I
# 696    We_nqlLpxCkMMXse2iFXrksayBzHJ7UIuEqRKQKLr2-pLGQ          1000    I
# 697    O9AtUURskPC2m3lQ6mquX1DOpzPdaqKwZqbuK-GDw9EnUkw           751    I
# 698     ythsa-lvypTWLImcC6R7w2P0BtCNtH8Zuic_HHl7ZmxXVw          1019    I
# 699  5OKtkFV6frQrNYJ0GS8vRIOv6Zd06X3t4XhYWWG5SmJPk1...           920    I
#
#      wins  losses  veteran  inactive  freshBlood  hotStreak         tier
# ...

# %%
# 마스터 티어의 솔로랭크 정보중 entries에 들어 있는 summonerId 및 승패정보를 테이블로 담기

master_df = pd.DataFrame([master_data['entries'][0]])
data_size = len(master_data)

for i in range(1,data_size):
    append_df = pd.DataFrame([master_data['entries'][i]])
    master_df = pd.concat([master_df,append_df],ignore_index = True)

master_df['tier'] = 'MASTER'
master_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0         t46v-rEQQ0v75RY6j5u8_dbTx95coCsZ1XIyaURCUjKv2Q            12    I
# 1        rqtcAw8Ynj_1CaIbkMCljKSAizIrTxSmqdkuZPhSquwJLxs           476    I
# 2        lpyjGMsiBq33uAT9PG0XNaNDBJ3ZUV1aihCZpQ-QjCO5ldg           199    I
# 3      zi2RzsEek1bPkHN7R89QYXjWJs9FqsTZ19-FUTmAioTeLx...            18    I
# 4        0ucgAMgcUVv8jICUm0WwkPdxJWXS8xp0RC4MpdcBN-EuQqA           143    I
# ...                                                  ...           ...  ...
# 13793  E7OOQdQ2fjMAC85Fbl5V1wPS9tzeBNNQvb-c66YgBQo5L_...           267    I
# 13794     7tWYTsnDmuPgZAuYbLlC_500sskflkDBxUyC3Vv_bpLvug             0    I
# 13795    s2yVVpiotmFNBBy-KjPUKU3O58CYF057sa2TMqYtQD6Gwrk            91    I
# 13796  rHa_cz_DwhnVnhlhfUJx8EltLvWjsVm-nU78KiWqwiwODZ...            13    I
# 13797    KHPokwbOJ9xLlE9JIzpesoo82C9a_X4RvAj9P1_jFrXJttQ           575    I
#
# ...

# %%
# 첼린저,그마,마스터 티어의 entries정보를 하나의 테이블로 합치기

top_class_df = pd.concat([challenger_df,grandmaster_df,master_df],ignore_index = True)
top_class_df
# Out:
#                                               summonerId  leaguePoints rank  \
# 0      8wRb-eVFQ8pKxEb01nX5Wld8QS0TqVKOyufApX3SZcxja-...          1206    I
# 1      YVLH_wOkUXCfJS_n1tm5guE-IFWu0rWDz2ushzuC-WUnXB...          1087    I
# 2        REpIcOlW4VlWAqJqjjhgu2I_yHIJfw1-2T5-UGUq3aBg5NE          1097    I
# 3      006zqZuubVqBRf9kegTZzLzm96Vv_7eoJ46Ql2HJnst8cE...          1165    I
# 4      IvwprQKIMWS0tYA2N5-xCmyRMzAjLGInrlZP0lHbHIO35F...          1093    I
# ...                                                  ...           ...  ...
# 14793  E7OOQdQ2fjMAC85Fbl5V1wPS9tzeBNNQvb-c66YgBQo5L_...           267    I
# 14794     7tWYTsnDmuPgZAuYbLlC_500sskflkDBxUyC3Vv_bpLvug             0    I
# 14795    s2yVVpiotmFNBBy-KjPUKU3O58CYF057sa2TMqYtQD6Gwrk            91    I
# 14796  rHa_cz_DwhnVnhlhfUJx8EltLvWjsVm-nU78KiWqwiwODZ...            13    I
# 14797    KHPokwbOJ9xLlE9JIzpesoo82C9a_X4RvAj9P1_jFrXJttQ           575    I
#
# ...

# %%
# summonerid로 소환사 정보인 puuid를 가져오기 위한 API코드
def summoners(encryptedSummonerId):
    url = f"https://kr.api.riotgames.com/lol/summoner/v4/summoners/{encryptedSummonerId}"
    
    return requests.get(url, headers = header)

# %%
# top_class_df에 추가적으로 컬럼을 생성하고 temp값을 넣어 둔다.(주석처리해둔다)

"""
top_class_df['accountId'] = 'temp_1'
top_class_df['puuid'] = 'temp_2'
top_class_df['profileIconId'] = 'temp_3'
top_class_df['revisionDate'] = 'temp_4'
top_class_df['summonerLevel'] = 'temp_5'
"""

# %%
# 유저마다 puuid,accountid등을 가져와서 top_class_df에 넣는다.
# 해당코드는 한번 생성한 뒤에는 실행되지 않게끔 주석처리해둔다.

"""
for i in range(len(top_class_df)):
    encryptedSummonerId = top_class_df['summonerId'].loc[i]
    summoners_info = summoners(encryptedSummonerId).json()

    acid = summoners_info['accountId']
    puid = summoners_info['puuid']
    proid = summoners_info['profileIconId']
    re_date = summoners_info['revisionDate']
    summo_level = summoners_info['summonerLevel']

    top_class_df.loc[i,'accountId'] = acid
    top_class_df.loc[i,'puuid'] = puid
    top_class_df.loc[i,'profileIconId'] = proid
    top_class_df.loc[i,'revisionDate'] = re_date
    top_class_df.loc[i,'summonerLevel'] = summo_level
    
    print(i,summoners_info['id'])
    if i%100 == 0:
        top_class_df.to_csv("lol_summoner_tb.csv")
        print("중간저장 합니다.")
    else:
        pass

    time.sleep(1)

top_class_df.to_csv("lol_summoner_tb.csv")
top_class_df
"""
# Out:
# 0 iu9Bqa1ZWsuuuBaGGxDnvHoNp4hF4opbM-6fkZi_Vsd1EJE
# 중간저장 합니다.
# 1 ePH97qZuKh8WOiFWT9McXhKRVpNj2OB1hBWmiC3_X2b0uHY
# 2 QN-0f_FEw8Dmo3mL91c5wrKOdcHtIKKykjWrMazb3KHNKRo
# 3 QT09KWHgrtgPYCbQpnRMV_n7kC4RobcVfBrVIDFbeGyuWnTD
# 4 U3vfmFzGwbTf7525keZC8NzucB-q9-FzlpF9ibrdzVWrcGY
# 5 VxGElG9oszy7hp9AB-dahWqyO5cYOJ_0tsdI4HhDW6dgIyq7WDJKpfIgAA
# 6 qBkY_WoD4AceNYOLpx6lxuV_WUY6Q_vZCD5mKJrZasK5CLhVGXEPpYnHrg
# 7 cHqD5t-tD5fB9oXuVubxyjZj4tBByS-fGJA5JUAy4qCgix8
# 8 WM1bxfvRj9Di-t-yq3lAVo3yXPtdxiLmXZZpdk799FaGHqE
# 9 rrI2jOyK91QKi4OuOfy-FdX56L1NrpCiZHYEU7hBoEHT7KI
# 10 p0dnYl0FKB6DXtwVEZwWBhlEv8LyT-PqpHbKEFqYZEeGlv8
# 11 vva82OSfjBWli3YIUpJpI864Xr3UUt10Y-BQYc2iBh7Qn1fJcvrKLQZITw
# 12 2nj9ox18ClJntEEanOcRbkXUR7PzdgSXR9Xbo86sTnKMRxUYqktf22mvGQ
# 13 eteIZAD0Tv7SOCYn6WI0r9J1UmXLG7NKqA0tJFm0dW3tmVNORQ5sajEBNg
# 14 Mzxq1irBGGR_IPcwMbRn_9q8YintZuB_Tz2rhnvJ6bJqP44
# 15 H8jFI2RPHpFWmxHdhPFZIEAJXm0hDB7X6M8kGE2DXrUEQSwqIQxW9KKP3Q
# 16 SCfvkUpcyPY-oLIZmfIMF6ZucBNYT_YFC6yTjON6Q3Hhfxora8nF610wnQ
# ...

# %%
# CSV파일로 저장한 top_class_df를 불러온다.

user_basic_df = pd.read_csv("lol_summoner_tb.csv")
user_basic_df
# Out:
#        Unnamed: 0                                         summonerId  \
# 0               0    iu9Bqa1ZWsuuuBaGGxDnvHoNp4hF4opbM-6fkZi_Vsd1EJE
# 1               1    ePH97qZuKh8WOiFWT9McXhKRVpNj2OB1hBWmiC3_X2b0uHY
# 2               2    QN-0f_FEw8Dmo3mL91c5wrKOdcHtIKKykjWrMazb3KHNKRo
# 3               3   QT09KWHgrtgPYCbQpnRMV_n7kC4RobcVfBrVIDFbeGyuWnTD
# 4               4    U3vfmFzGwbTf7525keZC8NzucB-q9-FzlpF9ibrdzVWrcGY
# ...           ...                                                ...
# 14729       14729  V8qpRyZvd27OdiCgqQmj7feBeq3gL1Ce2A_94Hz71hQgvd...
# 14730       14730    4OIPYx-fNzQhQCW1DM7EUvpoMVEq23oKarLKQKoAf1ttgrE
# 14731       14731    JcM3a0Yw_3qhsBuURT_LiI7ezi0TsR38se0wESUej3SNzDo
# 14732       14732     TYUxw6DOV4aW2AVzR0M411IfCjIkjoLYF8ZxB2I3fMlNGg
# 14733       14733  scnqweVhygYOpyyQ0s66Z6QnQyH6TW6uygyLBWhKri_3UN...
#
#        leaguePoints rank  wins  losses  veteran  inactive  freshBlood  \
# ...

# %%
# puuid를 활용하여 match list를 불러오는 함수

def match_list(puuid):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?type=ranked&start={0}&count={100}"
    
    return requests.get(url, headers=header)

# %%
# puuid를 사용하여 유저별로 100개의 match list를 불러오고 중복된 리스트는 제거하여 14,773명의 전체 경기 리스트를 생성(주석처리)

"""
puuid_match_list = []

for i in range(len(user_basic_df['puuid'])):
    puuid = user_basic_df['puuid'].loc[i]
    add_match_list = match_list(puuid).json()
    puuid_match_list = list(set(puuid_match_list + add_match_list))
    print(i,puuid,len(puuid_match_list))
    time.sleep(1)

puuid_match_list
"""
# Out:
# 0 QeSI9xFO_BjWyfJOA4r2u_68Vje6oqnqNuM0KB-mlftO_FBi1kgbMIPZNV-NsETt6CLvygZ9Tec3kg 100
# 1 JvspNlohSNIiiXS58cvaCpo-pnL3Yb3dTeeI5ap9kF_BnXQpLXi9TAUceq9cIR2qGAV-19pb8tduqg 199
# 2 TpBGuaZ7aLQVv8E1t2Bocs2ENoA9_u0d3M9VjgST8LVqSUqOhrQWtbDOlbCoIGMv6tBHSAjr5wVb_g 298
# 3 H1eeRph-Fmd9gyGlvwYgxvjvNRUxyR3n1HwJPmeaY9fopOF7nS3r87YoYdn7XFcEpYinlrMizC2RXw 396
# 4 ceG_uauZlgZfA6S5jJDl3zdsnVtVNgTiIq3xn2JOJUyiy5TDGNr6PwOH-5HOulzc6ocDZwTQpuCtZA 492
# 5 9vbXzuTMX8gNdteBw3JIxaekcEErturpBnn0JP2pBzsEfKeD-bsewaqPC5c4dSe8QcGHemnExGNWTQ 589
# 6 yKyNLkTwxwvc5UcxcVJ93k7p45GgGGWm9bkuWifKHDeDRdIuSBBJWo2ysk_Qwdtou4mK99PhszrK6A 689
# 7 o_OTUsIBq4kU7QAlXA_8SlNyrEt0cMFVwhkAcfwtVn7LegHIfSZjVXuLqS7A_qHkqJKQ-YTtUDUhow 780
# 8 gawLXJxhGVTlnKcsqjbBlINaPjaGiTWbieJs10_pAD9PG6eDG5m1E5NEswrGiosioXb1u9UBkVgTEg 880
# 9 CtadsPwBPadNmKjU39Va6q68KTVRQQffYzk-MSS9niJ1x0w0ZrGy8LH3rEge9S6nqBUtfyVRQalOyA 974
# 10 LQ2jrGzLI85VQ2kF1rtkUGLb1dek_25NcO5KNveWda8Mn7SsEGBJt3CMqztdRfFpkatAtKrCzfwAHA 1061
# ...

# %%
# puuid로 생성한 match list를 테이블형태로 변환하여 CSV파일로 저장(주석처리)

"""
match_df = pd.DataFrame(puuid_match_list)
match_df.rename(columns={0 : 'user_match_list'},inplace=True)
match_df.to_csv("summoner_match_tb.csv")
match_df
"""
# Out:
#        user_match_list
# 0        KR_7131747348
# 1        KR_7148470299
# 2        KR_7119629224
# 3        KR_7115008566
# 4        KR_7099095905
# ...                ...
# 627396   KR_7148578603
# 627397   KR_7112348152
# 627398   KR_7114142622
# 627399   KR_7127406946
# 627400   KR_7140380155
#
# [627401 rows x 1 columns]

# %%
# 저장된 user의 match list 불러오기

user_match_df = pd.read_csv("summoner_match_tb.csv")
user_match_df = user_match_df.drop(['Unnamed: 0'],axis=1)
user_match_df
# Out:
#        user_match_list
# 0        KR_7131747348
# 1        KR_7148470299
# 2        KR_7119629224
# 3        KR_7115008566
# 4        KR_7099095905
# ...                ...
# 627396   KR_7148578603
# 627397   KR_7112348152
# 627398   KR_7114142622
# 627399   KR_7127406946
# 627400   KR_7140380155
#
# [627401 rows x 1 columns]

# %%
def match(matchId):
    url = f"https://asia.api.riotgames.com/lol/match/v5/matches/{matchId}"
    
    return requests.get(url, headers=header)

# %%
match_data_metadata_df = pd.DataFrame()

for i in range(5):
    # matchid를 통해 match정보를 가져오기
    matchId = user_match_df['user_match_list'].loc[i]
    match_data_row = match(matchId).json()

    # match정보중 metadata를 전처리하여 match별로 쌓아서 테이블로 생성------------------------------
    match_data_metadata = pd.DataFrame(match_data_row['metadata'])

    match_data_metadata['player_1'] = match_data_metadata['participants'].loc[0]
    match_data_metadata['player_2'] = match_data_metadata['participants'].loc[1]
    match_data_metadata['player_3'] = match_data_metadata['participants'].loc[2]
    match_data_metadata['player_4'] = match_data_metadata['participants'].loc[3]
    match_data_metadata['player_5'] = match_data_metadata['participants'].loc[4]
    match_data_metadata['player_6'] = match_data_metadata['participants'].loc[5]
    match_data_metadata['player_7'] = match_data_metadata['participants'].loc[6]
    match_data_metadata['player_8'] = match_data_metadata['participants'].loc[7]
    match_data_metadata['player_9'] = match_data_metadata['participants'].loc[8]
    match_data_metadata['player_10'] = match_data_metadata['participants'].loc[9]

    match_data_metadata.drop(['participants'],axis=1,inplace=True)
    match_data_metadata.drop([1,2,3,4,5,6,7,8,9],axis=0,inplace=True)
    match_data_metadata

    append_mata = match_data_metadata
    match_data_metadata_df = pd.concat([match_data_metadata_df,append_mata],ignore_index = True)
    #--------------------------------------------------------------------------------------------


    print(i,matchId)
    time.sleep(1)


match_data_metadata_df
# Out:
# 0 KR_7131747348
# 1 KR_7148470299
# 2 KR_7119629224
# 3 KR_7115008566
# 4 KR_7099095905
#   dataVersion        matchId  \
# 0           2  KR_7131747348
# 1           2  KR_7148470299
# 2           2  KR_7119629224
# 3           2  KR_7115008566
# 4           2  KR_7099095905
#
#                                             player_1  \
# 0  B83PwkYljOCD9q6ObhPYPLRTtF2GNTlg7y3D9JjOhLWSpV...
# 1  KVH5Pgu5NlyE__yf6NJR4GN6YAlIqRzZsbhVefaVEHerPb...
# 2  25k3AYEOln641aD9yu93wvozo6_iexxkJI2EANdZvAmXWk...
# 3  fdVSjlblc_sxW6SWA1mCwTfy2dy7LofVcxKMXIy8U5np0N...
# 4  9rBpKbL6S6YjOZ-EqePSKp746bgP7_bv4tpEeSFgZ_mBWg...
#
#                                             player_2  \
# 0  SRy7kInCA4ueBCJyDn9CsCyVDkb95_AzVJOTii3lk4UClf...
# 1  1B9FAJf_lDEuWu1iHd9UYitn6uGfMaFcarxtEtDVmXZcSW...
# 2  DZPt_qsDIGJOypuytsQT1lEROmwKEY2YKjvDdP5QX3lXFJ...
# 3  aOugu91Lb4krSBx2oa06WXXPeRB4XXI6ToZwmbxL53UA0x...
# 4  5MtfIe_edEXERXIANRaiVqTvXzzJKOKe9caHTSMg7zEXHi...
#
# ...

# %%
match_id_test = user_match_df['user_match_list'].loc[0]
match_data_temp = match(match_id_test).json()
match_data_temp
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_7131747348',
#   'participants': ['B83PwkYljOCD9q6ObhPYPLRTtF2GNTlg7y3D9JjOhLWSpV5sw_oCzfKD6nLB0qBCJEw1eSX3TM50bA',
#    'SRy7kInCA4ueBCJyDn9CsCyVDkb95_AzVJOTii3lk4UClfJjdz-4LC1h75sRdxTHRkg21cKTlciqvQ',
#    'gFNvKqX94tEHCPv5Md5IcbA7BTkFWGwel8EliX88x-fg-XOgDap-RCKzUfqkoOBJvi-TXt9e_x8wlA',
#    'bRC9rzZ8ysgkPgtMirIV26ci4qGK0yeUgqprTmeMxzVLU8c4oA_jWatzKNZtlPbbNPhx18Co7e-xPg',
#    '_zSDaqLtyP2i9mvANKWWpfiM9APoXP8sm16-c0vLPIBQPjE8AFP7J4ZHiglqRjgf1XR_hsxkMjeQMw',
#    'oKMURIArWnffbfV7U4IP6jeVq78rQDB2zuG799KG9CTg-6CV0T21qAD7KuJigUQQS11xiq3EBdKZ2g',
#    'wQuuOiR4yuTIpDG_pgHbi87ayx-mbb1XiycWx-PwJu1Vjw13oHpfxqCVj-aZ2btq-r9QmlG02AW1Kg',
#    'iRL0PfHJErOMeqLnzvADBAze8VH506fCYmIMwAhI0woGpatcpgIsuE9vWYSIxiYI6ljXzsvJUt1V_w',
#    'zkSvDYHu89lkQp5gSwdnp0AJEpG7BmD-zWv7WVb1vwlWoXMRTLglvXC8f-w3BFr9ikvrHN-5UcU3VA',
#    'a5Aj-3ivDMjfhm9UTnueKAfwsxYCIQ17hspIy6mreGTv9q3rua6euzQa3e8e5UrEBm-HX6ULtKTYcA']},
# ...

# %%
pd.DataFrame(match_data_temp['info']['participants'][0]['challenges'])
# Out:
#    12AssistStreakCount  InfernalScalePickup  abilityUses  acesBefore15Minutes  \
# 0                    0                    0          132                    0
#
#    alliedJungleMonsterKills  baronTakedowns  blastConeOppositeOpponentCount  \
# 0                         0               0                               0
#
#    bountyGold  buffsStolen  completeSupportQuestInTime  ...  \
# 0           0            0                           0  ...
#
#    turretsTakenWithRiftHerald  twentyMinionsIn3SecondsCount  \
# 0                           0                             0
#
#    twoWardsOneSweeperCount  unseenRecalls  visionScoreAdvantageLaneOpponent  \
# 0                        0              0                          2.570829
#
#    visionScorePerMinute  voidMonsterKill  wardTakedowns  \
# 0              0.707541                0              1
#
#    wardTakedownsBefore20M  wardsGuarded
# 0                       1             2
#
# [1 rows x 114 columns]

# %%
match_data_participants = pd.DataFrame(match_data_Test['info']['participants'])
match_data_teams = pd.DataFrame(match_data_Test['info']['teams'])

# %%
match_data_participants
# Out:
#    allInPings  assistMePings  assists  baronKills  basicPings  bountyLevel  \
# 0           0              5        1           0           0            0
# 1           0              0        2           0           0            0
# 2           0              0        0           0           0            0
# 3           0              0        2           0           0            1
# 4           0              0        5           0           0            0
# 5           0              0        3           0           0            0
# 6           0              2        5           0           0            3
# 7           0              0        0           0           0            0
# 8           0              2        5           0           0            3
# 9           0              0       12           0           0            3
#
#                                           challenges  champExperience  \
# 0  {'12AssistStreakCount': 0, 'InfernalScalePicku...             6510
# ...

# %%
match_data_teams
# Out:
#                                                 bans  \
# 0  [{'championId': 143, 'pickTurn': 1}, {'champio...
# 1  [{'championId': 18, 'pickTurn': 6}, {'champion...
#
#                                           objectives  teamId    win
# 0  {'baron': {'first': False, 'kills': 0}, 'champ...     100  False
# 1  {'baron': {'first': False, 'kills': 0}, 'champ...     200   True

# %%
del match_data_Test['info']['participants']
del match_data_Test['info']['teams']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 3
#       1 del match_data_Test['info']['participants']
#       2 del match_data_Test['info']['teams']
# ----> 3 match_data_info = pd.DataFrame(match_data_Test['info'])
#       4 match_data_info
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
match_data_info = pd.DataFrame(match_data_Test['info'],index=[0])
match_data_info
# Out:
#   endOfGameResult   gameCreation  gameDuration  gameEndTimestamp      gameId  \
# 0    GameComplete  1719858250588           930     1719859200182  7131747348
#
#   gameMode                      gameName  gameStartTimestamp      gameType  \
# 0  CLASSIC  teambuilder-match-7131747348       1719858269755  MATCHED_GAME
#
#       gameVersion  mapId platformId  queueId tournamentCode
# 0  14.13.596.7996     11         KR      420

# %%
match_data_Test['info']
# Out:
# {'endOfGameResult': 'GameComplete',
#  'gameCreation': 1719858250588,
#  'gameDuration': 930,
#  'gameEndTimestamp': 1719859200182,
#  'gameId': 7131747348,
#  'gameMode': 'CLASSIC',
#  'gameName': 'teambuilder-match-7131747348',
#  'gameStartTimestamp': 1719858269755,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '14.13.596.7996',
#  'mapId': 11,
#  'platformId': 'KR',
#  'queueId': 420,
#  'tournamentCode': ''}
