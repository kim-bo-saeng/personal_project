# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
data_meta = pd.read_csv('c:\\Users\\user\\Documents\\GitHub\\data_tb_file\\lol_metadata_tb.csv')
data_meta
# Out:
#        Unnamed: 0  dataVersion        matchId  \
# 0               0            2  KR_7131747348
# 1               1            2  KR_7148470299
# 2               2            2  KR_7119629224
# 3               3            2  KR_7115008566
# 4               4            2  KR_7099095905
# ...           ...          ...            ...
# 20392       20392            2  KR_7131641171
# 20393       20393            2  KR_7138034706
# 20394       20394            2  KR_7148821577
# 20395       20395            2  KR_7103294636
# 20396       20396            2  KR_7157673001
#
#                                                 player_1  \
# 0      B83PwkYljOCD9q6ObhPYPLRTtF2GNTlg7y3D9JjOhLWSpV...
# 1      KVH5Pgu5NlyE__yf6NJR4GN6YAlIqRzZsbhVefaVEHerPb...
# 2      25k3AYEOln641aD9yu93wvozo6_iexxkJI2EANdZvAmXWk...
# 3      fdVSjlblc_sxW6SWA1mCwTfy2dy7LofVcxKMXIy8U5np0N...
# 4      9rBpKbL6S6YjOZ-EqePSKp746bgP7_bv4tpEeSFgZ_mBWg...
# ...                                                  ...
# ...

# %%
for i in range(10):
    players = data_meta['player'+str(i)]

# %%
player_list_row = list(data_meta['player_1'])+list(data_meta['player_2'])+list(data_meta['player_3'])+list(data_meta['player_4'])+list(data_meta['player_5'])+list(data_meta['player_6'])+list(data_meta['player_7'])+list(data_meta['player_8'])+list(data_meta['player_9'])+list(data_meta['player_10'])
player_list_row
# Out:
# ['B83PwkYljOCD9q6ObhPYPLRTtF2GNTlg7y3D9JjOhLWSpV5sw_oCzfKD6nLB0qBCJEw1eSX3TM50bA',
#  'KVH5Pgu5NlyE__yf6NJR4GN6YAlIqRzZsbhVefaVEHerPbmQ_GgXqXCc4glR2daZjXkiX-5Jp6hZ0A',
#  '25k3AYEOln641aD9yu93wvozo6_iexxkJI2EANdZvAmXWkN4WpOCBuYsPex883uokXSMBy26qRXSRw',
#  'fdVSjlblc_sxW6SWA1mCwTfy2dy7LofVcxKMXIy8U5np0N-wQYelqyMzZ7cEsaNvqKwtO7VYGXGxpQ',
#  '9rBpKbL6S6YjOZ-EqePSKp746bgP7_bv4tpEeSFgZ_mBWgLwGuxZrG8arxmdE5s2Z9ONSgG2djIcaQ',
#  'hUOgFVSOp2SgMaN4WZ8P5VxaqW1mh2Thoav1bEOxARTZSZYq4ED4cXhhnWZFu8LB1ddYjmCZhA7YcA',
#  'TsGBHY3ehUfkRmGKrdx2q-8Nf25HRGav88Gr0y3Z5YyFQW1D62F2_61joGUuxKJs3CiztaFIoeGkuQ',
#  'usjeuEdRUjWblJkUBNMz46QrmJtGN-BnzCyttvJP1RmIey46lSSF5iBGnf18tChkig6bEwXbmZtwDA',
#  'ywLUQFbUxBFRpezxKWN5Fu8TuXhnhYwH4WQhzXpD1LAMHt-F-3igHF9J1y6hS-hwFI4tnG0eyZHYOw',
#  '8XxmHvM-KSM7sLKOFjm4zYe0xpsIsVVptUGbEpuwcs71wQWudmYB7U4aX2TNci2v4ZbS7wSytjeQdw',
#  '38Dx3uRK4UmfJ1O5cY2NSOF2Ns37RoONVD6XcD0vNAMc0KvF7tfd4K39m7YOwQfj0ojuO4K5giOv2w',
# ...

# %%
len(player_list_row)
# Out:
# 203970

# %%
len(set(player_list_row))
# Out:
# 90392
